# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6dad510c752a8889ccc9d341278fdbf3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6dad510c752a8889ccc9d341278fdbf3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6dad510c752a8889ccc9d341278fdbf3 = L.map(
#                 &quot;map_6dad510c752a8889ccc9d341278fdbf3&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7cd4261f2a869289273e81d490d3866 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e7cd4261f2a869289273e81d490d3866.addTo(map_6dad510c752a8889ccc9d341278fdbf3);
#
#
#             var feature_group_f2636d67c818a99c076bf58fe573ceb7 = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_f2636d67c818a99c076bf58fe573ceb7.addTo(map_6dad510c752a8889ccc9d341278fdbf3);
#
#
#             var feature_group_sub_group_b812c70702422b77af6cbf5d0e1e2967 = L.featureGroup.subGroup(
#                 feature_group_f2636d67c818a99c076bf58fe573ceb7
#             );
#
#
#             var marker_06d84bbede20ce3ccd7f1455b55416be = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_b812c70702422b77af6cbf5d0e1e2967);
#
#
#             var marker_81252e4566ded0fcf3106c88d418a120 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_b812c70702422b77af6cbf5d0e1e2967);
#
#
#             feature_group_sub_group_b812c70702422b77af6cbf5d0e1e2967.addTo(map_6dad510c752a8889ccc9d341278fdbf3);
#
#
#             var feature_group_sub_group_5fe1a10780f782f1a750c4e66dd87eac = L.featureGroup.subGroup(
#                 feature_group_f2636d67c818a99c076bf58fe573ceb7
#             );
#
#
#             var marker_f1519087756718eb4049f4c11c860c7b = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_5fe1a10780f782f1a750c4e66dd87eac);
#
#
#             var marker_5e6c76d080414b740f99fecb61685652 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_5fe1a10780f782f1a750c4e66dd87eac);
#
#
#             feature_group_sub_group_5fe1a10780f782f1a750c4e66dd87eac.addTo(map_6dad510c752a8889ccc9d341278fdbf3);
#
#
#             var layer_control_eca583c89abd6ec55b1233b6d9c9b9ea_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_e7cd4261f2a869289273e81d490d3866,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_f2636d67c818a99c076bf58fe573ceb7,
#                     &quot;group1&quot; : feature_group_sub_group_b812c70702422b77af6cbf5d0e1e2967,
#                     &quot;group2&quot; : feature_group_sub_group_5fe1a10780f782f1a750c4e66dd87eac,
#                 },
#             };
#             let layer_control_eca583c89abd6ec55b1233b6d9c9b9ea = L.control.layers(
#                 layer_control_eca583c89abd6ec55b1233b6d9c9b9ea_layers.base_layers,
#                 layer_control_eca583c89abd6ec55b1233b6d9c9b9ea_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_6dad510c752a8889ccc9d341278fdbf3);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ae4bb8dbce51ded80a5265a06a5ce18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ae4bb8dbce51ded80a5265a06a5ce18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ae4bb8dbce51ded80a5265a06a5ce18 = L.map(
#                 &quot;map_8ae4bb8dbce51ded80a5265a06a5ce18&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1e2bb8e5abda466457a4cbd35d1cb2d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c1e2bb8e5abda466457a4cbd35d1cb2d.addTo(map_8ae4bb8dbce51ded80a5265a06a5ce18);
#
#
#             var marker_cluster_d006ff3eed50e3aa34f1238ce7b7b10e = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_d006ff3eed50e3aa34f1238ce7b7b10e.addTo(map_8ae4bb8dbce51ded80a5265a06a5ce18);
#
#
#             var feature_group_sub_group_e9c338e2b8ca3e2507c9056c3fc65b9a = L.featureGroup.subGroup(
#                 marker_cluster_d006ff3eed50e3aa34f1238ce7b7b10e
#             );
#
#
#             var marker_af3b3a5ebc6f35ed7f4184261bf0a276 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_e9c338e2b8ca3e2507c9056c3fc65b9a);
#
#
#             var marker_11e61c5f505dc6ad5d7851e6fc864207 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_e9c338e2b8ca3e2507c9056c3fc65b9a);
#
#
#             feature_group_sub_group_e9c338e2b8ca3e2507c9056c3fc65b9a.addTo(map_8ae4bb8dbce51ded80a5265a06a5ce18);
#
#
#             var feature_group_sub_group_f04384e0c180c5a2480d2a0d88d4de06 = L.featureGroup.subGroup(
#                 marker_cluster_d006ff3eed50e3aa34f1238ce7b7b10e
#             );
#
#
#             var marker_390d764233784fcc2956c6ccb2826d23 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_f04384e0c180c5a2480d2a0d88d4de06);
#
#
#             var marker_a5507154dfb6fb05314f4498361a798c = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_f04384e0c180c5a2480d2a0d88d4de06);
#
#
#             feature_group_sub_group_f04384e0c180c5a2480d2a0d88d4de06.addTo(map_8ae4bb8dbce51ded80a5265a06a5ce18);
#
#
#             var layer_control_fb8664d01f917f0f472deb09b6e1df3f_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_c1e2bb8e5abda466457a4cbd35d1cb2d,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_e9c338e2b8ca3e2507c9056c3fc65b9a,
#                     &quot;group2&quot; : feature_group_sub_group_f04384e0c180c5a2480d2a0d88d4de06,
#                 },
#             };
#             let layer_control_fb8664d01f917f0f472deb09b6e1df3f = L.control.layers(
#                 layer_control_fb8664d01f917f0f472deb09b6e1df3f_layers.base_layers,
#                 layer_control_fb8664d01f917f0f472deb09b6e1df3f_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_8ae4bb8dbce51ded80a5265a06a5ce18);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
