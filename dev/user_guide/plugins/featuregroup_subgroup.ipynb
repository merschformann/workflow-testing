# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82ec7be486b7ce7202ab27b0cf81cf73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82ec7be486b7ce7202ab27b0cf81cf73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82ec7be486b7ce7202ab27b0cf81cf73 = L.map(
#                 &quot;map_82ec7be486b7ce7202ab27b0cf81cf73&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d895d8a5ee052edfb3f6f0817805cb62 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d895d8a5ee052edfb3f6f0817805cb62.addTo(map_82ec7be486b7ce7202ab27b0cf81cf73);
#
#
#             var feature_group_2c0164fd57db5787e4741cc3bd96eb2e = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_2c0164fd57db5787e4741cc3bd96eb2e.addTo(map_82ec7be486b7ce7202ab27b0cf81cf73);
#
#
#             var feature_group_sub_group_f2697ad4a0e1d039f7deeb6935cb06ae = L.featureGroup.subGroup(
#                 feature_group_2c0164fd57db5787e4741cc3bd96eb2e
#             );
#
#
#             var marker_9ed0d829eb8b23493ecae0ba6ce8ec37 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_f2697ad4a0e1d039f7deeb6935cb06ae);
#
#
#             var marker_5314fee49c8db635e8882421a980ce21 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_f2697ad4a0e1d039f7deeb6935cb06ae);
#
#
#             feature_group_sub_group_f2697ad4a0e1d039f7deeb6935cb06ae.addTo(map_82ec7be486b7ce7202ab27b0cf81cf73);
#
#
#             var feature_group_sub_group_af81f785afea6f2043615fc3a3ee4a85 = L.featureGroup.subGroup(
#                 feature_group_2c0164fd57db5787e4741cc3bd96eb2e
#             );
#
#
#             var marker_77d170f48ec1ff3d389eddb801e4f2b6 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_af81f785afea6f2043615fc3a3ee4a85);
#
#
#             var marker_5b5f8382ebaab490b27ae772240ff9a4 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_af81f785afea6f2043615fc3a3ee4a85);
#
#
#             feature_group_sub_group_af81f785afea6f2043615fc3a3ee4a85.addTo(map_82ec7be486b7ce7202ab27b0cf81cf73);
#
#
#             var layer_control_5cbcb2c3831fda342ad06a15271a8659_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_d895d8a5ee052edfb3f6f0817805cb62,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_2c0164fd57db5787e4741cc3bd96eb2e,
#                     &quot;group1&quot; : feature_group_sub_group_f2697ad4a0e1d039f7deeb6935cb06ae,
#                     &quot;group2&quot; : feature_group_sub_group_af81f785afea6f2043615fc3a3ee4a85,
#                 },
#             };
#             let layer_control_5cbcb2c3831fda342ad06a15271a8659 = L.control.layers(
#                 layer_control_5cbcb2c3831fda342ad06a15271a8659_layers.base_layers,
#                 layer_control_5cbcb2c3831fda342ad06a15271a8659_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_82ec7be486b7ce7202ab27b0cf81cf73);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b0e79e71a86e94f809ae588d3ad0549 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b0e79e71a86e94f809ae588d3ad0549&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b0e79e71a86e94f809ae588d3ad0549 = L.map(
#                 &quot;map_1b0e79e71a86e94f809ae588d3ad0549&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe92a1471d0605ab6aed198a42e05e1e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fe92a1471d0605ab6aed198a42e05e1e.addTo(map_1b0e79e71a86e94f809ae588d3ad0549);
#
#
#             var marker_cluster_860e8e8fa564c0473b5dc665db1dc537 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_860e8e8fa564c0473b5dc665db1dc537.addTo(map_1b0e79e71a86e94f809ae588d3ad0549);
#
#
#             var feature_group_sub_group_573812b9c55a70d28dcaf9c4ce30e6e0 = L.featureGroup.subGroup(
#                 marker_cluster_860e8e8fa564c0473b5dc665db1dc537
#             );
#
#
#             var marker_a59e0dd1c75763e2aa0c357be51ddeb8 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_573812b9c55a70d28dcaf9c4ce30e6e0);
#
#
#             var marker_6c3931ddbb6149b495a366c83c1e2eea = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_573812b9c55a70d28dcaf9c4ce30e6e0);
#
#
#             feature_group_sub_group_573812b9c55a70d28dcaf9c4ce30e6e0.addTo(map_1b0e79e71a86e94f809ae588d3ad0549);
#
#
#             var feature_group_sub_group_6787dd0a47a8f9d466fec8cfd8ced432 = L.featureGroup.subGroup(
#                 marker_cluster_860e8e8fa564c0473b5dc665db1dc537
#             );
#
#
#             var marker_2b15ac4aa4c5d4770f55c9dee06c39dd = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_6787dd0a47a8f9d466fec8cfd8ced432);
#
#
#             var marker_22893ce218e827b3a1df7006a622f1c1 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_6787dd0a47a8f9d466fec8cfd8ced432);
#
#
#             feature_group_sub_group_6787dd0a47a8f9d466fec8cfd8ced432.addTo(map_1b0e79e71a86e94f809ae588d3ad0549);
#
#
#             var layer_control_e2a785518bb975b344aa11150361b203_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_fe92a1471d0605ab6aed198a42e05e1e,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_573812b9c55a70d28dcaf9c4ce30e6e0,
#                     &quot;group2&quot; : feature_group_sub_group_6787dd0a47a8f9d466fec8cfd8ced432,
#                 },
#             };
#             let layer_control_e2a785518bb975b344aa11150361b203 = L.control.layers(
#                 layer_control_e2a785518bb975b344aa11150361b203_layers.base_layers,
#                 layer_control_e2a785518bb975b344aa11150361b203_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_1b0e79e71a86e94f809ae588d3ad0549);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
