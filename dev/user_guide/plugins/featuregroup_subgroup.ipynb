# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7880364d2f3ce7326f03bf13dd36ddfd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7880364d2f3ce7326f03bf13dd36ddfd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7880364d2f3ce7326f03bf13dd36ddfd = L.map(
#                 &quot;map_7880364d2f3ce7326f03bf13dd36ddfd&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1dbc0c6376d8b7418ca413fffd5468ff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1dbc0c6376d8b7418ca413fffd5468ff.addTo(map_7880364d2f3ce7326f03bf13dd36ddfd);
#
#
#             var feature_group_ac28bb378fb475c476bfd8c0b75a25d0 = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_ac28bb378fb475c476bfd8c0b75a25d0.addTo(map_7880364d2f3ce7326f03bf13dd36ddfd);
#
#
#             var feature_group_sub_group_23990e88ebc4af3048e321f1eeebab48 = L.featureGroup.subGroup(
#                 feature_group_ac28bb378fb475c476bfd8c0b75a25d0
#             );
#
#
#             var marker_9badeab1786f94e897dd5de95c15a434 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_23990e88ebc4af3048e321f1eeebab48);
#
#
#             var marker_cf4f8533b2988110b5d201d38111d7c9 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_23990e88ebc4af3048e321f1eeebab48);
#
#
#             feature_group_sub_group_23990e88ebc4af3048e321f1eeebab48.addTo(map_7880364d2f3ce7326f03bf13dd36ddfd);
#
#
#             var feature_group_sub_group_6a3defe16fd4ee640d0958e4fb786ee2 = L.featureGroup.subGroup(
#                 feature_group_ac28bb378fb475c476bfd8c0b75a25d0
#             );
#
#
#             var marker_ab987e1245480efa9853633cc0c33de6 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_6a3defe16fd4ee640d0958e4fb786ee2);
#
#
#             var marker_907b65bf9eec1c925deeef9a1908e7a0 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_6a3defe16fd4ee640d0958e4fb786ee2);
#
#
#             feature_group_sub_group_6a3defe16fd4ee640d0958e4fb786ee2.addTo(map_7880364d2f3ce7326f03bf13dd36ddfd);
#
#
#             var layer_control_416d1ecee22ad8dd9e986893dd2b4805_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_1dbc0c6376d8b7418ca413fffd5468ff,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_ac28bb378fb475c476bfd8c0b75a25d0,
#                     &quot;group1&quot; : feature_group_sub_group_23990e88ebc4af3048e321f1eeebab48,
#                     &quot;group2&quot; : feature_group_sub_group_6a3defe16fd4ee640d0958e4fb786ee2,
#                 },
#             };
#             let layer_control_416d1ecee22ad8dd9e986893dd2b4805 = L.control.layers(
#                 layer_control_416d1ecee22ad8dd9e986893dd2b4805_layers.base_layers,
#                 layer_control_416d1ecee22ad8dd9e986893dd2b4805_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_7880364d2f3ce7326f03bf13dd36ddfd);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2bb2a153160f05843cd4b51f10c5762 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2bb2a153160f05843cd4b51f10c5762&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2bb2a153160f05843cd4b51f10c5762 = L.map(
#                 &quot;map_c2bb2a153160f05843cd4b51f10c5762&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_076f6821b9cc14a28366a254a5976be3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_076f6821b9cc14a28366a254a5976be3.addTo(map_c2bb2a153160f05843cd4b51f10c5762);
#
#
#             var marker_cluster_8ee3fbc265bdcd864a8ce9d6da16dafd = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_8ee3fbc265bdcd864a8ce9d6da16dafd.addTo(map_c2bb2a153160f05843cd4b51f10c5762);
#
#
#             var feature_group_sub_group_a61acb84f79fb1bb1c8cbca8e817dece = L.featureGroup.subGroup(
#                 marker_cluster_8ee3fbc265bdcd864a8ce9d6da16dafd
#             );
#
#
#             var marker_8d815b2e8d582ec1bd6d8c793333ddb6 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_a61acb84f79fb1bb1c8cbca8e817dece);
#
#
#             var marker_66da906ed912907794e29fa833e19e22 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_a61acb84f79fb1bb1c8cbca8e817dece);
#
#
#             feature_group_sub_group_a61acb84f79fb1bb1c8cbca8e817dece.addTo(map_c2bb2a153160f05843cd4b51f10c5762);
#
#
#             var feature_group_sub_group_28c18edb856860adf28dc3ca5b2fa7ab = L.featureGroup.subGroup(
#                 marker_cluster_8ee3fbc265bdcd864a8ce9d6da16dafd
#             );
#
#
#             var marker_db3ba16877629cce5a5244779291e7a9 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_28c18edb856860adf28dc3ca5b2fa7ab);
#
#
#             var marker_fd970b42163d50841ef78ac812ef783b = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_28c18edb856860adf28dc3ca5b2fa7ab);
#
#
#             feature_group_sub_group_28c18edb856860adf28dc3ca5b2fa7ab.addTo(map_c2bb2a153160f05843cd4b51f10c5762);
#
#
#             var layer_control_34845849fe0aca6d8e5b25a5dd2d473b_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_076f6821b9cc14a28366a254a5976be3,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_a61acb84f79fb1bb1c8cbca8e817dece,
#                     &quot;group2&quot; : feature_group_sub_group_28c18edb856860adf28dc3ca5b2fa7ab,
#                 },
#             };
#             let layer_control_34845849fe0aca6d8e5b25a5dd2d473b = L.control.layers(
#                 layer_control_34845849fe0aca6d8e5b25a5dd2d473b_layers.base_layers,
#                 layer_control_34845849fe0aca6d8e5b25a5dd2d473b_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_c2bb2a153160f05843cd4b51f10c5762);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
