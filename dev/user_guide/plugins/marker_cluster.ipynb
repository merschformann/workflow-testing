# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93747ac2874b5df7bb0078a292329ddb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93747ac2874b5df7bb0078a292329ddb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93747ac2874b5df7bb0078a292329ddb = L.map(
#                 &quot;map_93747ac2874b5df7bb0078a292329ddb&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e811b354c145bd3d27e4bd1c54995ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8e811b354c145bd3d27e4bd1c54995ca.addTo(map_93747ac2874b5df7bb0078a292329ddb);
#
#
#             var marker_cluster_6f3e06fd0770e2a18715ce43f87f2cf4 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_28725ac7709832269ff1a2b1cd6cfe52 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_6f3e06fd0770e2a18715ce43f87f2cf4);
#
#
#             var icon_f0affc2318448ee4ef6382bb86f6986d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_28725ac7709832269ff1a2b1cd6cfe52.setIcon(icon_f0affc2318448ee4ef6382bb86f6986d);
#
#
#         var popup_91d832e35857590a035c31468698ac10 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8fbf596299cbf0a38b4e2b738bfddc7 = $(`&lt;div id=&quot;html_a8fbf596299cbf0a38b4e2b738bfddc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_91d832e35857590a035c31468698ac10.setContent(html_a8fbf596299cbf0a38b4e2b738bfddc7);
#
#
#
#         marker_28725ac7709832269ff1a2b1cd6cfe52.bindPopup(popup_91d832e35857590a035c31468698ac10)
#         ;
#
#
#
#
#             var marker_13e35313c9069bbeb647683eaeb3af8b = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_6f3e06fd0770e2a18715ce43f87f2cf4);
#
#
#             var icon_44942c9707d12589ff34921cecadde0d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_13e35313c9069bbeb647683eaeb3af8b.setIcon(icon_44942c9707d12589ff34921cecadde0d);
#
#
#         var popup_bb364ad076a961da3ffcf3837ffcf9d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5e1707ededac9f60b6b14c6c87a7a1f9 = $(`&lt;div id=&quot;html_5e1707ededac9f60b6b14c6c87a7a1f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_bb364ad076a961da3ffcf3837ffcf9d4.setContent(html_5e1707ededac9f60b6b14c6c87a7a1f9);
#
#
#
#         marker_13e35313c9069bbeb647683eaeb3af8b.bindPopup(popup_bb364ad076a961da3ffcf3837ffcf9d4)
#         ;
#
#
#
#
#             var marker_cc2c70edcae46d0b014187371b306a9a = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_6f3e06fd0770e2a18715ce43f87f2cf4);
#
#
#         var popup_ae5a19934f1c7ccae655c7b6762f1e5d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb1a884a3e25436d3d24c3c7fbf09eb0 = $(`&lt;div id=&quot;html_fb1a884a3e25436d3d24c3c7fbf09eb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_ae5a19934f1c7ccae655c7b6762f1e5d.setContent(html_fb1a884a3e25436d3d24c3c7fbf09eb0);
#
#
#
#         marker_cc2c70edcae46d0b014187371b306a9a.bindPopup(popup_ae5a19934f1c7ccae655c7b6762f1e5d)
#         ;
#
#
#
#
#             marker_cluster_6f3e06fd0770e2a18715ce43f87f2cf4.addTo(map_93747ac2874b5df7bb0078a292329ddb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6a5e6bbfc96b87b86ffff35f4eaf118 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6a5e6bbfc96b87b86ffff35f4eaf118&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6a5e6bbfc96b87b86ffff35f4eaf118 = L.map(
#                 &quot;map_b6a5e6bbfc96b87b86ffff35f4eaf118&quot;,
#                 {
#                     center: [0.54, -8.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e19d3c82b7a5b7b194a8b2f981fe395f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e19d3c82b7a5b7b194a8b2f981fe395f.addTo(map_b6a5e6bbfc96b87b86ffff35f4eaf118);
#
#
#             var marker_cluster_cff4e3a244af18dcaed45d07641787f3 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_cff4e3a244af18dcaed45d07641787f3.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_6bcdf3e55ae89d0cb81b988079927928 = L.marker(
#                 [59.0, -85.0],
#                 {}
#             ).addTo(marker_cluster_cff4e3a244af18dcaed45d07641787f3);
#
#
#         var popup_4b358469a72bed78dd82d307a99ac590 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d63e298c79534266750c1633ecc2c20e = $(`&lt;div id=&quot;html_d63e298c79534266750c1633ecc2c20e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-85&lt;br&gt;lat:59&lt;/div&gt;`)[0];
#                 popup_4b358469a72bed78dd82d307a99ac590.setContent(html_d63e298c79534266750c1633ecc2c20e);
#
#
#
#         marker_6bcdf3e55ae89d0cb81b988079927928.bindPopup(popup_4b358469a72bed78dd82d307a99ac590)
#         ;
#
#
#
#
#             var marker_5f852795700b53673b87a551e18200b8 = L.marker(
#                 [82.0, -104.0],
#                 {}
#             ).addTo(marker_cluster_cff4e3a244af18dcaed45d07641787f3);
#
#
#         var popup_fd4a27543aa88ba13b1a7c92c62ecb90 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db84cc218b81f24065a8d2cb2e3f2375 = $(`&lt;div id=&quot;html_db84cc218b81f24065a8d2cb2e3f2375&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-104&lt;br&gt;lat:82&lt;/div&gt;`)[0];
#                 popup_fd4a27543aa88ba13b1a7c92c62ecb90.setContent(html_db84cc218b81f24065a8d2cb2e3f2375);
#
#
#
#         marker_5f852795700b53673b87a551e18200b8.bindPopup(popup_fd4a27543aa88ba13b1a7c92c62ecb90)
#         ;
#
#
#
#
#             var marker_c624f5fcd076a29c94bcecdce8e7e4db = L.marker(
#                 [-64.0, -48.0],
#                 {}
#             ).addTo(marker_cluster_cff4e3a244af18dcaed45d07641787f3);
#
#
#         var popup_9744f1324c022ddee15ddea223460107 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_931243ae8e1575747613e877ee6a5598 = $(`&lt;div id=&quot;html_931243ae8e1575747613e877ee6a5598&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-48&lt;br&gt;lat:-64&lt;/div&gt;`)[0];
#                 popup_9744f1324c022ddee15ddea223460107.setContent(html_931243ae8e1575747613e877ee6a5598);
#
#
#
#         marker_c624f5fcd076a29c94bcecdce8e7e4db.bindPopup(popup_9744f1324c022ddee15ddea223460107)
#         ;
#
#
#
#
#             var marker_f88ffe65d9fbd1911d03315be6a5ab9c = L.marker(
#                 [-41.0, 102.0],
#                 {}
#             ).addTo(marker_cluster_cff4e3a244af18dcaed45d07641787f3);
#
#
#         var popup_2e4943f817851aec58545849d127cc8f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0b5bf0b6772a2717dda3c7925d6b7919 = $(`&lt;div id=&quot;html_0b5bf0b6772a2717dda3c7925d6b7919&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:102&lt;br&gt;lat:-41&lt;/div&gt;`)[0];
#                 popup_2e4943f817851aec58545849d127cc8f.setContent(html_0b5bf0b6772a2717dda3c7925d6b7919);
#
#
#
#         marker_f88ffe65d9fbd

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8657a4dfc072612f9c37388bfbe4f39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8657a4dfc072612f9c37388bfbe4f39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8657a4dfc072612f9c37388bfbe4f39 = L.map(
#                 &quot;map_b8657a4dfc072612f9c37388bfbe4f39&quot;,
#                 {
#                     center: [0.54, -8.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c59af6206d110e969ac1fdb256cb8e19 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c59af6206d110e969ac1fdb256cb8e19.addTo(map_b8657a4dfc072612f9c37388bfbe4f39);
#
#
#             var marker_cluster_1e3d0065c087c8d7b80675cb556fef0f = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_b5a3f063e50733e504040c4f39d91396 = L.marker(
#                 [59.0, -85.0],
#                 {}
#             ).addTo(marker_cluster_1e3d0065c087c8d7b80675cb556fef0f);
#
#
#         var popup_ec2f7e6ae35950d9fbf83f747c2b1075 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3ce6b6cc89029248d8db734378b3fc8f = $(`&lt;div id=&quot;html_3ce6b6cc89029248d8db734378b3fc8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-85&lt;br&gt;lat:59&lt;/div&gt;`)[0];
#                 popup_ec2f7e6ae35950d9fbf83f747c2b1075.setContent(html_3ce6b6cc89029248d8db734378b3fc8f);
#
#
#
#         marker_b5a3f063e50733e504040c4f39d91396.bindPopup(popup_ec2f7e6ae35950d9fbf83f747c2b1075)
#         ;
#
#
#
#
#             var marker_24990b0c6bfe56a16f1f58c215103a20 = L.marker(
#                 [82.0, -104.0],
#                 {}
#             ).addTo(marker_cluster_1e3d0065c087c8d7b80675cb556fef0f);
#
#
#         var popup_992ace297a9ae806b5baeff755bd1320 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d8552daa007724f589dc4288cabb109b = $(`&lt;div id=&quot;html_d8552daa007724f589dc4288cabb109b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-104&lt;br&gt;lat:82&lt;/div&gt;`)[0];
#                 popup_992ace297a9ae806b5baeff755bd1320.setContent(html_d8552daa007724f589dc4288cabb109b);
#
#
#
#         marker_24990b0c6bfe56a16f1f58c215103a20.bindPopup(popup_992ace297a9ae806b5baeff755bd1320)
#         ;
#
#
#
#
#             var marker_a3f71a7e456ba7452df7b1b86850a092 = L.marker(
#                 [-64.0, -48.0],
#                 {}
#             ).addTo(marker_cluster_1e3d0065c087c8d7b80675cb556fef0f);
#
#
#         var popup_e3aeed55770f5cf0fb621bee62c916ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dce2bf9af6534861bdf266a340a98698 = $(`&lt;div id=&quot;html_dce2bf9af6534861bdf266a340a98698&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-48&lt;br&gt;lat:-64&lt;/div&gt;`)[0];
#                 popup_e3aeed55770f5cf0fb621bee62c916ae.setContent(html_dce2bf9af6534861bdf266a340a98698);
#
#
#
#         marker_a3f71a7e456ba7452df7b1b86850a092.bindPopup(popup_e3aeed55770f5cf0fb621bee62c916ae)
#         ;
#
#
#
#
#             var marker_a85c68a6690dc99db918c553e91de689 = L.marker(
#                 [-41.0, 102.0],
#                 {}
#             ).addTo(marker_cluster_1e3d0065c087c8d7b80675cb556fef0f);
#
#
#         var popup_8b91dde4e128898fc7d6adf11a63142a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a0ddcb8f10b52df931d874ae3e1ecd46 = $(`&lt;div id=&quot;html_a0ddcb8f10b52df931d874ae3e1ecd46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:102&lt;br&gt;lat:-41&lt;/div&gt;`)[0];
#                 popup_8b91dde4e128898fc7d6adf11a63142a.setContent(html_a0ddcb8f10b52df931d874ae3e1ecd46);
#
#
#
#         marker_a85c68a6690dc99db918c553e91de689.bindPopup(popup_8b91dde4e128898fc7d6adf11a63142a)
#         ;
#
#
#
#
#             var marker_7ff58d24289058bb5cf0253e03abf190 = L.marker(
#                 [-81.0, -18.0],
#                 {}
#             ).addTo(marker_cluster_1e3d0065c087c8d7b80675cb556fef0f);
#
#
#         var popup_5f77bf2299bf2f216814

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c03398216e95c9cfffe0ebbe9a4cdb6b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c03398216e95c9cfffe0ebbe9a4cdb6b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c03398216e95c9cfffe0ebbe9a4cdb6b = L.map(
#                 &quot;map_c03398216e95c9cfffe0ebbe9a4cdb6b&quot;,
#                 {
#                     center: [0.54, -8.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b85cd7464c8883aff6e45205060abca4 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b85cd7464c8883aff6e45205060abca4.addTo(map_c03398216e95c9cfffe0ebbe9a4cdb6b);
#
#
#             var fast_marker_cluster_34fb25d285923458864449c86b893b9d = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[59.0, -85.0], [82.0, -104.0], [-64.0, -48.0], [-41.0, 102.0], [-81.0, -18.0], [-35.0, -40.0], [64.0, -9.0], [48.0, 106.0], [-67.0, 132.0], [33.0, -86.0], [73.0, -132.0], [-14.0, 174.0], [39.0, -71.0], [-53.0, 67.0], [-40.0, -44.0], [25.0, -110.0], [-70.0, -11.0], [60.0, 92.0], [38.0, 60.0], [57.0, -30.0], [47.0, -89.0], [23.0, -158.0], [85.0, 81.0], [-41.0, 44.0], [-87.0, -122.0], [-68.0, 171.0], [-80.0, 169.0], [-50.0, 44.0], [-19.0, 10.0], [-33.0, 172.0], [-28.0, 88.0], [8.0, -42.0], [42.0, 112.0], [-53.0, 64.0], [-39.0, -129.0], [30.0, -159.0], [20.0, 53.0], [70.0, -154.0], [-3.0, -77.0], [-6.0, 81.0], [-10.0, -143.0], [29.0, 108.0], [77.0, -31.0], [25.0, 24.0], [-10.0, 14.0], [33.0, -162.0], [-27.0, -157.0], [87.0, 147.0], [16.0, 9.0], [27.0, -16.0], [3.0, 1.0], [29.0, 92.0], [26.0, -123.0], [-1.0, 62.0], [-23.0, 114.0], [71.0, -129.0], [13.0, -177.0], [-38.0, 61.0], [10.0, 138.0], [-21.0, 176.0], [82.0, 5.0], [59.0, 79.0], [-37.0, 26.0], [-8.0, 23.0], [11.0, -83.0], [-69.0, 111.0], [35.0, 7.0], [-79.0, 15.0], [-58.0, -142.0], [89.0, -148.0], [-40.0, 26.0], [-51.0, 43.0], [-79.0, 158.0], [-29.0, -87.0], [-42.0, 126.0], [-6.0, -73.0], [-54.0, 60.0], [48.0, 139.0], [87.0, -94.0], [-36.0, 162.0], [-13.0, -17.0], [-17.0, -45.0], [-49.0, 140.0], [-55.0, -77.0], [45.0, -166.0], [-84.0, 43.0], [21.0, -167.0], [70.0, -57.0], [-66.0, -127.0], [-27.0, -168.0], [-51.0, 27.0], [33.0, -153.0], [-11.0, 93.0], [71.0, 46.0], [9.0, -172.0], [16.0, -176.0], [19.0, -140.0], [7.0, -96.0], [-23.0, -9.0], [89.0, -81.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_c03398216e95c9cfffe0ebbe9a4cdb6b);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_34fb25d285923458864449c86b893b9d.addTo(map_c03398216e95c9cfffe0ebbe9a4cdb6b);
#
#
#             var layer_control_ea0600c5466d55aef679c3f3dbb4bd7c_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_b85cd7464c8883aff6e45205060abca4,
#                 },
#                 overlays :  {
#                     &quot;macro_element_34fb25d285923458864449c86b893b9d&quot; : fast_marker_cluster_34fb25d285923458864449c86b893b9d,
#                 },
#             };
#             let layer_control_ea0600c5466d55aef679c3f3dbb4bd7c = L.control.layers(
#                 layer_control_ea0600c5466d55aef679c3f3dbb4bd7c_layers.base_layers,
#                 layer_control_ea0600c5466d55aef679c3f3dbb4bd7c_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_c03398216e95c9cfffe0ebbe9a4cdb6b);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2775ff0a929b1a17e61fa6d091ee7d47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2775ff0a929b1a17e61fa6d091ee7d47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2775ff0a929b1a17e61fa6d091ee7d47 = L.map(
#                 &quot;map_2775ff0a929b1a17e61fa6d091ee7d47&quot;,
#                 {
#                     center: [0.54, -8.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2626dbbd788b8fe5c60f1739a21e0762 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2626dbbd788b8fe5c60f1739a21e0762.addTo(map_2775ff0a929b1a17e61fa6d091ee7d47);
#
#
#             var fast_marker_cluster_2ce809ceb8c19ee89808a13c6fa7b1f2 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[59.0, -85.0], [82.0, -104.0], [-64.0, -48.0], [-41.0, 102.0], [-81.0, -18.0], [-35.0, -40.0], [64.0, -9.0], [48.0, 106.0], [-67.0, 132.0], [33.0, -86.0], [73.0, -132.0], [-14.0, 174.0], [39.0, -71.0], [-53.0, 67.0], [-40.0, -44.0], [25.0, -110.0], [-70.0, -11.0], [60.0, 92.0], [38.0, 60.0], [57.0, -30.0], [47.0, -89.0], [23.0, -158.0], [85.0, 81.0], [-41.0, 44.0], [-87.0, -122.0], [-68.0, 171.0], [-80.0, 169.0], [-50.0, 44.0], [-19.0, 10.0], [-33.0, 172.0], [-28.0, 88.0], [8.0, -42.0], [42.0, 112.0], [-53.0, 64.0], [-39.0, -129.0], [30.0, -159.0], [20.0, 53.0], [70.0, -154.0], [-3.0, -77.0], [-6.0, 81.0], [-10.0, -143.0], [29.0, 108.0], [77.0, -31.0], [25.0, 24.0], [-10.0, 14.0], [33.0, -162.0], [-27.0, -157.0], [87.0, 147.0], [16.0, 9.0], [27.0, -16.0], [3.0, 1.0], [29.0, 92.0], [26.0, -123.0], [-1.0, 62.0], [-23.0, 114.0], [71.0, -129.0], [13.0, -177.0], [-38.0, 61.0], [10.0, 138.0], [-21.0, 176.0], [82.0, 5.0], [59.0, 79.0], [-37.0, 26.0], [-8.0, 23.0], [11.0, -83.0], [-69.0, 111.0], [35.0, 7.0], [-79.0, 15.0], [-58.0, -142.0], [89.0, -148.0], [-40.0, 26.0], [-51.0, 43.0], [-79.0, 158.0], [-29.0, -87.0], [-42.0, 126.0], [-6.0, -73.0], [-54.0, 60.0], [48.0, 139.0], [87.0, -94.0], [-36.0, 162.0], [-13.0, -17.0], [-17.0, -45.0], [-49.0, 140.0], [-55.0, -77.0], [45.0, -166.0], [-84.0, 43.0], [21.0, -167.0], [70.0, -57.0], [-66.0, -127.0], [-27.0, -168.0], [-51.0, 27.0], [33.0, -153.0], [-11.0, 93.0], [71.0, 46.0], [9.0, -172.0], [16.0, -176.0], [19.0, -140.0], [7.0, -96.0], [-23.0, -9.0], [89.0, -81.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_2775ff0a929b1a17e61fa6d091ee7d47);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_2ce809ceb8c19ee89808a13c6fa7b1f2.addTo(map_2775ff0a929b1a17e61fa6d091ee7d47);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
