# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b75673d72565c2688c785744ca551058 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b75673d72565c2688c785744ca551058&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b75673d72565c2688c785744ca551058 = L.map(
#                 &quot;map_b75673d72565c2688c785744ca551058&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_228034d273577fc79b0a5cfb5b094699 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_228034d273577fc79b0a5cfb5b094699.addTo(map_b75673d72565c2688c785744ca551058);
#
#
#             var marker_cluster_9a322627f4ca4ad1489b28d5de002455 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_a59de9fd09bf6d12d81671e40da4ee17 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_9a322627f4ca4ad1489b28d5de002455);
#
#
#             var icon_9de35e1fcd3725e1f0f6c9239668f9b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a59de9fd09bf6d12d81671e40da4ee17.setIcon(icon_9de35e1fcd3725e1f0f6c9239668f9b7);
#
#
#         var popup_701f29b9889468fff873d19ecbb015c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d1b4142244184ea46bc6d0eef229a054 = $(`&lt;div id=&quot;html_d1b4142244184ea46bc6d0eef229a054&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_701f29b9889468fff873d19ecbb015c2.setContent(html_d1b4142244184ea46bc6d0eef229a054);
#
#
#
#         marker_a59de9fd09bf6d12d81671e40da4ee17.bindPopup(popup_701f29b9889468fff873d19ecbb015c2)
#         ;
#
#
#
#
#             var marker_3ad89430898efb3d8c0a9fb051a9cffa = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_9a322627f4ca4ad1489b28d5de002455);
#
#
#             var icon_7fff5c4ddf2c8dc230926098c9d9b219 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3ad89430898efb3d8c0a9fb051a9cffa.setIcon(icon_7fff5c4ddf2c8dc230926098c9d9b219);
#
#
#         var popup_0480242a2b098fa5aae034d26c06f839 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3a1a6ed529d6bbc8041cb9615e05c877 = $(`&lt;div id=&quot;html_3a1a6ed529d6bbc8041cb9615e05c877&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_0480242a2b098fa5aae034d26c06f839.setContent(html_3a1a6ed529d6bbc8041cb9615e05c877);
#
#
#
#         marker_3ad89430898efb3d8c0a9fb051a9cffa.bindPopup(popup_0480242a2b098fa5aae034d26c06f839)
#         ;
#
#
#
#
#             var marker_4c72193afd5c175b8f38b030abf318c2 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_9a322627f4ca4ad1489b28d5de002455);
#
#
#         var popup_c8b2100d6a846ac7ec9afc444c488137 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f13bcf89d5dc6b197a15edbd2364f3dd = $(`&lt;div id=&quot;html_f13bcf89d5dc6b197a15edbd2364f3dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_c8b2100d6a846ac7ec9afc444c488137.setContent(html_f13bcf89d5dc6b197a15edbd2364f3dd);
#
#
#
#         marker_4c72193afd5c175b8f38b030abf318c2.bindPopup(popup_c8b2100d6a846ac7ec9afc444c488137)
#         ;
#
#
#
#
#             marker_cluster_9a322627f4ca4ad1489b28d5de002455.addTo(map_b75673d72565c2688c785744ca551058);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_213207cc25d1ef710423380e61d076cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_213207cc25d1ef710423380e61d076cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_213207cc25d1ef710423380e61d076cb = L.map(
#                 &quot;map_213207cc25d1ef710423380e61d076cb&quot;,
#                 {
#                     center: [0.1, -0.34],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8389c0d73945de025c7d5e7a6b27a815 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8389c0d73945de025c7d5e7a6b27a815.addTo(map_213207cc25d1ef710423380e61d076cb);
#
#
#             var marker_cluster_b3ea9f3d98ed7f8edf7b43e4e63b3b1e = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_b3ea9f3d98ed7f8edf7b43e4e63b3b1e.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_1f31e87a9765e3571750a73a4927f5ee = L.marker(
#                 [21.0, 143.0],
#                 {}
#             ).addTo(marker_cluster_b3ea9f3d98ed7f8edf7b43e4e63b3b1e);
#
#
#         var popup_f3ff1becc3627dc64557829d81f68f8b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d7b14ff1ba11c2a163d75af35aee0de = $(`&lt;div id=&quot;html_6d7b14ff1ba11c2a163d75af35aee0de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:143&lt;br&gt;lat:21&lt;/div&gt;`)[0];
#                 popup_f3ff1becc3627dc64557829d81f68f8b.setContent(html_6d7b14ff1ba11c2a163d75af35aee0de);
#
#
#
#         marker_1f31e87a9765e3571750a73a4927f5ee.bindPopup(popup_f3ff1becc3627dc64557829d81f68f8b)
#         ;
#
#
#
#
#             var marker_65c95fc89673005479299f6420426db4 = L.marker(
#                 [-78.0, 74.0],
#                 {}
#             ).addTo(marker_cluster_b3ea9f3d98ed7f8edf7b43e4e63b3b1e);
#
#
#         var popup_ce51a622d283b5d0e305a58df6e8306b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26b93458125e18c87b215f85d8b97ec9 = $(`&lt;div id=&quot;html_26b93458125e18c87b215f85d8b97ec9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:74&lt;br&gt;lat:-78&lt;/div&gt;`)[0];
#                 popup_ce51a622d283b5d0e305a58df6e8306b.setContent(html_26b93458125e18c87b215f85d8b97ec9);
#
#
#
#         marker_65c95fc89673005479299f6420426db4.bindPopup(popup_ce51a622d283b5d0e305a58df6e8306b)
#         ;
#
#
#
#
#             var marker_af7ad45a3e035aab15895bd66862a61d = L.marker(
#                 [78.0, 35.0],
#                 {}
#             ).addTo(marker_cluster_b3ea9f3d98ed7f8edf7b43e4e63b3b1e);
#
#
#         var popup_968a87984a6fb9389a40209e5032a79d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ffdbbb9b2c5a9b16211a5ae734c3464d = $(`&lt;div id=&quot;html_ffdbbb9b2c5a9b16211a5ae734c3464d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:35&lt;br&gt;lat:78&lt;/div&gt;`)[0];
#                 popup_968a87984a6fb9389a40209e5032a79d.setContent(html_ffdbbb9b2c5a9b16211a5ae734c3464d);
#
#
#
#         marker_af7ad45a3e035aab15895bd66862a61d.bindPopup(popup_968a87984a6fb9389a40209e5032a79d)
#         ;
#
#
#
#
#             var marker_6bbff09e3c11f57d70423c4ae1491eec = L.marker(
#                 [-82.0, 79.0],
#                 {}
#             ).addTo(marker_cluster_b3ea9f3d98ed7f8edf7b43e4e63b3b1e);
#
#
#         var popup_81d393ae9de9164fc96e8c31a7fce791 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b0b55e75c6d513113a845cffdf1d3a6 = $(`&lt;div id=&quot;html_8b0b55e75c6d513113a845cffdf1d3a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:79&lt;br&gt;lat:-82&lt;/div&gt;`)[0];
#                 popup_81d393ae9de9164fc96e8c31a7fce791.setContent(html_8b0b55e75c6d513113a845cffdf1d3a6);
#
#
#
#         marker_6bbff09e3c11f57d70423c

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b890e8099180e26c460bf3a8d185c788 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b890e8099180e26c460bf3a8d185c788&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b890e8099180e26c460bf3a8d185c788 = L.map(
#                 &quot;map_b890e8099180e26c460bf3a8d185c788&quot;,
#                 {
#                     center: [0.1, -0.34],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1565c044a461282377321a94de5a3c48 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1565c044a461282377321a94de5a3c48.addTo(map_b890e8099180e26c460bf3a8d185c788);
#
#
#             var marker_cluster_fe61363a2513f4d39412fb45aa60ee0d = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_7d327ca498c3bcbe2625261f03b9a121 = L.marker(
#                 [21.0, 143.0],
#                 {}
#             ).addTo(marker_cluster_fe61363a2513f4d39412fb45aa60ee0d);
#
#
#         var popup_d8ab896fbd624e5ebfd3a346ea96fd1e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f62508f0f8977b6f4190bbd7ffb4cc92 = $(`&lt;div id=&quot;html_f62508f0f8977b6f4190bbd7ffb4cc92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:143&lt;br&gt;lat:21&lt;/div&gt;`)[0];
#                 popup_d8ab896fbd624e5ebfd3a346ea96fd1e.setContent(html_f62508f0f8977b6f4190bbd7ffb4cc92);
#
#
#
#         marker_7d327ca498c3bcbe2625261f03b9a121.bindPopup(popup_d8ab896fbd624e5ebfd3a346ea96fd1e)
#         ;
#
#
#
#
#             var marker_48998f216fa45c9dbf5cbd5bec0ca6dc = L.marker(
#                 [-78.0, 74.0],
#                 {}
#             ).addTo(marker_cluster_fe61363a2513f4d39412fb45aa60ee0d);
#
#
#         var popup_67323305139e0f852f4211946840247f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6ad75e532b05980e702df3a1da4a20fa = $(`&lt;div id=&quot;html_6ad75e532b05980e702df3a1da4a20fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:74&lt;br&gt;lat:-78&lt;/div&gt;`)[0];
#                 popup_67323305139e0f852f4211946840247f.setContent(html_6ad75e532b05980e702df3a1da4a20fa);
#
#
#
#         marker_48998f216fa45c9dbf5cbd5bec0ca6dc.bindPopup(popup_67323305139e0f852f4211946840247f)
#         ;
#
#
#
#
#             var marker_3c8ca2c16eccc7ce651008c8b3d4aebb = L.marker(
#                 [78.0, 35.0],
#                 {}
#             ).addTo(marker_cluster_fe61363a2513f4d39412fb45aa60ee0d);
#
#
#         var popup_cac2ab9a9a7f5cde4c5bcd579afa619c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1cc14ec18c4605dd7868e8b91974ebc8 = $(`&lt;div id=&quot;html_1cc14ec18c4605dd7868e8b91974ebc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:35&lt;br&gt;lat:78&lt;/div&gt;`)[0];
#                 popup_cac2ab9a9a7f5cde4c5bcd579afa619c.setContent(html_1cc14ec18c4605dd7868e8b91974ebc8);
#
#
#
#         marker_3c8ca2c16eccc7ce651008c8b3d4aebb.bindPopup(popup_cac2ab9a9a7f5cde4c5bcd579afa619c)
#         ;
#
#
#
#
#             var marker_43cb4ec86f57bbf0031b163b06b9af16 = L.marker(
#                 [-82.0, 79.0],
#                 {}
#             ).addTo(marker_cluster_fe61363a2513f4d39412fb45aa60ee0d);
#
#
#         var popup_4fda6aeb7cb624fd34e690a324551907 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_de2980a96df94b814e2b7b2882eb9849 = $(`&lt;div id=&quot;html_de2980a96df94b814e2b7b2882eb9849&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:79&lt;br&gt;lat:-82&lt;/div&gt;`)[0];
#                 popup_4fda6aeb7cb624fd34e690a324551907.setContent(html_de2980a96df94b814e2b7b2882eb9849);
#
#
#
#         marker_43cb4ec86f57bbf0031b163b06b9af16.bindPopup(popup_4fda6aeb7cb624fd34e690a324551907)
#         ;
#
#
#
#
#             var marker_41d61336ca855958d9360b22960343aa = L.marker(
#                 [37.0, -78.0],
#                 {}
#             ).addTo(marker_cluster_fe61363a2513f4d39412fb45aa60ee0d);
#
#
#         var popup_9ae093ae05c3f5bd7620c0b2c93f72

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e8d3b57c4d81c45ee2536122832fb276 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e8d3b57c4d81c45ee2536122832fb276&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e8d3b57c4d81c45ee2536122832fb276 = L.map(
#                 &quot;map_e8d3b57c4d81c45ee2536122832fb276&quot;,
#                 {
#                     center: [0.1, -0.34],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f94358c9c5b901b8e24ee092a5688ed = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6f94358c9c5b901b8e24ee092a5688ed.addTo(map_e8d3b57c4d81c45ee2536122832fb276);
#
#
#             var fast_marker_cluster_955466ff69eb288bc779ac341436e563 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[21.0, 143.0], [-78.0, 74.0], [78.0, 35.0], [-82.0, 79.0], [37.0, -78.0], [-36.0, -165.0], [-84.0, 153.0], [-37.0, 70.0], [29.0, 111.0], [61.0, 158.0], [43.0, 82.0], [-45.0, 11.0], [39.0, 96.0], [26.0, -81.0], [28.0, -178.0], [-43.0, -81.0], [37.0, -94.0], [39.0, -10.0], [-66.0, -168.0], [-58.0, 114.0], [-39.0, 166.0], [37.0, -63.0], [0.0, 167.0], [-28.0, 3.0], [-33.0, 140.0], [-42.0, 118.0], [29.0, 119.0], [-22.0, -24.0], [-37.0, 77.0], [54.0, -106.0], [83.0, -38.0], [-54.0, -160.0], [-1.0, 24.0], [-38.0, -176.0], [-41.0, -143.0], [-50.0, 138.0], [5.0, 137.0], [62.0, -33.0], [-74.0, -4.0], [-2.0, 173.0], [23.0, -128.0], [-23.0, -171.0], [-79.0, -23.0], [81.0, -26.0], [-53.0, 21.0], [-36.0, -141.0], [-28.0, -9.0], [1.0, -167.0], [67.0, -160.0], [51.0, -13.0], [-63.0, -150.0], [83.0, -71.0], [25.0, -100.0], [8.0, -67.0], [51.0, 18.0], [-74.0, 102.0], [-68.0, -65.0], [11.0, 33.0], [-87.0, -41.0], [-24.0, -68.0], [63.0, -154.0], [12.0, -78.0], [70.0, -114.0], [48.0, -39.0], [-49.0, -84.0], [42.0, 103.0], [87.0, 10.0], [80.0, 171.0], [-85.0, -88.0], [67.0, 29.0], [-30.0, 64.0], [-60.0, 86.0], [35.0, 148.0], [-84.0, -134.0], [57.0, 153.0], [24.0, 82.0], [-63.0, 131.0], [54.0, 47.0], [-70.0, -178.0], [-26.0, 119.0], [30.0, 79.0], [79.0, 22.0], [35.0, 70.0], [-9.0, -119.0], [54.0, 167.0], [-42.0, 113.0], [-1.0, -151.0], [89.0, -139.0], [-29.0, -23.0], [-26.0, 130.0], [35.0, 55.0], [59.0, 17.0], [-7.0, -175.0], [13.0, 132.0], [34.0, -168.0], [-69.0, 2.0], [85.0, 34.0], [49.0, -43.0], [-82.0, 41.0], [-43.0, 88.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_e8d3b57c4d81c45ee2536122832fb276);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_955466ff69eb288bc779ac341436e563.addTo(map_e8d3b57c4d81c45ee2536122832fb276);
#
#
#             var layer_control_21aa939137e1f0769e3ceb02963bbb6e_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_6f94358c9c5b901b8e24ee092a5688ed,
#                 },
#                 overlays :  {
#                     &quot;macro_element_955466ff69eb288bc779ac341436e563&quot; : fast_marker_cluster_955466ff69eb288bc779ac341436e563,
#                 },
#             };
#             let layer_control_21aa939137e1f0769e3ceb02963bbb6e = L.control.layers(
#                 layer_control_21aa939137e1f0769e3ceb02963bbb6e_layers.base_layers,
#                 layer_control_21aa939137e1f0769e3ceb02963bbb6e_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_e8d3b57c4d81c45ee2536122832fb276);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_689e6671a2c7cc6760983fb1fa9d9e72 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_689e6671a2c7cc6760983fb1fa9d9e72&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_689e6671a2c7cc6760983fb1fa9d9e72 = L.map(
#                 &quot;map_689e6671a2c7cc6760983fb1fa9d9e72&quot;,
#                 {
#                     center: [0.1, -0.34],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56f80c729d3aabe3116a0db94a250531 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_56f80c729d3aabe3116a0db94a250531.addTo(map_689e6671a2c7cc6760983fb1fa9d9e72);
#
#
#             var fast_marker_cluster_6ea5bc853a615459c97cd6689e61f7dd = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[21.0, 143.0], [-78.0, 74.0], [78.0, 35.0], [-82.0, 79.0], [37.0, -78.0], [-36.0, -165.0], [-84.0, 153.0], [-37.0, 70.0], [29.0, 111.0], [61.0, 158.0], [43.0, 82.0], [-45.0, 11.0], [39.0, 96.0], [26.0, -81.0], [28.0, -178.0], [-43.0, -81.0], [37.0, -94.0], [39.0, -10.0], [-66.0, -168.0], [-58.0, 114.0], [-39.0, 166.0], [37.0, -63.0], [0.0, 167.0], [-28.0, 3.0], [-33.0, 140.0], [-42.0, 118.0], [29.0, 119.0], [-22.0, -24.0], [-37.0, 77.0], [54.0, -106.0], [83.0, -38.0], [-54.0, -160.0], [-1.0, 24.0], [-38.0, -176.0], [-41.0, -143.0], [-50.0, 138.0], [5.0, 137.0], [62.0, -33.0], [-74.0, -4.0], [-2.0, 173.0], [23.0, -128.0], [-23.0, -171.0], [-79.0, -23.0], [81.0, -26.0], [-53.0, 21.0], [-36.0, -141.0], [-28.0, -9.0], [1.0, -167.0], [67.0, -160.0], [51.0, -13.0], [-63.0, -150.0], [83.0, -71.0], [25.0, -100.0], [8.0, -67.0], [51.0, 18.0], [-74.0, 102.0], [-68.0, -65.0], [11.0, 33.0], [-87.0, -41.0], [-24.0, -68.0], [63.0, -154.0], [12.0, -78.0], [70.0, -114.0], [48.0, -39.0], [-49.0, -84.0], [42.0, 103.0], [87.0, 10.0], [80.0, 171.0], [-85.0, -88.0], [67.0, 29.0], [-30.0, 64.0], [-60.0, 86.0], [35.0, 148.0], [-84.0, -134.0], [57.0, 153.0], [24.0, 82.0], [-63.0, 131.0], [54.0, 47.0], [-70.0, -178.0], [-26.0, 119.0], [30.0, 79.0], [79.0, 22.0], [35.0, 70.0], [-9.0, -119.0], [54.0, 167.0], [-42.0, 113.0], [-1.0, -151.0], [89.0, -139.0], [-29.0, -23.0], [-26.0, 130.0], [35.0, 55.0], [59.0, 17.0], [-7.0, -175.0], [13.0, 132.0], [34.0, -168.0], [-69.0, 2.0], [85.0, 34.0], [49.0, -43.0], [-82.0, 41.0], [-43.0, 88.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_689e6671a2c7cc6760983fb1fa9d9e72);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_6ea5bc853a615459c97cd6689e61f7dd.addTo(map_689e6671a2c7cc6760983fb1fa9d9e72);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
