# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5e0aa7b6b82c492dbffdcd808496a0f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5e0aa7b6b82c492dbffdcd808496a0f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5e0aa7b6b82c492dbffdcd808496a0f = L.map(
#                 &quot;map_b5e0aa7b6b82c492dbffdcd808496a0f&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f4e7fa9f6958966b84a1c834bc0f4a8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0f4e7fa9f6958966b84a1c834bc0f4a8.addTo(map_b5e0aa7b6b82c492dbffdcd808496a0f);
#
#
#             var marker_cluster_5b9e4a48d6a38c25756bb61dfcb025de = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_5d03ceaffb635e13e8912411e569dbaa = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_5b9e4a48d6a38c25756bb61dfcb025de);
#
#
#             var icon_4f266540206527e0dc65c1e709b32268 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5d03ceaffb635e13e8912411e569dbaa.setIcon(icon_4f266540206527e0dc65c1e709b32268);
#
#
#         var popup_e924ea0d07d58dcf700f763328128622 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d7902b3396b89f956dad47da9a2e81c = $(`&lt;div id=&quot;html_8d7902b3396b89f956dad47da9a2e81c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_e924ea0d07d58dcf700f763328128622.setContent(html_8d7902b3396b89f956dad47da9a2e81c);
#
#
#
#         marker_5d03ceaffb635e13e8912411e569dbaa.bindPopup(popup_e924ea0d07d58dcf700f763328128622)
#         ;
#
#
#
#
#             var marker_d8c7ee7327531c86b16b59aad1d23af6 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_5b9e4a48d6a38c25756bb61dfcb025de);
#
#
#             var icon_b441e6202015d96ea0c299447839e514 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d8c7ee7327531c86b16b59aad1d23af6.setIcon(icon_b441e6202015d96ea0c299447839e514);
#
#
#         var popup_a06f2e32337c795318998ad153cb2d71 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_84cfb7d24622e240fbb7a223de1f2b5f = $(`&lt;div id=&quot;html_84cfb7d24622e240fbb7a223de1f2b5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_a06f2e32337c795318998ad153cb2d71.setContent(html_84cfb7d24622e240fbb7a223de1f2b5f);
#
#
#
#         marker_d8c7ee7327531c86b16b59aad1d23af6.bindPopup(popup_a06f2e32337c795318998ad153cb2d71)
#         ;
#
#
#
#
#             var marker_f6ea3a13aef6f11e434bcb372120e9f1 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_5b9e4a48d6a38c25756bb61dfcb025de);
#
#
#         var popup_265967a394572b8cf6dd83e64475311e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9f1cd7387e0059effa844ace8fdba849 = $(`&lt;div id=&quot;html_9f1cd7387e0059effa844ace8fdba849&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_265967a394572b8cf6dd83e64475311e.setContent(html_9f1cd7387e0059effa844ace8fdba849);
#
#
#
#         marker_f6ea3a13aef6f11e434bcb372120e9f1.bindPopup(popup_265967a394572b8cf6dd83e64475311e)
#         ;
#
#
#
#
#             marker_cluster_5b9e4a48d6a38c25756bb61dfcb025de.addTo(map_b5e0aa7b6b82c492dbffdcd808496a0f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b701e9e6b0e5b8424cb9ffc94bebb3a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b701e9e6b0e5b8424cb9ffc94bebb3a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b701e9e6b0e5b8424cb9ffc94bebb3a6 = L.map(
#                 &quot;map_b701e9e6b0e5b8424cb9ffc94bebb3a6&quot;,
#                 {
#                     center: [-11.81, -8.92],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bae00552e40dca4fac8e413a9d4438c6 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bae00552e40dca4fac8e413a9d4438c6.addTo(map_b701e9e6b0e5b8424cb9ffc94bebb3a6);
#
#
#             var marker_cluster_37a96bb331c6c351e0ea54572d0837c1 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_37a96bb331c6c351e0ea54572d0837c1.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_394cd19b765ae6347e097d7035f42756 = L.marker(
#                 [79.0, 178.0],
#                 {}
#             ).addTo(marker_cluster_37a96bb331c6c351e0ea54572d0837c1);
#
#
#         var popup_0f989814925460fc190cd44f2177d7fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a99bbe108b1f08a56c0ca71d09a17cea = $(`&lt;div id=&quot;html_a99bbe108b1f08a56c0ca71d09a17cea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:178&lt;br&gt;lat:79&lt;/div&gt;`)[0];
#                 popup_0f989814925460fc190cd44f2177d7fd.setContent(html_a99bbe108b1f08a56c0ca71d09a17cea);
#
#
#
#         marker_394cd19b765ae6347e097d7035f42756.bindPopup(popup_0f989814925460fc190cd44f2177d7fd)
#         ;
#
#
#
#
#             var marker_c368cd3088893e707bb662e57b671742 = L.marker(
#                 [-43.0, 107.0],
#                 {}
#             ).addTo(marker_cluster_37a96bb331c6c351e0ea54572d0837c1);
#
#
#         var popup_0f5a6f6ff65b2b4f92f241daa37241c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_96f8cd98265fffe11f64495a4eabe451 = $(`&lt;div id=&quot;html_96f8cd98265fffe11f64495a4eabe451&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:107&lt;br&gt;lat:-43&lt;/div&gt;`)[0];
#                 popup_0f5a6f6ff65b2b4f92f241daa37241c3.setContent(html_96f8cd98265fffe11f64495a4eabe451);
#
#
#
#         marker_c368cd3088893e707bb662e57b671742.bindPopup(popup_0f5a6f6ff65b2b4f92f241daa37241c3)
#         ;
#
#
#
#
#             var marker_9dd8546dd951151b3134e01f4826fba6 = L.marker(
#                 [-54.0, 63.0],
#                 {}
#             ).addTo(marker_cluster_37a96bb331c6c351e0ea54572d0837c1);
#
#
#         var popup_f2cee4dbcce2900f34fe5fdf0b197e8a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54443bb906bb81881bca407a1514321b = $(`&lt;div id=&quot;html_54443bb906bb81881bca407a1514321b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:63&lt;br&gt;lat:-54&lt;/div&gt;`)[0];
#                 popup_f2cee4dbcce2900f34fe5fdf0b197e8a.setContent(html_54443bb906bb81881bca407a1514321b);
#
#
#
#         marker_9dd8546dd951151b3134e01f4826fba6.bindPopup(popup_f2cee4dbcce2900f34fe5fdf0b197e8a)
#         ;
#
#
#
#
#             var marker_e54361440d2caae018a8091812782c26 = L.marker(
#                 [50.0, -54.0],
#                 {}
#             ).addTo(marker_cluster_37a96bb331c6c351e0ea54572d0837c1);
#
#
#         var popup_bf612cbc3e43556de4ec9faab27d172a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f78b13022cfeb54dad828fc0b3a3102 = $(`&lt;div id=&quot;html_0f78b13022cfeb54dad828fc0b3a3102&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-54&lt;br&gt;lat:50&lt;/div&gt;`)[0];
#                 popup_bf612cbc3e43556de4ec9faab27d172a.setContent(html_0f78b13022cfeb54dad828fc0b3a3102);
#
#
#
#         marker_e54361440d2caae

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3a58d4e5ac27620935563e9a104c0b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3a58d4e5ac27620935563e9a104c0b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3a58d4e5ac27620935563e9a104c0b4 = L.map(
#                 &quot;map_e3a58d4e5ac27620935563e9a104c0b4&quot;,
#                 {
#                     center: [-11.81, -8.92],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40561316010d199a78356eb372514d5b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_40561316010d199a78356eb372514d5b.addTo(map_e3a58d4e5ac27620935563e9a104c0b4);
#
#
#             var marker_cluster_6eb8a24c3c9e92e9d53b735aefa9eeb0 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_34e71102f63938181d9bccf84a575368 = L.marker(
#                 [79.0, 178.0],
#                 {}
#             ).addTo(marker_cluster_6eb8a24c3c9e92e9d53b735aefa9eeb0);
#
#
#         var popup_1eef40f79391e6e490fea5ccb6f8e9f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_89d9e50df846bd2e24fe63bdd6a6f4c3 = $(`&lt;div id=&quot;html_89d9e50df846bd2e24fe63bdd6a6f4c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:178&lt;br&gt;lat:79&lt;/div&gt;`)[0];
#                 popup_1eef40f79391e6e490fea5ccb6f8e9f9.setContent(html_89d9e50df846bd2e24fe63bdd6a6f4c3);
#
#
#
#         marker_34e71102f63938181d9bccf84a575368.bindPopup(popup_1eef40f79391e6e490fea5ccb6f8e9f9)
#         ;
#
#
#
#
#             var marker_bc2f05f45c9f7f12a8891ae3262eda01 = L.marker(
#                 [-43.0, 107.0],
#                 {}
#             ).addTo(marker_cluster_6eb8a24c3c9e92e9d53b735aefa9eeb0);
#
#
#         var popup_51a8f30d0d64ca154e8b29764569f3de = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e717ed5e7dc40dcd133e31b954d29a92 = $(`&lt;div id=&quot;html_e717ed5e7dc40dcd133e31b954d29a92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:107&lt;br&gt;lat:-43&lt;/div&gt;`)[0];
#                 popup_51a8f30d0d64ca154e8b29764569f3de.setContent(html_e717ed5e7dc40dcd133e31b954d29a92);
#
#
#
#         marker_bc2f05f45c9f7f12a8891ae3262eda01.bindPopup(popup_51a8f30d0d64ca154e8b29764569f3de)
#         ;
#
#
#
#
#             var marker_e3fb453c6be8b7b19ab6fe22f921e304 = L.marker(
#                 [-54.0, 63.0],
#                 {}
#             ).addTo(marker_cluster_6eb8a24c3c9e92e9d53b735aefa9eeb0);
#
#
#         var popup_9e3d6ceee0f2999e22205c20c458aad2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54e500a31ecd266c7c33ab82f93ee3e4 = $(`&lt;div id=&quot;html_54e500a31ecd266c7c33ab82f93ee3e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:63&lt;br&gt;lat:-54&lt;/div&gt;`)[0];
#                 popup_9e3d6ceee0f2999e22205c20c458aad2.setContent(html_54e500a31ecd266c7c33ab82f93ee3e4);
#
#
#
#         marker_e3fb453c6be8b7b19ab6fe22f921e304.bindPopup(popup_9e3d6ceee0f2999e22205c20c458aad2)
#         ;
#
#
#
#
#             var marker_604f592f75a95b4d5256d2fc654f7872 = L.marker(
#                 [50.0, -54.0],
#                 {}
#             ).addTo(marker_cluster_6eb8a24c3c9e92e9d53b735aefa9eeb0);
#
#
#         var popup_40ddded7a4ce0dbeb132145937302138 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8172872444277c49654444b3e8425d7c = $(`&lt;div id=&quot;html_8172872444277c49654444b3e8425d7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-54&lt;br&gt;lat:50&lt;/div&gt;`)[0];
#                 popup_40ddded7a4ce0dbeb132145937302138.setContent(html_8172872444277c49654444b3e8425d7c);
#
#
#
#         marker_604f592f75a95b4d5256d2fc654f7872.bindPopup(popup_40ddded7a4ce0dbeb132145937302138)
#         ;
#
#
#
#
#             var marker_90b4e6b04926fa65906ece3e14899cf7 = L.marker(
#                 [-72.0, -153.0],
#                 {}
#             ).addTo(marker_cluster_6eb8a24c3c9e92e9d53b735aefa9eeb0);
#
#
#         var popup_77b08daf7a489ffaa0477

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29c68324744b8fb35bd5ba15a819d2b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29c68324744b8fb35bd5ba15a819d2b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29c68324744b8fb35bd5ba15a819d2b2 = L.map(
#                 &quot;map_29c68324744b8fb35bd5ba15a819d2b2&quot;,
#                 {
#                     center: [-11.81, -8.92],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98da28107bde09c70cfa852da0a9c016 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_98da28107bde09c70cfa852da0a9c016.addTo(map_29c68324744b8fb35bd5ba15a819d2b2);
#
#
#             var fast_marker_cluster_c0e12088857c0019d44e1a709111a31a = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[79.0, 178.0], [-43.0, 107.0], [-54.0, 63.0], [50.0, -54.0], [-72.0, -153.0], [0.0, -70.0], [38.0, 149.0], [26.0, 122.0], [-81.0, -157.0], [-18.0, 27.0], [13.0, 176.0], [-57.0, -166.0], [-36.0, -52.0], [28.0, 66.0], [-59.0, 123.0], [59.0, -32.0], [-73.0, 173.0], [-78.0, 152.0], [-44.0, 17.0], [-85.0, -21.0], [62.0, -85.0], [42.0, 162.0], [-22.0, -10.0], [-67.0, -95.0], [-86.0, -118.0], [-69.0, -136.0], [-74.0, -135.0], [16.0, -163.0], [15.0, -161.0], [67.0, 143.0], [42.0, -125.0], [32.0, 104.0], [88.0, -126.0], [-30.0, -164.0], [6.0, -80.0], [-66.0, -35.0], [62.0, 77.0], [30.0, -165.0], [63.0, -127.0], [5.0, 72.0], [-83.0, 25.0], [-46.0, -19.0], [-45.0, -105.0], [80.0, -172.0], [58.0, 175.0], [15.0, -127.0], [28.0, 78.0], [-39.0, -88.0], [-72.0, 173.0], [-46.0, -43.0], [52.0, 91.0], [41.0, 20.0], [40.0, -168.0], [88.0, -62.0], [49.0, 3.0], [72.0, -136.0], [-77.0, -67.0], [77.0, 6.0], [-31.0, 75.0], [-40.0, -118.0], [5.0, 13.0], [-71.0, -40.0], [-28.0, 127.0], [-45.0, 133.0], [83.0, -154.0], [-52.0, 71.0], [26.0, -9.0], [51.0, 153.0], [7.0, 11.0], [69.0, 176.0], [-40.0, 117.0], [-56.0, -12.0], [-78.0, -1.0], [-69.0, 35.0], [-69.0, 146.0], [-66.0, 69.0], [-83.0, 112.0], [65.0, 86.0], [-63.0, -110.0], [-79.0, 6.0], [0.0, -135.0], [-62.0, -137.0], [29.0, 29.0], [-69.0, -156.0], [-36.0, -42.0], [-59.0, -25.0], [52.0, -81.0], [-82.0, -176.0], [-34.0, -151.0], [-4.0, -128.0], [-28.0, -7.0], [-2.0, -31.0], [-52.0, 98.0], [-39.0, 58.0], [-19.0, 11.0], [-17.0, -55.0], [-50.0, 170.0], [-68.0, -79.0], [-3.0, -150.0], [25.0, 144.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_29c68324744b8fb35bd5ba15a819d2b2);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_c0e12088857c0019d44e1a709111a31a.addTo(map_29c68324744b8fb35bd5ba15a819d2b2);
#
#
#             var layer_control_793967f832ee2fe976e3e19976bb4852_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_98da28107bde09c70cfa852da0a9c016,
#                 },
#                 overlays :  {
#                     &quot;macro_element_c0e12088857c0019d44e1a709111a31a&quot; : fast_marker_cluster_c0e12088857c0019d44e1a709111a31a,
#                 },
#             };
#             let layer_control_793967f832ee2fe976e3e19976bb4852 = L.control.layers(
#                 layer_control_793967f832ee2fe976e3e19976bb4852_layers.base_layers,
#                 layer_control_793967f832ee2fe976e3e19976bb4852_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_29c68324744b8fb35bd5ba15a819d2b2);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43a935699863138d56ec83f489b7cc4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43a935699863138d56ec83f489b7cc4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43a935699863138d56ec83f489b7cc4f = L.map(
#                 &quot;map_43a935699863138d56ec83f489b7cc4f&quot;,
#                 {
#                     center: [-11.81, -8.92],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb6e2693bfcbb29c5dd642553bb09583 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fb6e2693bfcbb29c5dd642553bb09583.addTo(map_43a935699863138d56ec83f489b7cc4f);
#
#
#             var fast_marker_cluster_d20b14ec4d7ae4ed7126a3dc30feb987 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[79.0, 178.0], [-43.0, 107.0], [-54.0, 63.0], [50.0, -54.0], [-72.0, -153.0], [0.0, -70.0], [38.0, 149.0], [26.0, 122.0], [-81.0, -157.0], [-18.0, 27.0], [13.0, 176.0], [-57.0, -166.0], [-36.0, -52.0], [28.0, 66.0], [-59.0, 123.0], [59.0, -32.0], [-73.0, 173.0], [-78.0, 152.0], [-44.0, 17.0], [-85.0, -21.0], [62.0, -85.0], [42.0, 162.0], [-22.0, -10.0], [-67.0, -95.0], [-86.0, -118.0], [-69.0, -136.0], [-74.0, -135.0], [16.0, -163.0], [15.0, -161.0], [67.0, 143.0], [42.0, -125.0], [32.0, 104.0], [88.0, -126.0], [-30.0, -164.0], [6.0, -80.0], [-66.0, -35.0], [62.0, 77.0], [30.0, -165.0], [63.0, -127.0], [5.0, 72.0], [-83.0, 25.0], [-46.0, -19.0], [-45.0, -105.0], [80.0, -172.0], [58.0, 175.0], [15.0, -127.0], [28.0, 78.0], [-39.0, -88.0], [-72.0, 173.0], [-46.0, -43.0], [52.0, 91.0], [41.0, 20.0], [40.0, -168.0], [88.0, -62.0], [49.0, 3.0], [72.0, -136.0], [-77.0, -67.0], [77.0, 6.0], [-31.0, 75.0], [-40.0, -118.0], [5.0, 13.0], [-71.0, -40.0], [-28.0, 127.0], [-45.0, 133.0], [83.0, -154.0], [-52.0, 71.0], [26.0, -9.0], [51.0, 153.0], [7.0, 11.0], [69.0, 176.0], [-40.0, 117.0], [-56.0, -12.0], [-78.0, -1.0], [-69.0, 35.0], [-69.0, 146.0], [-66.0, 69.0], [-83.0, 112.0], [65.0, 86.0], [-63.0, -110.0], [-79.0, 6.0], [0.0, -135.0], [-62.0, -137.0], [29.0, 29.0], [-69.0, -156.0], [-36.0, -42.0], [-59.0, -25.0], [52.0, -81.0], [-82.0, -176.0], [-34.0, -151.0], [-4.0, -128.0], [-28.0, -7.0], [-2.0, -31.0], [-52.0, 98.0], [-39.0, 58.0], [-19.0, 11.0], [-17.0, -55.0], [-50.0, 170.0], [-68.0, -79.0], [-3.0, -150.0], [25.0, 144.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_43a935699863138d56ec83f489b7cc4f);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_d20b14ec4d7ae4ed7126a3dc30feb987.addTo(map_43a935699863138d56ec83f489b7cc4f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
