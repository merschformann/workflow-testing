# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f1f36251be267e3777be0e39a1b0504 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f1f36251be267e3777be0e39a1b0504&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f1f36251be267e3777be0e39a1b0504 = L.map(
#                 &quot;map_3f1f36251be267e3777be0e39a1b0504&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82280464e27ff2eed7bc6fc3deddb4ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_82280464e27ff2eed7bc6fc3deddb4ca.addTo(map_3f1f36251be267e3777be0e39a1b0504);
#
#
#             var marker_cluster_c9d3c2490a2b0125dcaef6ba061d7906 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_5d2b34405d2b0ed52c049afb5333b000 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_c9d3c2490a2b0125dcaef6ba061d7906);
#
#
#             var icon_74377cfdc36a7ac20c72b7b9abba8848 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5d2b34405d2b0ed52c049afb5333b000.setIcon(icon_74377cfdc36a7ac20c72b7b9abba8848);
#
#
#         var popup_986eb96a2f999e58bbb099485cc86a2f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af8e26ac75a2c0ad812c66b273182c8f = $(`&lt;div id=&quot;html_af8e26ac75a2c0ad812c66b273182c8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_986eb96a2f999e58bbb099485cc86a2f.setContent(html_af8e26ac75a2c0ad812c66b273182c8f);
#
#
#
#         marker_5d2b34405d2b0ed52c049afb5333b000.bindPopup(popup_986eb96a2f999e58bbb099485cc86a2f)
#         ;
#
#
#
#
#             var marker_dc72295167672d325334fcd68ba6b6c4 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_c9d3c2490a2b0125dcaef6ba061d7906);
#
#
#             var icon_4859df2941e3489489822f674d970a4b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dc72295167672d325334fcd68ba6b6c4.setIcon(icon_4859df2941e3489489822f674d970a4b);
#
#
#         var popup_7fac672fabc811cc3f9dfee234090269 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_08fb204eaf68f55212e8e9d66f863a35 = $(`&lt;div id=&quot;html_08fb204eaf68f55212e8e9d66f863a35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_7fac672fabc811cc3f9dfee234090269.setContent(html_08fb204eaf68f55212e8e9d66f863a35);
#
#
#
#         marker_dc72295167672d325334fcd68ba6b6c4.bindPopup(popup_7fac672fabc811cc3f9dfee234090269)
#         ;
#
#
#
#
#             var marker_00555fde8b230a5009174e1f283ead07 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_c9d3c2490a2b0125dcaef6ba061d7906);
#
#
#         var popup_536a15658596b16697a6825c076cc469 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1cee278c31cb363a8acd9d53800e5d85 = $(`&lt;div id=&quot;html_1cee278c31cb363a8acd9d53800e5d85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_536a15658596b16697a6825c076cc469.setContent(html_1cee278c31cb363a8acd9d53800e5d85);
#
#
#
#         marker_00555fde8b230a5009174e1f283ead07.bindPopup(popup_536a15658596b16697a6825c076cc469)
#         ;
#
#
#
#
#             marker_cluster_c9d3c2490a2b0125dcaef6ba061d7906.addTo(map_3f1f36251be267e3777be0e39a1b0504);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abc10a480f39a8a4a40708a27a9f01d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abc10a480f39a8a4a40708a27a9f01d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abc10a480f39a8a4a40708a27a9f01d9 = L.map(
#                 &quot;map_abc10a480f39a8a4a40708a27a9f01d9&quot;,
#                 {
#                     center: [0.71, -2.85],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ccfb68e161ba3b74316f56beca98343 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2ccfb68e161ba3b74316f56beca98343.addTo(map_abc10a480f39a8a4a40708a27a9f01d9);
#
#
#             var marker_cluster_8c737e13291dd55858efcf1cebcfd5c0 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_8c737e13291dd55858efcf1cebcfd5c0.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_638e8b2690829599030341d9dedf374a = L.marker(
#                 [72.0, -134.0],
#                 {}
#             ).addTo(marker_cluster_8c737e13291dd55858efcf1cebcfd5c0);
#
#
#         var popup_b7dc6d3a3b24b9f60a0de7a1a5b63592 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a2fbf6f68f7c861d596cb7f0a5e0902d = $(`&lt;div id=&quot;html_a2fbf6f68f7c861d596cb7f0a5e0902d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-134&lt;br&gt;lat:72&lt;/div&gt;`)[0];
#                 popup_b7dc6d3a3b24b9f60a0de7a1a5b63592.setContent(html_a2fbf6f68f7c861d596cb7f0a5e0902d);
#
#
#
#         marker_638e8b2690829599030341d9dedf374a.bindPopup(popup_b7dc6d3a3b24b9f60a0de7a1a5b63592)
#         ;
#
#
#
#
#             var marker_7c20b58554f2a77cc2c7e778aaa66850 = L.marker(
#                 [47.0, -25.0],
#                 {}
#             ).addTo(marker_cluster_8c737e13291dd55858efcf1cebcfd5c0);
#
#
#         var popup_2381c14d1d4d76872598c1dbfa7ae4d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dcfbb537a0f02ad3c849f4d1bba88c67 = $(`&lt;div id=&quot;html_dcfbb537a0f02ad3c849f4d1bba88c67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-25&lt;br&gt;lat:47&lt;/div&gt;`)[0];
#                 popup_2381c14d1d4d76872598c1dbfa7ae4d8.setContent(html_dcfbb537a0f02ad3c849f4d1bba88c67);
#
#
#
#         marker_7c20b58554f2a77cc2c7e778aaa66850.bindPopup(popup_2381c14d1d4d76872598c1dbfa7ae4d8)
#         ;
#
#
#
#
#             var marker_eb5b876b420d6e594a0c192a1a3c256c = L.marker(
#                 [20.0, -172.0],
#                 {}
#             ).addTo(marker_cluster_8c737e13291dd55858efcf1cebcfd5c0);
#
#
#         var popup_16b29f5a9c932b69ddbf9f7716a5a6c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e83519e5e2abf754ca49cd27760378e1 = $(`&lt;div id=&quot;html_e83519e5e2abf754ca49cd27760378e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-172&lt;br&gt;lat:20&lt;/div&gt;`)[0];
#                 popup_16b29f5a9c932b69ddbf9f7716a5a6c7.setContent(html_e83519e5e2abf754ca49cd27760378e1);
#
#
#
#         marker_eb5b876b420d6e594a0c192a1a3c256c.bindPopup(popup_16b29f5a9c932b69ddbf9f7716a5a6c7)
#         ;
#
#
#
#
#             var marker_2f12e1970a807bf05f8d22890d45c100 = L.marker(
#                 [47.0, -149.0],
#                 {}
#             ).addTo(marker_cluster_8c737e13291dd55858efcf1cebcfd5c0);
#
#
#         var popup_4341ea8dde819758f05499a89f9852b3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c40685c9c05355dd74a19d3448064fe4 = $(`&lt;div id=&quot;html_c40685c9c05355dd74a19d3448064fe4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-149&lt;br&gt;lat:47&lt;/div&gt;`)[0];
#                 popup_4341ea8dde819758f05499a89f9852b3.setContent(html_c40685c9c05355dd74a19d3448064fe4);
#
#
#
#         marker_2f12e1970a807

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73a2546ec667a30ba78f077e0e7edf5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73a2546ec667a30ba78f077e0e7edf5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73a2546ec667a30ba78f077e0e7edf5f = L.map(
#                 &quot;map_73a2546ec667a30ba78f077e0e7edf5f&quot;,
#                 {
#                     center: [0.71, -2.85],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61ea433ff290117f0b5660fdc8c424bd = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_61ea433ff290117f0b5660fdc8c424bd.addTo(map_73a2546ec667a30ba78f077e0e7edf5f);
#
#
#             var marker_cluster_2d569c02d1824463fef8dee4cbbc553c = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_eafd003a27aa5d3a5bb66b2ea51e3656 = L.marker(
#                 [72.0, -134.0],
#                 {}
#             ).addTo(marker_cluster_2d569c02d1824463fef8dee4cbbc553c);
#
#
#         var popup_8bba6108db6104bf80b58b0bdcf20d4c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_89eefef1ddbd59776db25a810f1cc705 = $(`&lt;div id=&quot;html_89eefef1ddbd59776db25a810f1cc705&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-134&lt;br&gt;lat:72&lt;/div&gt;`)[0];
#                 popup_8bba6108db6104bf80b58b0bdcf20d4c.setContent(html_89eefef1ddbd59776db25a810f1cc705);
#
#
#
#         marker_eafd003a27aa5d3a5bb66b2ea51e3656.bindPopup(popup_8bba6108db6104bf80b58b0bdcf20d4c)
#         ;
#
#
#
#
#             var marker_66f87405d556011b0feb7ce235a594af = L.marker(
#                 [47.0, -25.0],
#                 {}
#             ).addTo(marker_cluster_2d569c02d1824463fef8dee4cbbc553c);
#
#
#         var popup_ed03b6ff6988ccbc30f18a4cd2c5c59d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0402163fce4c70ed40ba78fb992405c0 = $(`&lt;div id=&quot;html_0402163fce4c70ed40ba78fb992405c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-25&lt;br&gt;lat:47&lt;/div&gt;`)[0];
#                 popup_ed03b6ff6988ccbc30f18a4cd2c5c59d.setContent(html_0402163fce4c70ed40ba78fb992405c0);
#
#
#
#         marker_66f87405d556011b0feb7ce235a594af.bindPopup(popup_ed03b6ff6988ccbc30f18a4cd2c5c59d)
#         ;
#
#
#
#
#             var marker_02c227accee74db75543d2e6c968168b = L.marker(
#                 [20.0, -172.0],
#                 {}
#             ).addTo(marker_cluster_2d569c02d1824463fef8dee4cbbc553c);
#
#
#         var popup_9776b796158000775b8d15d650007434 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_92740d3dc101b95991545884586469b2 = $(`&lt;div id=&quot;html_92740d3dc101b95991545884586469b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-172&lt;br&gt;lat:20&lt;/div&gt;`)[0];
#                 popup_9776b796158000775b8d15d650007434.setContent(html_92740d3dc101b95991545884586469b2);
#
#
#
#         marker_02c227accee74db75543d2e6c968168b.bindPopup(popup_9776b796158000775b8d15d650007434)
#         ;
#
#
#
#
#             var marker_88f8b02a6593db25412e70a3def24ab0 = L.marker(
#                 [47.0, -149.0],
#                 {}
#             ).addTo(marker_cluster_2d569c02d1824463fef8dee4cbbc553c);
#
#
#         var popup_b8e7f19e38642c9e35dbf8efb2b3ab6c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_623f01005f80159abe56b9928b8d260c = $(`&lt;div id=&quot;html_623f01005f80159abe56b9928b8d260c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-149&lt;br&gt;lat:47&lt;/div&gt;`)[0];
#                 popup_b8e7f19e38642c9e35dbf8efb2b3ab6c.setContent(html_623f01005f80159abe56b9928b8d260c);
#
#
#
#         marker_88f8b02a6593db25412e70a3def24ab0.bindPopup(popup_b8e7f19e38642c9e35dbf8efb2b3ab6c)
#         ;
#
#
#
#
#             var marker_3f2b04942d19c8b4d10bbe29e946adbf = L.marker(
#                 [-89.0, -64.0],
#                 {}
#             ).addTo(marker_cluster_2d569c02d1824463fef8dee4cbbc553c);
#
#
#         var popup_a50d7012466a5dba8e76

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b0be96a6d21f0172b543b1482aa1cf31 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b0be96a6d21f0172b543b1482aa1cf31&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b0be96a6d21f0172b543b1482aa1cf31 = L.map(
#                 &quot;map_b0be96a6d21f0172b543b1482aa1cf31&quot;,
#                 {
#                     center: [0.71, -2.85],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_747525fae539fc95b87e178cbd17d2dd = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_747525fae539fc95b87e178cbd17d2dd.addTo(map_b0be96a6d21f0172b543b1482aa1cf31);
#
#
#             var fast_marker_cluster_04b4d9e80d15c0021d51c9c7606c0011 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[72.0, -134.0], [47.0, -25.0], [20.0, -172.0], [47.0, -149.0], [-89.0, -64.0], [78.0, 125.0], [52.0, 132.0], [39.0, 108.0], [53.0, 78.0], [-13.0, 153.0], [12.0, 27.0], [-88.0, -162.0], [4.0, -111.0], [-89.0, 35.0], [-17.0, 0.0], [10.0, -22.0], [75.0, 80.0], [-5.0, 143.0], [65.0, 60.0], [25.0, -117.0], [-61.0, 24.0], [-79.0, -67.0], [-42.0, 55.0], [-20.0, 104.0], [50.0, -155.0], [-13.0, -122.0], [61.0, 142.0], [83.0, -75.0], [-16.0, 146.0], [-27.0, -178.0], [70.0, -146.0], [25.0, 103.0], [-45.0, -13.0], [-67.0, 18.0], [-56.0, 72.0], [-38.0, -48.0], [-83.0, -67.0], [10.0, -69.0], [-23.0, -180.0], [-28.0, 4.0], [-48.0, 119.0], [24.0, -38.0], [-50.0, 64.0], [15.0, -2.0], [-63.0, -143.0], [-15.0, 130.0], [52.0, -37.0], [72.0, 26.0], [88.0, 24.0], [-24.0, 54.0], [45.0, 154.0], [-33.0, -52.0], [-19.0, 105.0], [57.0, -55.0], [53.0, 59.0], [-83.0, -153.0], [48.0, -81.0], [63.0, -6.0], [-40.0, -126.0], [-82.0, -97.0], [63.0, 75.0], [-64.0, 53.0], [5.0, 29.0], [-29.0, 0.0], [-63.0, -126.0], [-49.0, -93.0], [39.0, -36.0], [84.0, 12.0], [14.0, -120.0], [20.0, 23.0], [-35.0, 83.0], [22.0, 115.0], [66.0, -49.0], [8.0, -28.0], [-39.0, 112.0], [74.0, -53.0], [-38.0, 15.0], [-69.0, -143.0], [-76.0, -37.0], [-33.0, 65.0], [78.0, -13.0], [87.0, -45.0], [-45.0, 69.0], [24.0, -162.0], [56.0, 23.0], [64.0, -7.0], [-68.0, 4.0], [53.0, -7.0], [59.0, -12.0], [-53.0, -111.0], [-44.0, 47.0], [-26.0, 153.0], [14.0, -72.0], [-34.0, -146.0], [-86.0, 134.0], [-85.0, 137.0], [84.0, 172.0], [11.0, 122.0], [68.0, 160.0], [-45.0, -106.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_b0be96a6d21f0172b543b1482aa1cf31);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_04b4d9e80d15c0021d51c9c7606c0011.addTo(map_b0be96a6d21f0172b543b1482aa1cf31);
#
#
#             var layer_control_66de291f39c2d7bff7721d903d8e053f_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_747525fae539fc95b87e178cbd17d2dd,
#                 },
#                 overlays :  {
#                     &quot;macro_element_04b4d9e80d15c0021d51c9c7606c0011&quot; : fast_marker_cluster_04b4d9e80d15c0021d51c9c7606c0011,
#                 },
#             };
#             let layer_control_66de291f39c2d7bff7721d903d8e053f = L.control.layers(
#                 layer_control_66de291f39c2d7bff7721d903d8e053f_layers.base_layers,
#                 layer_control_66de291f39c2d7bff7721d903d8e053f_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_b0be96a6d21f0172b543b1482aa1cf31);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04bb4034389611b36f5d921a479bd2c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04bb4034389611b36f5d921a479bd2c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04bb4034389611b36f5d921a479bd2c0 = L.map(
#                 &quot;map_04bb4034389611b36f5d921a479bd2c0&quot;,
#                 {
#                     center: [0.71, -2.85],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_615504d4bb176a6d169827a469808e62 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_615504d4bb176a6d169827a469808e62.addTo(map_04bb4034389611b36f5d921a479bd2c0);
#
#
#             var fast_marker_cluster_565febb9f8f16107e3beebcbac64b248 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[72.0, -134.0], [47.0, -25.0], [20.0, -172.0], [47.0, -149.0], [-89.0, -64.0], [78.0, 125.0], [52.0, 132.0], [39.0, 108.0], [53.0, 78.0], [-13.0, 153.0], [12.0, 27.0], [-88.0, -162.0], [4.0, -111.0], [-89.0, 35.0], [-17.0, 0.0], [10.0, -22.0], [75.0, 80.0], [-5.0, 143.0], [65.0, 60.0], [25.0, -117.0], [-61.0, 24.0], [-79.0, -67.0], [-42.0, 55.0], [-20.0, 104.0], [50.0, -155.0], [-13.0, -122.0], [61.0, 142.0], [83.0, -75.0], [-16.0, 146.0], [-27.0, -178.0], [70.0, -146.0], [25.0, 103.0], [-45.0, -13.0], [-67.0, 18.0], [-56.0, 72.0], [-38.0, -48.0], [-83.0, -67.0], [10.0, -69.0], [-23.0, -180.0], [-28.0, 4.0], [-48.0, 119.0], [24.0, -38.0], [-50.0, 64.0], [15.0, -2.0], [-63.0, -143.0], [-15.0, 130.0], [52.0, -37.0], [72.0, 26.0], [88.0, 24.0], [-24.0, 54.0], [45.0, 154.0], [-33.0, -52.0], [-19.0, 105.0], [57.0, -55.0], [53.0, 59.0], [-83.0, -153.0], [48.0, -81.0], [63.0, -6.0], [-40.0, -126.0], [-82.0, -97.0], [63.0, 75.0], [-64.0, 53.0], [5.0, 29.0], [-29.0, 0.0], [-63.0, -126.0], [-49.0, -93.0], [39.0, -36.0], [84.0, 12.0], [14.0, -120.0], [20.0, 23.0], [-35.0, 83.0], [22.0, 115.0], [66.0, -49.0], [8.0, -28.0], [-39.0, 112.0], [74.0, -53.0], [-38.0, 15.0], [-69.0, -143.0], [-76.0, -37.0], [-33.0, 65.0], [78.0, -13.0], [87.0, -45.0], [-45.0, 69.0], [24.0, -162.0], [56.0, 23.0], [64.0, -7.0], [-68.0, 4.0], [53.0, -7.0], [59.0, -12.0], [-53.0, -111.0], [-44.0, 47.0], [-26.0, 153.0], [14.0, -72.0], [-34.0, -146.0], [-86.0, 134.0], [-85.0, 137.0], [84.0, 172.0], [11.0, 122.0], [68.0, 160.0], [-45.0, -106.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_04bb4034389611b36f5d921a479bd2c0);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_565febb9f8f16107e3beebcbac64b248.addTo(map_04bb4034389611b36f5d921a479bd2c0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
