# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b43391aa5bec9973946feff206c79df3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b43391aa5bec9973946feff206c79df3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b43391aa5bec9973946feff206c79df3 = L.map(
#                 &quot;map_b43391aa5bec9973946feff206c79df3&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_826b534e2cf8d5a85fa8476532c1b937 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_826b534e2cf8d5a85fa8476532c1b937.addTo(map_b43391aa5bec9973946feff206c79df3);
#
#
#             var marker_cluster_2d6ab1644e959de49b46d102bcb61e0b = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_f0bf6554edb5f4f3851136fa42eeed5a = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_2d6ab1644e959de49b46d102bcb61e0b);
#
#
#             var icon_45395ce44174557952bdcad6040310f8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f0bf6554edb5f4f3851136fa42eeed5a.setIcon(icon_45395ce44174557952bdcad6040310f8);
#
#
#         var popup_32c67094f1c160aa7cc9bdb3603bfa2b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e264c351c14ff9fd359c4707818903b = $(`&lt;div id=&quot;html_3e264c351c14ff9fd359c4707818903b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_32c67094f1c160aa7cc9bdb3603bfa2b.setContent(html_3e264c351c14ff9fd359c4707818903b);
#
#
#
#         marker_f0bf6554edb5f4f3851136fa42eeed5a.bindPopup(popup_32c67094f1c160aa7cc9bdb3603bfa2b)
#         ;
#
#
#
#
#             var marker_b67b005b013963d8968009bdd292f445 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_2d6ab1644e959de49b46d102bcb61e0b);
#
#
#             var icon_37114417377398e574d724e78e8c4058 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b67b005b013963d8968009bdd292f445.setIcon(icon_37114417377398e574d724e78e8c4058);
#
#
#         var popup_6acb6a65a017fc4486664bd8df2495d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_968ad8e121cbe0a9d4191fc34b27c9cf = $(`&lt;div id=&quot;html_968ad8e121cbe0a9d4191fc34b27c9cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_6acb6a65a017fc4486664bd8df2495d8.setContent(html_968ad8e121cbe0a9d4191fc34b27c9cf);
#
#
#
#         marker_b67b005b013963d8968009bdd292f445.bindPopup(popup_6acb6a65a017fc4486664bd8df2495d8)
#         ;
#
#
#
#
#             var marker_baf6cffa5a1236ce5f913ab769da6ecd = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_2d6ab1644e959de49b46d102bcb61e0b);
#
#
#         var popup_0b5e347cf4d977750a215a585e08d0a6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe3baad57b02963f5122b4b8095c45d9 = $(`&lt;div id=&quot;html_fe3baad57b02963f5122b4b8095c45d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_0b5e347cf4d977750a215a585e08d0a6.setContent(html_fe3baad57b02963f5122b4b8095c45d9);
#
#
#
#         marker_baf6cffa5a1236ce5f913ab769da6ecd.bindPopup(popup_0b5e347cf4d977750a215a585e08d0a6)
#         ;
#
#
#
#
#             marker_cluster_2d6ab1644e959de49b46d102bcb61e0b.addTo(map_b43391aa5bec9973946feff206c79df3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3e55d2dedc72aa8a7a4da1270b280ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3e55d2dedc72aa8a7a4da1270b280ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b3e55d2dedc72aa8a7a4da1270b280ab = L.map(
#                 &quot;map_b3e55d2dedc72aa8a7a4da1270b280ab&quot;,
#                 {
#                     center: [4.56, -13.25],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6581e7b03e17016433f43164f99657e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a6581e7b03e17016433f43164f99657e.addTo(map_b3e55d2dedc72aa8a7a4da1270b280ab);
#
#
#             var marker_cluster_ea4277cbf70c9127cdf283e772e58d62 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_ea4277cbf70c9127cdf283e772e58d62.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_fa2ef905b660e0613aea85302d732e0d = L.marker(
#                 [25.0, 115.0],
#                 {}
#             ).addTo(marker_cluster_ea4277cbf70c9127cdf283e772e58d62);
#
#
#         var popup_7576aa6a2ced456a94dad87cf1cabbb5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_38451c52ac28960f540838d639471302 = $(`&lt;div id=&quot;html_38451c52ac28960f540838d639471302&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:115&lt;br&gt;lat:25&lt;/div&gt;`)[0];
#                 popup_7576aa6a2ced456a94dad87cf1cabbb5.setContent(html_38451c52ac28960f540838d639471302);
#
#
#
#         marker_fa2ef905b660e0613aea85302d732e0d.bindPopup(popup_7576aa6a2ced456a94dad87cf1cabbb5)
#         ;
#
#
#
#
#             var marker_f7f1a08c06febd44a4c9108a14f23969 = L.marker(
#                 [81.0, 87.0],
#                 {}
#             ).addTo(marker_cluster_ea4277cbf70c9127cdf283e772e58d62);
#
#
#         var popup_0cd376cb29a3d76b7708098469f414f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1295ff061da96ad9d0b20e12f92f0c91 = $(`&lt;div id=&quot;html_1295ff061da96ad9d0b20e12f92f0c91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:87&lt;br&gt;lat:81&lt;/div&gt;`)[0];
#                 popup_0cd376cb29a3d76b7708098469f414f8.setContent(html_1295ff061da96ad9d0b20e12f92f0c91);
#
#
#
#         marker_f7f1a08c06febd44a4c9108a14f23969.bindPopup(popup_0cd376cb29a3d76b7708098469f414f8)
#         ;
#
#
#
#
#             var marker_eed2d0afc3c33dee2e56fc3478f0c226 = L.marker(
#                 [-16.0, -2.0],
#                 {}
#             ).addTo(marker_cluster_ea4277cbf70c9127cdf283e772e58d62);
#
#
#         var popup_0c73e220112f44acf03d859fe6d4137b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d51a855069a4974130c2f4385cb53c6c = $(`&lt;div id=&quot;html_d51a855069a4974130c2f4385cb53c6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-2&lt;br&gt;lat:-16&lt;/div&gt;`)[0];
#                 popup_0c73e220112f44acf03d859fe6d4137b.setContent(html_d51a855069a4974130c2f4385cb53c6c);
#
#
#
#         marker_eed2d0afc3c33dee2e56fc3478f0c226.bindPopup(popup_0c73e220112f44acf03d859fe6d4137b)
#         ;
#
#
#
#
#             var marker_d235bf7599671a846e0b0f719896ae0e = L.marker(
#                 [-64.0, 95.0],
#                 {}
#             ).addTo(marker_cluster_ea4277cbf70c9127cdf283e772e58d62);
#
#
#         var popup_caaa396e674a4fa7b4e253f899076a51 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_155b5731951c89b825fbe14480b99e32 = $(`&lt;div id=&quot;html_155b5731951c89b825fbe14480b99e32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:95&lt;br&gt;lat:-64&lt;/div&gt;`)[0];
#                 popup_caaa396e674a4fa7b4e253f899076a51.setContent(html_155b5731951c89b825fbe14480b99e32);
#
#
#
#         marker_d235bf7599671a846e0b

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a4ee8d09b0170e917b98c74abe9ad23 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a4ee8d09b0170e917b98c74abe9ad23&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a4ee8d09b0170e917b98c74abe9ad23 = L.map(
#                 &quot;map_2a4ee8d09b0170e917b98c74abe9ad23&quot;,
#                 {
#                     center: [4.56, -13.25],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2dae6b7a614406a09467fc74e149443 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e2dae6b7a614406a09467fc74e149443.addTo(map_2a4ee8d09b0170e917b98c74abe9ad23);
#
#
#             var marker_cluster_74c27e22a7eeed4bb758c8f24df4a8a1 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_e625bddb8286d9b683f038ed7a8658f3 = L.marker(
#                 [25.0, 115.0],
#                 {}
#             ).addTo(marker_cluster_74c27e22a7eeed4bb758c8f24df4a8a1);
#
#
#         var popup_db152c0a2dd8b8a10f9d63d972124d75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c8ff523d1a4df54bd040eb7faadb791 = $(`&lt;div id=&quot;html_5c8ff523d1a4df54bd040eb7faadb791&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:115&lt;br&gt;lat:25&lt;/div&gt;`)[0];
#                 popup_db152c0a2dd8b8a10f9d63d972124d75.setContent(html_5c8ff523d1a4df54bd040eb7faadb791);
#
#
#
#         marker_e625bddb8286d9b683f038ed7a8658f3.bindPopup(popup_db152c0a2dd8b8a10f9d63d972124d75)
#         ;
#
#
#
#
#             var marker_6fd1fe3746aa7fb77a45f8e009983837 = L.marker(
#                 [81.0, 87.0],
#                 {}
#             ).addTo(marker_cluster_74c27e22a7eeed4bb758c8f24df4a8a1);
#
#
#         var popup_2b1eaf318ef9c80180c996b9c875c392 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_999f2ee43fc5904427dfda140cdbbd76 = $(`&lt;div id=&quot;html_999f2ee43fc5904427dfda140cdbbd76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:87&lt;br&gt;lat:81&lt;/div&gt;`)[0];
#                 popup_2b1eaf318ef9c80180c996b9c875c392.setContent(html_999f2ee43fc5904427dfda140cdbbd76);
#
#
#
#         marker_6fd1fe3746aa7fb77a45f8e009983837.bindPopup(popup_2b1eaf318ef9c80180c996b9c875c392)
#         ;
#
#
#
#
#             var marker_79f88a04c13717cfbb9d41f895b1ac6e = L.marker(
#                 [-16.0, -2.0],
#                 {}
#             ).addTo(marker_cluster_74c27e22a7eeed4bb758c8f24df4a8a1);
#
#
#         var popup_6c9f958dcead954da941cc2cc65ed2c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d82cb187defa9d45db49d5527cf5d283 = $(`&lt;div id=&quot;html_d82cb187defa9d45db49d5527cf5d283&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-2&lt;br&gt;lat:-16&lt;/div&gt;`)[0];
#                 popup_6c9f958dcead954da941cc2cc65ed2c8.setContent(html_d82cb187defa9d45db49d5527cf5d283);
#
#
#
#         marker_79f88a04c13717cfbb9d41f895b1ac6e.bindPopup(popup_6c9f958dcead954da941cc2cc65ed2c8)
#         ;
#
#
#
#
#             var marker_d9bfa55376afbfbe1b32960372807116 = L.marker(
#                 [-64.0, 95.0],
#                 {}
#             ).addTo(marker_cluster_74c27e22a7eeed4bb758c8f24df4a8a1);
#
#
#         var popup_74a4ef7222ab41eef12f2ab578cb261a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_871bfd713f073920e339b49b8f1bf39e = $(`&lt;div id=&quot;html_871bfd713f073920e339b49b8f1bf39e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:95&lt;br&gt;lat:-64&lt;/div&gt;`)[0];
#                 popup_74a4ef7222ab41eef12f2ab578cb261a.setContent(html_871bfd713f073920e339b49b8f1bf39e);
#
#
#
#         marker_d9bfa55376afbfbe1b32960372807116.bindPopup(popup_74a4ef7222ab41eef12f2ab578cb261a)
#         ;
#
#
#
#
#             var marker_11a2fdb57e60c9966b54f8301f172f6c = L.marker(
#                 [-54.0, 128.0],
#                 {}
#             ).addTo(marker_cluster_74c27e22a7eeed4bb758c8f24df4a8a1);
#
#
#         var popup_79cdd08c8d78d0738ff68ecfc8b

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_953d54a88656bb8543afaae5fdf8d1e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_953d54a88656bb8543afaae5fdf8d1e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_953d54a88656bb8543afaae5fdf8d1e0 = L.map(
#                 &quot;map_953d54a88656bb8543afaae5fdf8d1e0&quot;,
#                 {
#                     center: [4.56, -13.25],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21cbe5d87424fec4e6749356f6fde299 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_21cbe5d87424fec4e6749356f6fde299.addTo(map_953d54a88656bb8543afaae5fdf8d1e0);
#
#
#             var fast_marker_cluster_2b8e7e3090a4561bc00d85efa15ed2bc = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[25.0, 115.0], [81.0, 87.0], [-16.0, -2.0], [-64.0, 95.0], [-54.0, 128.0], [75.0, 30.0], [1.0, 125.0], [5.0, 128.0], [63.0, -68.0], [-5.0, -123.0], [59.0, -120.0], [88.0, -130.0], [54.0, 62.0], [87.0, 26.0], [70.0, -118.0], [-49.0, 13.0], [62.0, 15.0], [27.0, 100.0], [69.0, 90.0], [69.0, -46.0], [58.0, 125.0], [8.0, -25.0], [-10.0, -27.0], [-62.0, -18.0], [10.0, -112.0], [-42.0, -164.0], [41.0, -148.0], [77.0, 26.0], [47.0, 37.0], [-90.0, 133.0], [59.0, 4.0], [27.0, -9.0], [1.0, -106.0], [-8.0, -97.0], [-79.0, -47.0], [47.0, -101.0], [41.0, -157.0], [-28.0, 92.0], [-5.0, 35.0], [-27.0, 89.0], [-24.0, 7.0], [-59.0, -110.0], [39.0, 116.0], [-36.0, 78.0], [32.0, -12.0], [2.0, -133.0], [21.0, -137.0], [-67.0, -26.0], [-30.0, -102.0], [-64.0, 31.0], [-45.0, 38.0], [-16.0, 170.0], [42.0, -93.0], [50.0, 175.0], [21.0, -100.0], [-56.0, -79.0], [-87.0, -161.0], [73.0, 118.0], [-12.0, 12.0], [-70.0, -19.0], [0.0, 118.0], [69.0, -141.0], [-10.0, 94.0], [86.0, -112.0], [-6.0, -167.0], [-84.0, 153.0], [-79.0, -136.0], [56.0, -21.0], [81.0, -134.0], [39.0, 2.0], [89.0, -100.0], [-38.0, -171.0], [-18.0, -156.0], [-22.0, -53.0], [13.0, -5.0], [4.0, -69.0], [-89.0, -93.0], [-61.0, -61.0], [76.0, -114.0], [62.0, -140.0], [58.0, 58.0], [-21.0, 3.0], [-38.0, 2.0], [-76.0, 113.0], [-88.0, -158.0], [62.0, -66.0], [-30.0, -153.0], [46.0, 129.0], [-7.0, 150.0], [5.0, 67.0], [16.0, 174.0], [64.0, -132.0], [47.0, -9.0], [-13.0, 93.0], [-43.0, -125.0], [-50.0, -144.0], [-32.0, 102.0], [-27.0, -178.0], [65.0, 179.0], [-76.0, 166.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_953d54a88656bb8543afaae5fdf8d1e0);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_2b8e7e3090a4561bc00d85efa15ed2bc.addTo(map_953d54a88656bb8543afaae5fdf8d1e0);
#
#
#             var layer_control_c844092b73735eb35cbc0de98a82f112_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_21cbe5d87424fec4e6749356f6fde299,
#                 },
#                 overlays :  {
#                     &quot;macro_element_2b8e7e3090a4561bc00d85efa15ed2bc&quot; : fast_marker_cluster_2b8e7e3090a4561bc00d85efa15ed2bc,
#                 },
#             };
#             let layer_control_c844092b73735eb35cbc0de98a82f112 = L.control.layers(
#                 layer_control_c844092b73735eb35cbc0de98a82f112_layers.base_layers,
#                 layer_control_c844092b73735eb35cbc0de98a82f112_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_953d54a88656bb8543afaae5fdf8d1e0);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71637092bb45e5c2e1d174ac5f5eddb4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71637092bb45e5c2e1d174ac5f5eddb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71637092bb45e5c2e1d174ac5f5eddb4 = L.map(
#                 &quot;map_71637092bb45e5c2e1d174ac5f5eddb4&quot;,
#                 {
#                     center: [4.56, -13.25],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8194b3c599dd42b77c27f0a473b1efd8 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8194b3c599dd42b77c27f0a473b1efd8.addTo(map_71637092bb45e5c2e1d174ac5f5eddb4);
#
#
#             var fast_marker_cluster_b5165d43ef7db55414c33e9396f5def9 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[25.0, 115.0], [81.0, 87.0], [-16.0, -2.0], [-64.0, 95.0], [-54.0, 128.0], [75.0, 30.0], [1.0, 125.0], [5.0, 128.0], [63.0, -68.0], [-5.0, -123.0], [59.0, -120.0], [88.0, -130.0], [54.0, 62.0], [87.0, 26.0], [70.0, -118.0], [-49.0, 13.0], [62.0, 15.0], [27.0, 100.0], [69.0, 90.0], [69.0, -46.0], [58.0, 125.0], [8.0, -25.0], [-10.0, -27.0], [-62.0, -18.0], [10.0, -112.0], [-42.0, -164.0], [41.0, -148.0], [77.0, 26.0], [47.0, 37.0], [-90.0, 133.0], [59.0, 4.0], [27.0, -9.0], [1.0, -106.0], [-8.0, -97.0], [-79.0, -47.0], [47.0, -101.0], [41.0, -157.0], [-28.0, 92.0], [-5.0, 35.0], [-27.0, 89.0], [-24.0, 7.0], [-59.0, -110.0], [39.0, 116.0], [-36.0, 78.0], [32.0, -12.0], [2.0, -133.0], [21.0, -137.0], [-67.0, -26.0], [-30.0, -102.0], [-64.0, 31.0], [-45.0, 38.0], [-16.0, 170.0], [42.0, -93.0], [50.0, 175.0], [21.0, -100.0], [-56.0, -79.0], [-87.0, -161.0], [73.0, 118.0], [-12.0, 12.0], [-70.0, -19.0], [0.0, 118.0], [69.0, -141.0], [-10.0, 94.0], [86.0, -112.0], [-6.0, -167.0], [-84.0, 153.0], [-79.0, -136.0], [56.0, -21.0], [81.0, -134.0], [39.0, 2.0], [89.0, -100.0], [-38.0, -171.0], [-18.0, -156.0], [-22.0, -53.0], [13.0, -5.0], [4.0, -69.0], [-89.0, -93.0], [-61.0, -61.0], [76.0, -114.0], [62.0, -140.0], [58.0, 58.0], [-21.0, 3.0], [-38.0, 2.0], [-76.0, 113.0], [-88.0, -158.0], [62.0, -66.0], [-30.0, -153.0], [46.0, 129.0], [-7.0, 150.0], [5.0, 67.0], [16.0, 174.0], [64.0, -132.0], [47.0, -9.0], [-13.0, 93.0], [-43.0, -125.0], [-50.0, -144.0], [-32.0, 102.0], [-27.0, -178.0], [65.0, 179.0], [-76.0, 166.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_71637092bb45e5c2e1d174ac5f5eddb4);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_b5165d43ef7db55414c33e9396f5def9.addTo(map_71637092bb45e5c2e1d174ac5f5eddb4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
