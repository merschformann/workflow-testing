# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0470303305adc34f07ca20d815fdfaaa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0470303305adc34f07ca20d815fdfaaa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0470303305adc34f07ca20d815fdfaaa = L.map(
#                 &quot;map_0470303305adc34f07ca20d815fdfaaa&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b7ad2a0095558fa0111a9cf6ce92b0f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4b7ad2a0095558fa0111a9cf6ce92b0f.addTo(map_0470303305adc34f07ca20d815fdfaaa);
#
#
#             var marker_cluster_acda314911c60cecebe8d93e7ac0e236 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_e75dab5bd888869312c4e415f04c266e = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_acda314911c60cecebe8d93e7ac0e236);
#
#
#             var icon_02b928edac96f1da575a791eeda00919 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e75dab5bd888869312c4e415f04c266e.setIcon(icon_02b928edac96f1da575a791eeda00919);
#
#
#         var popup_a304293abe76264d5e28ae32def2836f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_91160b48d7199bda99c489878b4bf63f = $(`&lt;div id=&quot;html_91160b48d7199bda99c489878b4bf63f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_a304293abe76264d5e28ae32def2836f.setContent(html_91160b48d7199bda99c489878b4bf63f);
#
#
#
#         marker_e75dab5bd888869312c4e415f04c266e.bindPopup(popup_a304293abe76264d5e28ae32def2836f)
#         ;
#
#
#
#
#             var marker_b2ad52606e46e2954fd9bab15868acc7 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_acda314911c60cecebe8d93e7ac0e236);
#
#
#             var icon_37032f2c9d8308e486e60f90b48098f8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b2ad52606e46e2954fd9bab15868acc7.setIcon(icon_37032f2c9d8308e486e60f90b48098f8);
#
#
#         var popup_066743dc7d298b99c037a608f5f25e50 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fc920f77c8bdefeb78fcdfcb1d9b3010 = $(`&lt;div id=&quot;html_fc920f77c8bdefeb78fcdfcb1d9b3010&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_066743dc7d298b99c037a608f5f25e50.setContent(html_fc920f77c8bdefeb78fcdfcb1d9b3010);
#
#
#
#         marker_b2ad52606e46e2954fd9bab15868acc7.bindPopup(popup_066743dc7d298b99c037a608f5f25e50)
#         ;
#
#
#
#
#             var marker_4a3aafeba7fe7ba4d68b80ea50185830 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_acda314911c60cecebe8d93e7ac0e236);
#
#
#         var popup_aefaee42d3e44282954490fc1f32bb3e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5bc283f785ea851e3dc8cbe5649febb4 = $(`&lt;div id=&quot;html_5bc283f785ea851e3dc8cbe5649febb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_aefaee42d3e44282954490fc1f32bb3e.setContent(html_5bc283f785ea851e3dc8cbe5649febb4);
#
#
#
#         marker_4a3aafeba7fe7ba4d68b80ea50185830.bindPopup(popup_aefaee42d3e44282954490fc1f32bb3e)
#         ;
#
#
#
#
#             marker_cluster_acda314911c60cecebe8d93e7ac0e236.addTo(map_0470303305adc34f07ca20d815fdfaaa);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_736c6036b18f1df55fcb0804e2303eb3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_736c6036b18f1df55fcb0804e2303eb3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_736c6036b18f1df55fcb0804e2303eb3 = L.map(
#                 &quot;map_736c6036b18f1df55fcb0804e2303eb3&quot;,
#                 {
#                     center: [-7.53, -9.12],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2947d50f4c98d419718aa50759d03d45 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2947d50f4c98d419718aa50759d03d45.addTo(map_736c6036b18f1df55fcb0804e2303eb3);
#
#
#             var marker_cluster_73e170f4b38511a1551053a8aa1e3616 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_73e170f4b38511a1551053a8aa1e3616.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_87a7cd8e2e2ded779bbb8474ea823eac = L.marker(
#                 [-12.0, -119.0],
#                 {}
#             ).addTo(marker_cluster_73e170f4b38511a1551053a8aa1e3616);
#
#
#         var popup_5e58b1f4e0853e13d0972fe83d2ab934 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1fecc5124f27bcd80a0206f129ef6773 = $(`&lt;div id=&quot;html_1fecc5124f27bcd80a0206f129ef6773&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-119&lt;br&gt;lat:-12&lt;/div&gt;`)[0];
#                 popup_5e58b1f4e0853e13d0972fe83d2ab934.setContent(html_1fecc5124f27bcd80a0206f129ef6773);
#
#
#
#         marker_87a7cd8e2e2ded779bbb8474ea823eac.bindPopup(popup_5e58b1f4e0853e13d0972fe83d2ab934)
#         ;
#
#
#
#
#             var marker_5b68cb0c2d6c62b56895d733f7673836 = L.marker(
#                 [13.0, -81.0],
#                 {}
#             ).addTo(marker_cluster_73e170f4b38511a1551053a8aa1e3616);
#
#
#         var popup_8f2bbd2dbcdd2b6648bbf8bc4fe95869 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f08d175034b58bce39aa3aaba4d05bf4 = $(`&lt;div id=&quot;html_f08d175034b58bce39aa3aaba4d05bf4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-81&lt;br&gt;lat:13&lt;/div&gt;`)[0];
#                 popup_8f2bbd2dbcdd2b6648bbf8bc4fe95869.setContent(html_f08d175034b58bce39aa3aaba4d05bf4);
#
#
#
#         marker_5b68cb0c2d6c62b56895d733f7673836.bindPopup(popup_8f2bbd2dbcdd2b6648bbf8bc4fe95869)
#         ;
#
#
#
#
#             var marker_cf11ceae428f4fe378d7f6a485ce0f7e = L.marker(
#                 [23.0, -39.0],
#                 {}
#             ).addTo(marker_cluster_73e170f4b38511a1551053a8aa1e3616);
#
#
#         var popup_8653ef290147998d464481a0f135716c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b260f1c345b210fdc97949bdf228aed2 = $(`&lt;div id=&quot;html_b260f1c345b210fdc97949bdf228aed2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-39&lt;br&gt;lat:23&lt;/div&gt;`)[0];
#                 popup_8653ef290147998d464481a0f135716c.setContent(html_b260f1c345b210fdc97949bdf228aed2);
#
#
#
#         marker_cf11ceae428f4fe378d7f6a485ce0f7e.bindPopup(popup_8653ef290147998d464481a0f135716c)
#         ;
#
#
#
#
#             var marker_bc29bd1f8df04a3291c515c7398f499b = L.marker(
#                 [-70.0, 56.0],
#                 {}
#             ).addTo(marker_cluster_73e170f4b38511a1551053a8aa1e3616);
#
#
#         var popup_73dab2cb3a9f206a304b67a02441787c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0295f18def4bcef700575ad8b7a2bce = $(`&lt;div id=&quot;html_c0295f18def4bcef700575ad8b7a2bce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:56&lt;br&gt;lat:-70&lt;/div&gt;`)[0];
#                 popup_73dab2cb3a9f206a304b67a02441787c.setContent(html_c0295f18def4bcef700575ad8b7a2bce);
#
#
#
#         marker_bc29bd1f8df04a

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d830325a9867eb36f82d3c8d91796473 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d830325a9867eb36f82d3c8d91796473&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d830325a9867eb36f82d3c8d91796473 = L.map(
#                 &quot;map_d830325a9867eb36f82d3c8d91796473&quot;,
#                 {
#                     center: [-7.53, -9.12],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b7947b76b2e529e0bb1dfc33b59aa9d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6b7947b76b2e529e0bb1dfc33b59aa9d.addTo(map_d830325a9867eb36f82d3c8d91796473);
#
#
#             var marker_cluster_a7127b75eb7e0728e5209b4e20831d63 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_60b8c33a78855fc11d1a9970850c3caa = L.marker(
#                 [-12.0, -119.0],
#                 {}
#             ).addTo(marker_cluster_a7127b75eb7e0728e5209b4e20831d63);
#
#
#         var popup_18b0b287043f675845d1a2982f57e118 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c21d85dd96a334e631df4826f6832bf5 = $(`&lt;div id=&quot;html_c21d85dd96a334e631df4826f6832bf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-119&lt;br&gt;lat:-12&lt;/div&gt;`)[0];
#                 popup_18b0b287043f675845d1a2982f57e118.setContent(html_c21d85dd96a334e631df4826f6832bf5);
#
#
#
#         marker_60b8c33a78855fc11d1a9970850c3caa.bindPopup(popup_18b0b287043f675845d1a2982f57e118)
#         ;
#
#
#
#
#             var marker_78ba69a00fff1a0c5a3e724134c535b4 = L.marker(
#                 [13.0, -81.0],
#                 {}
#             ).addTo(marker_cluster_a7127b75eb7e0728e5209b4e20831d63);
#
#
#         var popup_d099db3b8e97179b6ecee97dcbf8d8f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2912cc2224c8fff666651dc5b40b8a9a = $(`&lt;div id=&quot;html_2912cc2224c8fff666651dc5b40b8a9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-81&lt;br&gt;lat:13&lt;/div&gt;`)[0];
#                 popup_d099db3b8e97179b6ecee97dcbf8d8f3.setContent(html_2912cc2224c8fff666651dc5b40b8a9a);
#
#
#
#         marker_78ba69a00fff1a0c5a3e724134c535b4.bindPopup(popup_d099db3b8e97179b6ecee97dcbf8d8f3)
#         ;
#
#
#
#
#             var marker_d03dd4a2183f8c0e08693adfaf023bc3 = L.marker(
#                 [23.0, -39.0],
#                 {}
#             ).addTo(marker_cluster_a7127b75eb7e0728e5209b4e20831d63);
#
#
#         var popup_76c52e991ef4050a64aca5c2f757e0c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_69b3f0c33fd5499ca71c2896603e8f23 = $(`&lt;div id=&quot;html_69b3f0c33fd5499ca71c2896603e8f23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-39&lt;br&gt;lat:23&lt;/div&gt;`)[0];
#                 popup_76c52e991ef4050a64aca5c2f757e0c4.setContent(html_69b3f0c33fd5499ca71c2896603e8f23);
#
#
#
#         marker_d03dd4a2183f8c0e08693adfaf023bc3.bindPopup(popup_76c52e991ef4050a64aca5c2f757e0c4)
#         ;
#
#
#
#
#             var marker_ff43f1057eb0a720e17a4a9cfeb32a7e = L.marker(
#                 [-70.0, 56.0],
#                 {}
#             ).addTo(marker_cluster_a7127b75eb7e0728e5209b4e20831d63);
#
#
#         var popup_aeb8233c607a2a3c963fe3c6910ae618 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4b92a752d41b43239fab5645d26e5eda = $(`&lt;div id=&quot;html_4b92a752d41b43239fab5645d26e5eda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:56&lt;br&gt;lat:-70&lt;/div&gt;`)[0];
#                 popup_aeb8233c607a2a3c963fe3c6910ae618.setContent(html_4b92a752d41b43239fab5645d26e5eda);
#
#
#
#         marker_ff43f1057eb0a720e17a4a9cfeb32a7e.bindPopup(popup_aeb8233c607a2a3c963fe3c6910ae618)
#         ;
#
#
#
#
#             var marker_8de2390cff0d9b518c44a0e46e1443d2 = L.marker(
#                 [61.0, 24.0],
#                 {}
#             ).addTo(marker_cluster_a7127b75eb7e0728e5209b4e20831d63);
#
#
#         var popup_e2fc70c95111dc34b79f288

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8385c259b79af4360d40a6b0bfbd5d16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8385c259b79af4360d40a6b0bfbd5d16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8385c259b79af4360d40a6b0bfbd5d16 = L.map(
#                 &quot;map_8385c259b79af4360d40a6b0bfbd5d16&quot;,
#                 {
#                     center: [-7.53, -9.12],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6528dceb0cb52343d73316f5cda16f86 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6528dceb0cb52343d73316f5cda16f86.addTo(map_8385c259b79af4360d40a6b0bfbd5d16);
#
#
#             var fast_marker_cluster_c6140416eda169fd429687977e5cf445 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[-12.0, -119.0], [13.0, -81.0], [23.0, -39.0], [-70.0, 56.0], [61.0, 24.0], [3.0, 173.0], [-15.0, -27.0], [77.0, -169.0], [-87.0, 127.0], [-53.0, 2.0], [44.0, 65.0], [-86.0, -84.0], [72.0, 40.0], [-68.0, -168.0], [-85.0, 152.0], [74.0, -21.0], [-83.0, 104.0], [26.0, 71.0], [-61.0, 121.0], [13.0, -43.0], [-12.0, -45.0], [22.0, -29.0], [69.0, -98.0], [24.0, 81.0], [-24.0, -47.0], [-21.0, -174.0], [-82.0, -35.0], [-34.0, -128.0], [11.0, -163.0], [-34.0, -57.0], [3.0, 3.0], [35.0, -162.0], [-7.0, 28.0], [-28.0, -20.0], [-52.0, -29.0], [-52.0, -164.0], [-81.0, -55.0], [-7.0, 88.0], [44.0, 145.0], [53.0, 164.0], [-23.0, -115.0], [-60.0, -153.0], [-76.0, -67.0], [-82.0, 163.0], [14.0, 1.0], [-83.0, -131.0], [-88.0, 27.0], [18.0, -119.0], [-21.0, -43.0], [27.0, 47.0], [87.0, -121.0], [-56.0, -96.0], [49.0, 114.0], [-28.0, 101.0], [-30.0, 144.0], [83.0, -81.0], [-18.0, -162.0], [-32.0, -33.0], [31.0, -69.0], [39.0, 6.0], [55.0, -65.0], [-90.0, -107.0], [76.0, -133.0], [22.0, -92.0], [26.0, 16.0], [-58.0, 146.0], [73.0, 160.0], [64.0, 112.0], [-10.0, -67.0], [51.0, -45.0], [77.0, 73.0], [62.0, -131.0], [-2.0, 130.0], [22.0, -129.0], [13.0, -44.0], [38.0, 176.0], [21.0, -28.0], [56.0, -177.0], [-27.0, 143.0], [52.0, -6.0], [-57.0, 23.0], [-79.0, 62.0], [-88.0, -123.0], [-29.0, 13.0], [-44.0, -104.0], [21.0, 174.0], [46.0, 63.0], [-74.0, 16.0], [-10.0, -173.0], [79.0, -113.0], [-25.0, 98.0], [-32.0, 90.0], [-43.0, 89.0], [-78.0, 109.0], [-4.0, 85.0], [-64.0, 77.0], [-24.0, 9.0], [-82.0, -146.0], [-46.0, 116.0], [-5.0, -109.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_8385c259b79af4360d40a6b0bfbd5d16);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_c6140416eda169fd429687977e5cf445.addTo(map_8385c259b79af4360d40a6b0bfbd5d16);
#
#
#             var layer_control_df139d80aa5e08f64bb0648ef9b92d5f_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_6528dceb0cb52343d73316f5cda16f86,
#                 },
#                 overlays :  {
#                     &quot;macro_element_c6140416eda169fd429687977e5cf445&quot; : fast_marker_cluster_c6140416eda169fd429687977e5cf445,
#                 },
#             };
#             let layer_control_df139d80aa5e08f64bb0648ef9b92d5f = L.control.layers(
#                 layer_control_df139d80aa5e08f64bb0648ef9b92d5f_layers.base_layers,
#                 layer_control_df139d80aa5e08f64bb0648ef9b92d5f_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_8385c259b79af4360d40a6b0bfbd5d16);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ec52f54fc2b115f70e273bc380bbb30 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ec52f54fc2b115f70e273bc380bbb30&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ec52f54fc2b115f70e273bc380bbb30 = L.map(
#                 &quot;map_8ec52f54fc2b115f70e273bc380bbb30&quot;,
#                 {
#                     center: [-7.53, -9.12],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9a84d6bb639046513cd082107cf6220 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f9a84d6bb639046513cd082107cf6220.addTo(map_8ec52f54fc2b115f70e273bc380bbb30);
#
#
#             var fast_marker_cluster_40f30eec9d4366fca5fa98cbcadff506 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[-12.0, -119.0], [13.0, -81.0], [23.0, -39.0], [-70.0, 56.0], [61.0, 24.0], [3.0, 173.0], [-15.0, -27.0], [77.0, -169.0], [-87.0, 127.0], [-53.0, 2.0], [44.0, 65.0], [-86.0, -84.0], [72.0, 40.0], [-68.0, -168.0], [-85.0, 152.0], [74.0, -21.0], [-83.0, 104.0], [26.0, 71.0], [-61.0, 121.0], [13.0, -43.0], [-12.0, -45.0], [22.0, -29.0], [69.0, -98.0], [24.0, 81.0], [-24.0, -47.0], [-21.0, -174.0], [-82.0, -35.0], [-34.0, -128.0], [11.0, -163.0], [-34.0, -57.0], [3.0, 3.0], [35.0, -162.0], [-7.0, 28.0], [-28.0, -20.0], [-52.0, -29.0], [-52.0, -164.0], [-81.0, -55.0], [-7.0, 88.0], [44.0, 145.0], [53.0, 164.0], [-23.0, -115.0], [-60.0, -153.0], [-76.0, -67.0], [-82.0, 163.0], [14.0, 1.0], [-83.0, -131.0], [-88.0, 27.0], [18.0, -119.0], [-21.0, -43.0], [27.0, 47.0], [87.0, -121.0], [-56.0, -96.0], [49.0, 114.0], [-28.0, 101.0], [-30.0, 144.0], [83.0, -81.0], [-18.0, -162.0], [-32.0, -33.0], [31.0, -69.0], [39.0, 6.0], [55.0, -65.0], [-90.0, -107.0], [76.0, -133.0], [22.0, -92.0], [26.0, 16.0], [-58.0, 146.0], [73.0, 160.0], [64.0, 112.0], [-10.0, -67.0], [51.0, -45.0], [77.0, 73.0], [62.0, -131.0], [-2.0, 130.0], [22.0, -129.0], [13.0, -44.0], [38.0, 176.0], [21.0, -28.0], [56.0, -177.0], [-27.0, 143.0], [52.0, -6.0], [-57.0, 23.0], [-79.0, 62.0], [-88.0, -123.0], [-29.0, 13.0], [-44.0, -104.0], [21.0, 174.0], [46.0, 63.0], [-74.0, 16.0], [-10.0, -173.0], [79.0, -113.0], [-25.0, 98.0], [-32.0, 90.0], [-43.0, 89.0], [-78.0, 109.0], [-4.0, 85.0], [-64.0, 77.0], [-24.0, 9.0], [-82.0, -146.0], [-46.0, 116.0], [-5.0, -109.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_8ec52f54fc2b115f70e273bc380bbb30);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_40f30eec9d4366fca5fa98cbcadff506.addTo(map_8ec52f54fc2b115f70e273bc380bbb30);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
