# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bd46a01db3d519123817cb7a79acab0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bd46a01db3d519123817cb7a79acab0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bd46a01db3d519123817cb7a79acab0 = L.map(
#                 &quot;map_4bd46a01db3d519123817cb7a79acab0&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d37101fef519288fd473125eb8427fe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1d37101fef519288fd473125eb8427fe.addTo(map_4bd46a01db3d519123817cb7a79acab0);
#
#
#             var marker_cluster_5c1578b4ecb81c047df7a0cb4659737e = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_58d410e6583eeb0c55b3c5f9a2751961 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_5c1578b4ecb81c047df7a0cb4659737e);
#
#
#             var icon_9facd8586114580e9a2db06b6da6b079 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_58d410e6583eeb0c55b3c5f9a2751961.setIcon(icon_9facd8586114580e9a2db06b6da6b079);
#
#
#         var popup_fd49dc1835ada61823561dc22125ce20 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8cd5db2908d4df9099e0c4dfa8d6b31a = $(`&lt;div id=&quot;html_8cd5db2908d4df9099e0c4dfa8d6b31a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_fd49dc1835ada61823561dc22125ce20.setContent(html_8cd5db2908d4df9099e0c4dfa8d6b31a);
#
#
#
#         marker_58d410e6583eeb0c55b3c5f9a2751961.bindPopup(popup_fd49dc1835ada61823561dc22125ce20)
#         ;
#
#
#
#
#             var marker_9e261c70f847d19d70dd85377c99519e = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_5c1578b4ecb81c047df7a0cb4659737e);
#
#
#             var icon_c0a8736b30b0bcd2963bd2e3a628bf83 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9e261c70f847d19d70dd85377c99519e.setIcon(icon_c0a8736b30b0bcd2963bd2e3a628bf83);
#
#
#         var popup_e18d497384dec18ec1c6f87a42eba6ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12372e7f2d318360dc4e503bc5173cc3 = $(`&lt;div id=&quot;html_12372e7f2d318360dc4e503bc5173cc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_e18d497384dec18ec1c6f87a42eba6ba.setContent(html_12372e7f2d318360dc4e503bc5173cc3);
#
#
#
#         marker_9e261c70f847d19d70dd85377c99519e.bindPopup(popup_e18d497384dec18ec1c6f87a42eba6ba)
#         ;
#
#
#
#
#             var marker_430bd563d3760d984ab0a31718db126d = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_5c1578b4ecb81c047df7a0cb4659737e);
#
#
#         var popup_0da0cc1539d0973061c5687151b20ceb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_63f880060002c4704e9b76cadb46486b = $(`&lt;div id=&quot;html_63f880060002c4704e9b76cadb46486b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_0da0cc1539d0973061c5687151b20ceb.setContent(html_63f880060002c4704e9b76cadb46486b);
#
#
#
#         marker_430bd563d3760d984ab0a31718db126d.bindPopup(popup_0da0cc1539d0973061c5687151b20ceb)
#         ;
#
#
#
#
#             marker_cluster_5c1578b4ecb81c047df7a0cb4659737e.addTo(map_4bd46a01db3d519123817cb7a79acab0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98004955ced2673768f1ea34ccb5b1ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98004955ced2673768f1ea34ccb5b1ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98004955ced2673768f1ea34ccb5b1ed = L.map(
#                 &quot;map_98004955ced2673768f1ea34ccb5b1ed&quot;,
#                 {
#                     center: [1.96, 8.34],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aaf9784e85257407c3be389ee457f70c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_aaf9784e85257407c3be389ee457f70c.addTo(map_98004955ced2673768f1ea34ccb5b1ed);
#
#
#             var marker_cluster_3b95f60f16ef4d3ec85da91b3dae8f06 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_3b95f60f16ef4d3ec85da91b3dae8f06.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_e80a2669b056950564880794ff14dfdb = L.marker(
#                 [44.0, 49.0],
#                 {}
#             ).addTo(marker_cluster_3b95f60f16ef4d3ec85da91b3dae8f06);
#
#
#         var popup_a1a447f9382557d7dd2cfea0c2a90821 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8488d8aefb0cf43a12c6a690a6492149 = $(`&lt;div id=&quot;html_8488d8aefb0cf43a12c6a690a6492149&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:49&lt;br&gt;lat:44&lt;/div&gt;`)[0];
#                 popup_a1a447f9382557d7dd2cfea0c2a90821.setContent(html_8488d8aefb0cf43a12c6a690a6492149);
#
#
#
#         marker_e80a2669b056950564880794ff14dfdb.bindPopup(popup_a1a447f9382557d7dd2cfea0c2a90821)
#         ;
#
#
#
#
#             var marker_534fdab486b123c2ad63fa0c38419713 = L.marker(
#                 [50.0, -46.0],
#                 {}
#             ).addTo(marker_cluster_3b95f60f16ef4d3ec85da91b3dae8f06);
#
#
#         var popup_7c707194b82f341ab13f3fb755ce3070 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5aae378f4a0efb8f1015aa2b2967d01 = $(`&lt;div id=&quot;html_c5aae378f4a0efb8f1015aa2b2967d01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-46&lt;br&gt;lat:50&lt;/div&gt;`)[0];
#                 popup_7c707194b82f341ab13f3fb755ce3070.setContent(html_c5aae378f4a0efb8f1015aa2b2967d01);
#
#
#
#         marker_534fdab486b123c2ad63fa0c38419713.bindPopup(popup_7c707194b82f341ab13f3fb755ce3070)
#         ;
#
#
#
#
#             var marker_5d4f262efc86d5a27d84a227cb2be2da = L.marker(
#                 [45.0, -176.0],
#                 {}
#             ).addTo(marker_cluster_3b95f60f16ef4d3ec85da91b3dae8f06);
#
#
#         var popup_e8a6f8e614fec2107e902e13d14a35be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d668901b18395cafa333a26c52dec1fb = $(`&lt;div id=&quot;html_d668901b18395cafa333a26c52dec1fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-176&lt;br&gt;lat:45&lt;/div&gt;`)[0];
#                 popup_e8a6f8e614fec2107e902e13d14a35be.setContent(html_d668901b18395cafa333a26c52dec1fb);
#
#
#
#         marker_5d4f262efc86d5a27d84a227cb2be2da.bindPopup(popup_e8a6f8e614fec2107e902e13d14a35be)
#         ;
#
#
#
#
#             var marker_e04239a15a5b5fcd3749c90099aef05b = L.marker(
#                 [-56.0, -72.0],
#                 {}
#             ).addTo(marker_cluster_3b95f60f16ef4d3ec85da91b3dae8f06);
#
#
#         var popup_f2f4c4957fdb3ba45bbb40d6e9025c49 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_23c69cdcc37b01ff01289ef7ce5b4e22 = $(`&lt;div id=&quot;html_23c69cdcc37b01ff01289ef7ce5b4e22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-72&lt;br&gt;lat:-56&lt;/div&gt;`)[0];
#                 popup_f2f4c4957fdb3ba45bbb40d6e9025c49.setContent(html_23c69cdcc37b01ff01289ef7ce5b4e22);
#
#
#
#         marker_e04239a15a5b5fcd37

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d8bc0f6d8ec976be7ea3680d1233029 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d8bc0f6d8ec976be7ea3680d1233029&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d8bc0f6d8ec976be7ea3680d1233029 = L.map(
#                 &quot;map_6d8bc0f6d8ec976be7ea3680d1233029&quot;,
#                 {
#                     center: [1.96, 8.34],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7852be70c5f49416a4d23502f35fcaee = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7852be70c5f49416a4d23502f35fcaee.addTo(map_6d8bc0f6d8ec976be7ea3680d1233029);
#
#
#             var marker_cluster_e79cd02d6ce35842873e8f3266fb78af = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_149161824e9e7662c2fe85d87df8b169 = L.marker(
#                 [44.0, 49.0],
#                 {}
#             ).addTo(marker_cluster_e79cd02d6ce35842873e8f3266fb78af);
#
#
#         var popup_464c2c858f69d1d5db1cd4d2fd1c68c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_acfc2ad1e0c27749429a90f87e5047b1 = $(`&lt;div id=&quot;html_acfc2ad1e0c27749429a90f87e5047b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:49&lt;br&gt;lat:44&lt;/div&gt;`)[0];
#                 popup_464c2c858f69d1d5db1cd4d2fd1c68c5.setContent(html_acfc2ad1e0c27749429a90f87e5047b1);
#
#
#
#         marker_149161824e9e7662c2fe85d87df8b169.bindPopup(popup_464c2c858f69d1d5db1cd4d2fd1c68c5)
#         ;
#
#
#
#
#             var marker_f9287de93f96dfefd25ec8969ef51921 = L.marker(
#                 [50.0, -46.0],
#                 {}
#             ).addTo(marker_cluster_e79cd02d6ce35842873e8f3266fb78af);
#
#
#         var popup_b99e0c68b742296de0b4f341fbffd5fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fff579dea5ba442b66f3278e54276fe0 = $(`&lt;div id=&quot;html_fff579dea5ba442b66f3278e54276fe0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-46&lt;br&gt;lat:50&lt;/div&gt;`)[0];
#                 popup_b99e0c68b742296de0b4f341fbffd5fa.setContent(html_fff579dea5ba442b66f3278e54276fe0);
#
#
#
#         marker_f9287de93f96dfefd25ec8969ef51921.bindPopup(popup_b99e0c68b742296de0b4f341fbffd5fa)
#         ;
#
#
#
#
#             var marker_4653ec6e8b19256f10c05ab4ce56cf98 = L.marker(
#                 [45.0, -176.0],
#                 {}
#             ).addTo(marker_cluster_e79cd02d6ce35842873e8f3266fb78af);
#
#
#         var popup_613c7ea8152060e61d85d591517ea9a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3c4b878b753b65ca0f01652d29f6a396 = $(`&lt;div id=&quot;html_3c4b878b753b65ca0f01652d29f6a396&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-176&lt;br&gt;lat:45&lt;/div&gt;`)[0];
#                 popup_613c7ea8152060e61d85d591517ea9a2.setContent(html_3c4b878b753b65ca0f01652d29f6a396);
#
#
#
#         marker_4653ec6e8b19256f10c05ab4ce56cf98.bindPopup(popup_613c7ea8152060e61d85d591517ea9a2)
#         ;
#
#
#
#
#             var marker_f047ddafda5a3de6e9b6d294b53567ef = L.marker(
#                 [-56.0, -72.0],
#                 {}
#             ).addTo(marker_cluster_e79cd02d6ce35842873e8f3266fb78af);
#
#
#         var popup_3f4a7c67c3c5b56ec26aa3bfc32332d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f854d863622dc5a1258aeefd477cda94 = $(`&lt;div id=&quot;html_f854d863622dc5a1258aeefd477cda94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-72&lt;br&gt;lat:-56&lt;/div&gt;`)[0];
#                 popup_3f4a7c67c3c5b56ec26aa3bfc32332d6.setContent(html_f854d863622dc5a1258aeefd477cda94);
#
#
#
#         marker_f047ddafda5a3de6e9b6d294b53567ef.bindPopup(popup_3f4a7c67c3c5b56ec26aa3bfc32332d6)
#         ;
#
#
#
#
#             var marker_355fae9e5992ce288413b30b10210b98 = L.marker(
#                 [57.0, 55.0],
#                 {}
#             ).addTo(marker_cluster_e79cd02d6ce35842873e8f3266fb78af);
#
#
#         var popup_59fc5ef10de7214ca2d85657230

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb43572aca88cb2437592742001110c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb43572aca88cb2437592742001110c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb43572aca88cb2437592742001110c3 = L.map(
#                 &quot;map_fb43572aca88cb2437592742001110c3&quot;,
#                 {
#                     center: [1.96, 8.34],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7bcd3953ef8a8121a3ab8a5eece45303 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7bcd3953ef8a8121a3ab8a5eece45303.addTo(map_fb43572aca88cb2437592742001110c3);
#
#
#             var fast_marker_cluster_53b55376facc8f5bea0de4ed355ce8d6 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[44.0, 49.0], [50.0, -46.0], [45.0, -176.0], [-56.0, -72.0], [57.0, 55.0], [53.0, -154.0], [-74.0, 129.0], [-64.0, -73.0], [-86.0, 150.0], [25.0, -68.0], [39.0, 6.0], [16.0, 150.0], [17.0, -159.0], [18.0, -1.0], [-20.0, -136.0], [6.0, 83.0], [-7.0, 78.0], [67.0, 157.0], [-71.0, -131.0], [37.0, 108.0], [19.0, 136.0], [-37.0, 64.0], [-1.0, 133.0], [83.0, -166.0], [-19.0, -84.0], [36.0, 114.0], [50.0, 112.0], [26.0, 53.0], [-57.0, 38.0], [83.0, 155.0], [74.0, 157.0], [-17.0, 112.0], [2.0, 163.0], [-38.0, -57.0], [-77.0, 34.0], [10.0, -29.0], [51.0, -133.0], [17.0, -59.0], [-41.0, -145.0], [64.0, 86.0], [4.0, -130.0], [57.0, 75.0], [-8.0, 71.0], [16.0, -95.0], [-3.0, -48.0], [12.0, -144.0], [-60.0, 102.0], [27.0, -113.0], [-3.0, 71.0], [87.0, -160.0], [77.0, -93.0], [-47.0, 150.0], [79.0, 61.0], [-15.0, 146.0], [-88.0, -23.0], [1.0, -166.0], [64.0, 101.0], [-26.0, 167.0], [39.0, 21.0], [-45.0, 107.0], [30.0, 5.0], [55.0, -34.0], [85.0, 33.0], [-80.0, -66.0], [-77.0, -86.0], [11.0, -38.0], [-59.0, 78.0], [-46.0, -88.0], [-86.0, -173.0], [67.0, 66.0], [-16.0, -34.0], [-75.0, -11.0], [30.0, -116.0], [-7.0, 124.0], [29.0, -73.0], [-20.0, 119.0], [3.0, 8.0], [63.0, 9.0], [-89.0, 158.0], [-72.0, -1.0], [-17.0, -120.0], [84.0, 155.0], [-61.0, 13.0], [-79.0, -13.0], [-55.0, -94.0], [-88.0, -81.0], [-30.0, 125.0], [83.0, 37.0], [-36.0, 88.0], [25.0, -123.0], [-26.0, 142.0], [31.0, 117.0], [82.0, 39.0], [26.0, -11.0], [85.0, 18.0], [-77.0, 77.0], [-29.0, 44.0], [75.0, -41.0], [23.0, -90.0], [-58.0, -61.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_fb43572aca88cb2437592742001110c3);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_53b55376facc8f5bea0de4ed355ce8d6.addTo(map_fb43572aca88cb2437592742001110c3);
#
#
#             var layer_control_bf55702b5984645a3650fe77c7a088fd_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_7bcd3953ef8a8121a3ab8a5eece45303,
#                 },
#                 overlays :  {
#                     &quot;macro_element_53b55376facc8f5bea0de4ed355ce8d6&quot; : fast_marker_cluster_53b55376facc8f5bea0de4ed355ce8d6,
#                 },
#             };
#             let layer_control_bf55702b5984645a3650fe77c7a088fd = L.control.layers(
#                 layer_control_bf55702b5984645a3650fe77c7a088fd_layers.base_layers,
#                 layer_control_bf55702b5984645a3650fe77c7a088fd_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_fb43572aca88cb2437592742001110c3);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e7054cbb06674f7e1b3757a064c68b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e7054cbb06674f7e1b3757a064c68b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e7054cbb06674f7e1b3757a064c68b3 = L.map(
#                 &quot;map_2e7054cbb06674f7e1b3757a064c68b3&quot;,
#                 {
#                     center: [1.96, 8.34],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_95d9fef6fa0b18d93024d4adaea8c277 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_95d9fef6fa0b18d93024d4adaea8c277.addTo(map_2e7054cbb06674f7e1b3757a064c68b3);
#
#
#             var fast_marker_cluster_63de09bcb5400690fccbda9068b987bf = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[44.0, 49.0], [50.0, -46.0], [45.0, -176.0], [-56.0, -72.0], [57.0, 55.0], [53.0, -154.0], [-74.0, 129.0], [-64.0, -73.0], [-86.0, 150.0], [25.0, -68.0], [39.0, 6.0], [16.0, 150.0], [17.0, -159.0], [18.0, -1.0], [-20.0, -136.0], [6.0, 83.0], [-7.0, 78.0], [67.0, 157.0], [-71.0, -131.0], [37.0, 108.0], [19.0, 136.0], [-37.0, 64.0], [-1.0, 133.0], [83.0, -166.0], [-19.0, -84.0], [36.0, 114.0], [50.0, 112.0], [26.0, 53.0], [-57.0, 38.0], [83.0, 155.0], [74.0, 157.0], [-17.0, 112.0], [2.0, 163.0], [-38.0, -57.0], [-77.0, 34.0], [10.0, -29.0], [51.0, -133.0], [17.0, -59.0], [-41.0, -145.0], [64.0, 86.0], [4.0, -130.0], [57.0, 75.0], [-8.0, 71.0], [16.0, -95.0], [-3.0, -48.0], [12.0, -144.0], [-60.0, 102.0], [27.0, -113.0], [-3.0, 71.0], [87.0, -160.0], [77.0, -93.0], [-47.0, 150.0], [79.0, 61.0], [-15.0, 146.0], [-88.0, -23.0], [1.0, -166.0], [64.0, 101.0], [-26.0, 167.0], [39.0, 21.0], [-45.0, 107.0], [30.0, 5.0], [55.0, -34.0], [85.0, 33.0], [-80.0, -66.0], [-77.0, -86.0], [11.0, -38.0], [-59.0, 78.0], [-46.0, -88.0], [-86.0, -173.0], [67.0, 66.0], [-16.0, -34.0], [-75.0, -11.0], [30.0, -116.0], [-7.0, 124.0], [29.0, -73.0], [-20.0, 119.0], [3.0, 8.0], [63.0, 9.0], [-89.0, 158.0], [-72.0, -1.0], [-17.0, -120.0], [84.0, 155.0], [-61.0, 13.0], [-79.0, -13.0], [-55.0, -94.0], [-88.0, -81.0], [-30.0, 125.0], [83.0, 37.0], [-36.0, 88.0], [25.0, -123.0], [-26.0, 142.0], [31.0, 117.0], [82.0, 39.0], [26.0, -11.0], [85.0, 18.0], [-77.0, 77.0], [-29.0, 44.0], [75.0, -41.0], [23.0, -90.0], [-58.0, -61.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_2e7054cbb06674f7e1b3757a064c68b3);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_63de09bcb5400690fccbda9068b987bf.addTo(map_2e7054cbb06674f7e1b3757a064c68b3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
