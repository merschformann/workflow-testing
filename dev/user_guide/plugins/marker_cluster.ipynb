# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f61d2bae2d0d8d266ecdb7b76152a2d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f61d2bae2d0d8d266ecdb7b76152a2d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f61d2bae2d0d8d266ecdb7b76152a2d5 = L.map(
#                 &quot;map_f61d2bae2d0d8d266ecdb7b76152a2d5&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba6cfec654168f8807bc403fb869f6bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ba6cfec654168f8807bc403fb869f6bf.addTo(map_f61d2bae2d0d8d266ecdb7b76152a2d5);
#
#
#             var marker_cluster_2fe182f23d5698bbbf0c858b1d73babd = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_c45ed95bbc538daab5c5bb888b81a957 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_2fe182f23d5698bbbf0c858b1d73babd);
#
#
#             var icon_ddabec9e59fec56cddb199773b322bea = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c45ed95bbc538daab5c5bb888b81a957.setIcon(icon_ddabec9e59fec56cddb199773b322bea);
#
#
#         var popup_27f1587ee57830cf43239b955f91a916 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b9b7f296ad0fb63d8f328977b0feaf99 = $(`&lt;div id=&quot;html_b9b7f296ad0fb63d8f328977b0feaf99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_27f1587ee57830cf43239b955f91a916.setContent(html_b9b7f296ad0fb63d8f328977b0feaf99);
#
#
#
#         marker_c45ed95bbc538daab5c5bb888b81a957.bindPopup(popup_27f1587ee57830cf43239b955f91a916)
#         ;
#
#
#
#
#             var marker_a41e2fa661b9b36037cab015f14f601c = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_2fe182f23d5698bbbf0c858b1d73babd);
#
#
#             var icon_0520eb9bde9543195c71c02db8c4ac49 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a41e2fa661b9b36037cab015f14f601c.setIcon(icon_0520eb9bde9543195c71c02db8c4ac49);
#
#
#         var popup_315af3b448acb0de423d7604228c26fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ffe7a052346e06ed45ae4f2f16fc3717 = $(`&lt;div id=&quot;html_ffe7a052346e06ed45ae4f2f16fc3717&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_315af3b448acb0de423d7604228c26fa.setContent(html_ffe7a052346e06ed45ae4f2f16fc3717);
#
#
#
#         marker_a41e2fa661b9b36037cab015f14f601c.bindPopup(popup_315af3b448acb0de423d7604228c26fa)
#         ;
#
#
#
#
#             var marker_65fc330e2c073f1d82000ff27ed4b5de = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_2fe182f23d5698bbbf0c858b1d73babd);
#
#
#         var popup_f287516f9748292d0cb54d316748332f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5777fbe578e13245c78bf3bfbec49d62 = $(`&lt;div id=&quot;html_5777fbe578e13245c78bf3bfbec49d62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_f287516f9748292d0cb54d316748332f.setContent(html_5777fbe578e13245c78bf3bfbec49d62);
#
#
#
#         marker_65fc330e2c073f1d82000ff27ed4b5de.bindPopup(popup_f287516f9748292d0cb54d316748332f)
#         ;
#
#
#
#
#             marker_cluster_2fe182f23d5698bbbf0c858b1d73babd.addTo(map_f61d2bae2d0d8d266ecdb7b76152a2d5);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d62ffb747c300b109f731180cb1c50c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d62ffb747c300b109f731180cb1c50c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d62ffb747c300b109f731180cb1c50c6 = L.map(
#                 &quot;map_d62ffb747c300b109f731180cb1c50c6&quot;,
#                 {
#                     center: [0.58, -21.53],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_866c40573f5cbf00c5ee515b58264cea = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_866c40573f5cbf00c5ee515b58264cea.addTo(map_d62ffb747c300b109f731180cb1c50c6);
#
#
#             var marker_cluster_838beb72f022631884328e685720d3e1 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_838beb72f022631884328e685720d3e1.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_3459729ff79baba7d164b85f4a0c7af6 = L.marker(
#                 [-11.0, 160.0],
#                 {}
#             ).addTo(marker_cluster_838beb72f022631884328e685720d3e1);
#
#
#         var popup_689e62238391d337d0038e673c433949 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3f341a01e26bf290e54f868235843b0 = $(`&lt;div id=&quot;html_b3f341a01e26bf290e54f868235843b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:160&lt;br&gt;lat:-11&lt;/div&gt;`)[0];
#                 popup_689e62238391d337d0038e673c433949.setContent(html_b3f341a01e26bf290e54f868235843b0);
#
#
#
#         marker_3459729ff79baba7d164b85f4a0c7af6.bindPopup(popup_689e62238391d337d0038e673c433949)
#         ;
#
#
#
#
#             var marker_36fba9e28e25166a5edba3911eb03e12 = L.marker(
#                 [3.0, -119.0],
#                 {}
#             ).addTo(marker_cluster_838beb72f022631884328e685720d3e1);
#
#
#         var popup_aa6cafcca4c267ccf7a7305dd2e3a82f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e73e2dd0a72b74a63c88475ae10edb94 = $(`&lt;div id=&quot;html_e73e2dd0a72b74a63c88475ae10edb94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-119&lt;br&gt;lat:3&lt;/div&gt;`)[0];
#                 popup_aa6cafcca4c267ccf7a7305dd2e3a82f.setContent(html_e73e2dd0a72b74a63c88475ae10edb94);
#
#
#
#         marker_36fba9e28e25166a5edba3911eb03e12.bindPopup(popup_aa6cafcca4c267ccf7a7305dd2e3a82f)
#         ;
#
#
#
#
#             var marker_3d4644acdbba5ae7ee455faf5c75e82c = L.marker(
#                 [-12.0, -80.0],
#                 {}
#             ).addTo(marker_cluster_838beb72f022631884328e685720d3e1);
#
#
#         var popup_3c1909bd3d6e4553f9aa24cd74ee16a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_749f653089db6ec8f55edccbecff8289 = $(`&lt;div id=&quot;html_749f653089db6ec8f55edccbecff8289&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-80&lt;br&gt;lat:-12&lt;/div&gt;`)[0];
#                 popup_3c1909bd3d6e4553f9aa24cd74ee16a3.setContent(html_749f653089db6ec8f55edccbecff8289);
#
#
#
#         marker_3d4644acdbba5ae7ee455faf5c75e82c.bindPopup(popup_3c1909bd3d6e4553f9aa24cd74ee16a3)
#         ;
#
#
#
#
#             var marker_51e8e1f9a38d0b1e30d203ee2c8eb75c = L.marker(
#                 [8.0, -53.0],
#                 {}
#             ).addTo(marker_cluster_838beb72f022631884328e685720d3e1);
#
#
#         var popup_e03b85e4e0008be655edd8efbed05d88 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_676a4ea37a641c65b08c4c613d002199 = $(`&lt;div id=&quot;html_676a4ea37a641c65b08c4c613d002199&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-53&lt;br&gt;lat:8&lt;/div&gt;`)[0];
#                 popup_e03b85e4e0008be655edd8efbed05d88.setContent(html_676a4ea37a641c65b08c4c613d002199);
#
#
#
#         marker_51e8e1f9a38d0b1e

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a37884ec3e4e6b365ba4298f1fa4b71 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a37884ec3e4e6b365ba4298f1fa4b71&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a37884ec3e4e6b365ba4298f1fa4b71 = L.map(
#                 &quot;map_5a37884ec3e4e6b365ba4298f1fa4b71&quot;,
#                 {
#                     center: [0.58, -21.53],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ccbd8ea874649e86ba976f43d9fdbf4f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ccbd8ea874649e86ba976f43d9fdbf4f.addTo(map_5a37884ec3e4e6b365ba4298f1fa4b71);
#
#
#             var marker_cluster_40f3db13c756c3a1161b4b226b35ebfc = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_01c40146d2386dc58c9d8b58b25e2f1c = L.marker(
#                 [-11.0, 160.0],
#                 {}
#             ).addTo(marker_cluster_40f3db13c756c3a1161b4b226b35ebfc);
#
#
#         var popup_87bd30197451e37443d4a307affa7986 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_89dd6178e3e236d6100157b1589a8f13 = $(`&lt;div id=&quot;html_89dd6178e3e236d6100157b1589a8f13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:160&lt;br&gt;lat:-11&lt;/div&gt;`)[0];
#                 popup_87bd30197451e37443d4a307affa7986.setContent(html_89dd6178e3e236d6100157b1589a8f13);
#
#
#
#         marker_01c40146d2386dc58c9d8b58b25e2f1c.bindPopup(popup_87bd30197451e37443d4a307affa7986)
#         ;
#
#
#
#
#             var marker_65b5acca7fd0a7ad92bc7ce6ac42ff94 = L.marker(
#                 [3.0, -119.0],
#                 {}
#             ).addTo(marker_cluster_40f3db13c756c3a1161b4b226b35ebfc);
#
#
#         var popup_7911ff5b4f7de079f8915bb506c6b358 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0b0d5db7098353eef62d7c17ba53191c = $(`&lt;div id=&quot;html_0b0d5db7098353eef62d7c17ba53191c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-119&lt;br&gt;lat:3&lt;/div&gt;`)[0];
#                 popup_7911ff5b4f7de079f8915bb506c6b358.setContent(html_0b0d5db7098353eef62d7c17ba53191c);
#
#
#
#         marker_65b5acca7fd0a7ad92bc7ce6ac42ff94.bindPopup(popup_7911ff5b4f7de079f8915bb506c6b358)
#         ;
#
#
#
#
#             var marker_554cd08f918025f96ada56c55e55bf1b = L.marker(
#                 [-12.0, -80.0],
#                 {}
#             ).addTo(marker_cluster_40f3db13c756c3a1161b4b226b35ebfc);
#
#
#         var popup_69ccb282804d8d8bc84dcd0f6ea0c58c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a9241f636bf0fcee27a7a90d156b5e8b = $(`&lt;div id=&quot;html_a9241f636bf0fcee27a7a90d156b5e8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-80&lt;br&gt;lat:-12&lt;/div&gt;`)[0];
#                 popup_69ccb282804d8d8bc84dcd0f6ea0c58c.setContent(html_a9241f636bf0fcee27a7a90d156b5e8b);
#
#
#
#         marker_554cd08f918025f96ada56c55e55bf1b.bindPopup(popup_69ccb282804d8d8bc84dcd0f6ea0c58c)
#         ;
#
#
#
#
#             var marker_7046c5d29ab5faac2af4ada6a72cccf2 = L.marker(
#                 [8.0, -53.0],
#                 {}
#             ).addTo(marker_cluster_40f3db13c756c3a1161b4b226b35ebfc);
#
#
#         var popup_4ed96e08067b4f00a6858ec7990d4e6f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_75264b05454d974986a4f31e7b9cb184 = $(`&lt;div id=&quot;html_75264b05454d974986a4f31e7b9cb184&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-53&lt;br&gt;lat:8&lt;/div&gt;`)[0];
#                 popup_4ed96e08067b4f00a6858ec7990d4e6f.setContent(html_75264b05454d974986a4f31e7b9cb184);
#
#
#
#         marker_7046c5d29ab5faac2af4ada6a72cccf2.bindPopup(popup_4ed96e08067b4f00a6858ec7990d4e6f)
#         ;
#
#
#
#
#             var marker_527f8e453eb04b58cf572f5fa5d4f236 = L.marker(
#                 [-27.0, 120.0],
#                 {}
#             ).addTo(marker_cluster_40f3db13c756c3a1161b4b226b35ebfc);
#
#
#         var popup_200a748f18af76db86393a7

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_879b2391ca40d5a2e0f0372838925fb3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_879b2391ca40d5a2e0f0372838925fb3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_879b2391ca40d5a2e0f0372838925fb3 = L.map(
#                 &quot;map_879b2391ca40d5a2e0f0372838925fb3&quot;,
#                 {
#                     center: [0.58, -21.53],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a8763fc18210c4ff1df66f4f66fdf06 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7a8763fc18210c4ff1df66f4f66fdf06.addTo(map_879b2391ca40d5a2e0f0372838925fb3);
#
#
#             var fast_marker_cluster_27e80adc1afa51686a121710d5459365 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[-11.0, 160.0], [3.0, -119.0], [-12.0, -80.0], [8.0, -53.0], [-27.0, 120.0], [-48.0, 90.0], [11.0, 135.0], [83.0, 73.0], [16.0, -67.0], [22.0, -82.0], [-63.0, 61.0], [14.0, 162.0], [67.0, -89.0], [-75.0, 29.0], [29.0, -113.0], [-69.0, -179.0], [9.0, -39.0], [-33.0, -53.0], [86.0, -95.0], [-38.0, 64.0], [23.0, -129.0], [-38.0, 105.0], [62.0, -100.0], [4.0, -77.0], [-67.0, 174.0], [-7.0, -125.0], [-25.0, -138.0], [-81.0, -135.0], [18.0, -67.0], [24.0, 0.0], [16.0, 149.0], [-2.0, -78.0], [77.0, -143.0], [57.0, -43.0], [-23.0, -59.0], [74.0, -32.0], [72.0, -145.0], [52.0, -123.0], [-33.0, -18.0], [88.0, -104.0], [-27.0, -25.0], [80.0, 28.0], [-3.0, -24.0], [-40.0, 93.0], [-70.0, 122.0], [-43.0, 14.0], [-33.0, 128.0], [17.0, 110.0], [-68.0, 65.0], [-20.0, 42.0], [-30.0, -49.0], [-15.0, 166.0], [-27.0, -8.0], [84.0, -101.0], [57.0, -65.0], [-39.0, 170.0], [84.0, 23.0], [32.0, -99.0], [-80.0, -13.0], [-30.0, 34.0], [-58.0, -128.0], [3.0, -58.0], [80.0, -1.0], [-3.0, -16.0], [70.0, -172.0], [-89.0, 48.0], [-34.0, -87.0], [72.0, -24.0], [-36.0, 74.0], [54.0, -100.0], [49.0, -122.0], [54.0, -125.0], [-37.0, -122.0], [-40.0, -85.0], [-18.0, -148.0], [73.0, 31.0], [-24.0, 107.0], [-65.0, -169.0], [12.0, 174.0], [-22.0, -76.0], [-23.0, -69.0], [21.0, -174.0], [-6.0, -24.0], [-82.0, -120.0], [9.0, -179.0], [-31.0, -77.0], [72.0, 101.0], [21.0, -144.0], [27.0, -153.0], [31.0, 83.0], [-65.0, -57.0], [-77.0, -40.0], [-25.0, -88.0], [-9.0, 173.0], [-12.0, 167.0], [42.0, -81.0], [82.0, 148.0], [-54.0, -24.0], [-45.0, 31.0], [49.0, -75.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_879b2391ca40d5a2e0f0372838925fb3);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_27e80adc1afa51686a121710d5459365.addTo(map_879b2391ca40d5a2e0f0372838925fb3);
#
#
#             var layer_control_b0854e129c23559172788742e5dc7325_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_7a8763fc18210c4ff1df66f4f66fdf06,
#                 },
#                 overlays :  {
#                     &quot;macro_element_27e80adc1afa51686a121710d5459365&quot; : fast_marker_cluster_27e80adc1afa51686a121710d5459365,
#                 },
#             };
#             let layer_control_b0854e129c23559172788742e5dc7325 = L.control.layers(
#                 layer_control_b0854e129c23559172788742e5dc7325_layers.base_layers,
#                 layer_control_b0854e129c23559172788742e5dc7325_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_879b2391ca40d5a2e0f0372838925fb3);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d714e5eee7a7dd9b1a7103186ee8aa82 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d714e5eee7a7dd9b1a7103186ee8aa82&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d714e5eee7a7dd9b1a7103186ee8aa82 = L.map(
#                 &quot;map_d714e5eee7a7dd9b1a7103186ee8aa82&quot;,
#                 {
#                     center: [0.58, -21.53],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a7ea947900a201c60da19c4e794bf5ad = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a7ea947900a201c60da19c4e794bf5ad.addTo(map_d714e5eee7a7dd9b1a7103186ee8aa82);
#
#
#             var fast_marker_cluster_ded5fc54f5891fbbf3b2ce0d948f4519 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[-11.0, 160.0], [3.0, -119.0], [-12.0, -80.0], [8.0, -53.0], [-27.0, 120.0], [-48.0, 90.0], [11.0, 135.0], [83.0, 73.0], [16.0, -67.0], [22.0, -82.0], [-63.0, 61.0], [14.0, 162.0], [67.0, -89.0], [-75.0, 29.0], [29.0, -113.0], [-69.0, -179.0], [9.0, -39.0], [-33.0, -53.0], [86.0, -95.0], [-38.0, 64.0], [23.0, -129.0], [-38.0, 105.0], [62.0, -100.0], [4.0, -77.0], [-67.0, 174.0], [-7.0, -125.0], [-25.0, -138.0], [-81.0, -135.0], [18.0, -67.0], [24.0, 0.0], [16.0, 149.0], [-2.0, -78.0], [77.0, -143.0], [57.0, -43.0], [-23.0, -59.0], [74.0, -32.0], [72.0, -145.0], [52.0, -123.0], [-33.0, -18.0], [88.0, -104.0], [-27.0, -25.0], [80.0, 28.0], [-3.0, -24.0], [-40.0, 93.0], [-70.0, 122.0], [-43.0, 14.0], [-33.0, 128.0], [17.0, 110.0], [-68.0, 65.0], [-20.0, 42.0], [-30.0, -49.0], [-15.0, 166.0], [-27.0, -8.0], [84.0, -101.0], [57.0, -65.0], [-39.0, 170.0], [84.0, 23.0], [32.0, -99.0], [-80.0, -13.0], [-30.0, 34.0], [-58.0, -128.0], [3.0, -58.0], [80.0, -1.0], [-3.0, -16.0], [70.0, -172.0], [-89.0, 48.0], [-34.0, -87.0], [72.0, -24.0], [-36.0, 74.0], [54.0, -100.0], [49.0, -122.0], [54.0, -125.0], [-37.0, -122.0], [-40.0, -85.0], [-18.0, -148.0], [73.0, 31.0], [-24.0, 107.0], [-65.0, -169.0], [12.0, 174.0], [-22.0, -76.0], [-23.0, -69.0], [21.0, -174.0], [-6.0, -24.0], [-82.0, -120.0], [9.0, -179.0], [-31.0, -77.0], [72.0, 101.0], [21.0, -144.0], [27.0, -153.0], [31.0, 83.0], [-65.0, -57.0], [-77.0, -40.0], [-25.0, -88.0], [-9.0, 173.0], [-12.0, 167.0], [42.0, -81.0], [82.0, 148.0], [-54.0, -24.0], [-45.0, 31.0], [49.0, -75.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_d714e5eee7a7dd9b1a7103186ee8aa82);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_ded5fc54f5891fbbf3b2ce0d948f4519.addTo(map_d714e5eee7a7dd9b1a7103186ee8aa82);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
