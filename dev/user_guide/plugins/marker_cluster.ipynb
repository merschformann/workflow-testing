# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d7e0086edcb026ededea627a0c1c615 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d7e0086edcb026ededea627a0c1c615&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d7e0086edcb026ededea627a0c1c615 = L.map(
#                 &quot;map_1d7e0086edcb026ededea627a0c1c615&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8fcb75b7a46fc3c7b149bd371ea7758 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b8fcb75b7a46fc3c7b149bd371ea7758.addTo(map_1d7e0086edcb026ededea627a0c1c615);
#
#
#             var marker_cluster_65d286abd35fd5b2b969c4a5b3574592 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_abb21727bb25863005cb112ebb298a98 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_65d286abd35fd5b2b969c4a5b3574592);
#
#
#             var icon_d3c1a27ae057c192c6851db7e316ca09 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_abb21727bb25863005cb112ebb298a98.setIcon(icon_d3c1a27ae057c192c6851db7e316ca09);
#
#
#         var popup_57fcf4f3dcafc0c792a773cfbd62af61 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e988e8c9a937cbfbfa983034eafe26ef = $(`&lt;div id=&quot;html_e988e8c9a937cbfbfa983034eafe26ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_57fcf4f3dcafc0c792a773cfbd62af61.setContent(html_e988e8c9a937cbfbfa983034eafe26ef);
#
#
#
#         marker_abb21727bb25863005cb112ebb298a98.bindPopup(popup_57fcf4f3dcafc0c792a773cfbd62af61)
#         ;
#
#
#
#
#             var marker_8be1e5d13153cf00fa51a7f438e35e9b = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_65d286abd35fd5b2b969c4a5b3574592);
#
#
#             var icon_9e430e7f3dc14923dc74058675c04989 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8be1e5d13153cf00fa51a7f438e35e9b.setIcon(icon_9e430e7f3dc14923dc74058675c04989);
#
#
#         var popup_379f4483689d4ca43c8be78d720390dc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b91450a11f9528732b46335cbae11871 = $(`&lt;div id=&quot;html_b91450a11f9528732b46335cbae11871&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_379f4483689d4ca43c8be78d720390dc.setContent(html_b91450a11f9528732b46335cbae11871);
#
#
#
#         marker_8be1e5d13153cf00fa51a7f438e35e9b.bindPopup(popup_379f4483689d4ca43c8be78d720390dc)
#         ;
#
#
#
#
#             var marker_e4d0c6e38354e96e375adeec375a7e40 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_65d286abd35fd5b2b969c4a5b3574592);
#
#
#         var popup_0318e45594f2d8e6d9a233ad16dfa4cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0964b8dcf3e421ac29c2924c5f31eb72 = $(`&lt;div id=&quot;html_0964b8dcf3e421ac29c2924c5f31eb72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_0318e45594f2d8e6d9a233ad16dfa4cd.setContent(html_0964b8dcf3e421ac29c2924c5f31eb72);
#
#
#
#         marker_e4d0c6e38354e96e375adeec375a7e40.bindPopup(popup_0318e45594f2d8e6d9a233ad16dfa4cd)
#         ;
#
#
#
#
#             marker_cluster_65d286abd35fd5b2b969c4a5b3574592.addTo(map_1d7e0086edcb026ededea627a0c1c615);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50cd82fe2da0a4270ecd23940c30f9ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50cd82fe2da0a4270ecd23940c30f9ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50cd82fe2da0a4270ecd23940c30f9ca = L.map(
#                 &quot;map_50cd82fe2da0a4270ecd23940c30f9ca&quot;,
#                 {
#                     center: [1.51, -2.33],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1ef64bcf96a3ebf7183fc8977e00605 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c1ef64bcf96a3ebf7183fc8977e00605.addTo(map_50cd82fe2da0a4270ecd23940c30f9ca);
#
#
#             var marker_cluster_b008c63eab336534015f100dcc627018 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_b008c63eab336534015f100dcc627018.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_722b100d788ad12ad7ec8c3bdeab0a15 = L.marker(
#                 [-70.0, -37.0],
#                 {}
#             ).addTo(marker_cluster_b008c63eab336534015f100dcc627018);
#
#
#         var popup_326bdf2267a60151bd6ef04a880a9444 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e23baf111b089513b542b6bff449a385 = $(`&lt;div id=&quot;html_e23baf111b089513b542b6bff449a385&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-37&lt;br&gt;lat:-70&lt;/div&gt;`)[0];
#                 popup_326bdf2267a60151bd6ef04a880a9444.setContent(html_e23baf111b089513b542b6bff449a385);
#
#
#
#         marker_722b100d788ad12ad7ec8c3bdeab0a15.bindPopup(popup_326bdf2267a60151bd6ef04a880a9444)
#         ;
#
#
#
#
#             var marker_1db417d7924e0e42f5b6aadc51a79be6 = L.marker(
#                 [-38.0, -4.0],
#                 {}
#             ).addTo(marker_cluster_b008c63eab336534015f100dcc627018);
#
#
#         var popup_a3bc73ed95d7323bc8f469baf8a2e6c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_22ab411c033afd6b3bdc8087341d04ad = $(`&lt;div id=&quot;html_22ab411c033afd6b3bdc8087341d04ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-4&lt;br&gt;lat:-38&lt;/div&gt;`)[0];
#                 popup_a3bc73ed95d7323bc8f469baf8a2e6c4.setContent(html_22ab411c033afd6b3bdc8087341d04ad);
#
#
#
#         marker_1db417d7924e0e42f5b6aadc51a79be6.bindPopup(popup_a3bc73ed95d7323bc8f469baf8a2e6c4)
#         ;
#
#
#
#
#             var marker_c9a74f3b8b4ad6970b908dd47766778b = L.marker(
#                 [-79.0, -67.0],
#                 {}
#             ).addTo(marker_cluster_b008c63eab336534015f100dcc627018);
#
#
#         var popup_b2954680a0068a32e8377f1b8e80787e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_abb83b1e0633aab78cfb86857ee5e812 = $(`&lt;div id=&quot;html_abb83b1e0633aab78cfb86857ee5e812&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-67&lt;br&gt;lat:-79&lt;/div&gt;`)[0];
#                 popup_b2954680a0068a32e8377f1b8e80787e.setContent(html_abb83b1e0633aab78cfb86857ee5e812);
#
#
#
#         marker_c9a74f3b8b4ad6970b908dd47766778b.bindPopup(popup_b2954680a0068a32e8377f1b8e80787e)
#         ;
#
#
#
#
#             var marker_ee0be4e57c052527ad7dde50b1101962 = L.marker(
#                 [31.0, 3.0],
#                 {}
#             ).addTo(marker_cluster_b008c63eab336534015f100dcc627018);
#
#
#         var popup_08609f959eb37a78deb82d8d08a60934 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aec9c626f6771f191330685a2c211591 = $(`&lt;div id=&quot;html_aec9c626f6771f191330685a2c211591&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:3&lt;br&gt;lat:31&lt;/div&gt;`)[0];
#                 popup_08609f959eb37a78deb82d8d08a60934.setContent(html_aec9c626f6771f191330685a2c211591);
#
#
#
#         marker_ee0be4e57c052527ad7

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ecf0a28e012d126b1c3cf8b7573e56df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ecf0a28e012d126b1c3cf8b7573e56df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ecf0a28e012d126b1c3cf8b7573e56df = L.map(
#                 &quot;map_ecf0a28e012d126b1c3cf8b7573e56df&quot;,
#                 {
#                     center: [1.51, -2.33],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4328b1c22656416abd913d94b104d6c0 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4328b1c22656416abd913d94b104d6c0.addTo(map_ecf0a28e012d126b1c3cf8b7573e56df);
#
#
#             var marker_cluster_2200dc1c31b9fabcc72160d01b982056 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_96c3d0ef28e72085caee5edee100b574 = L.marker(
#                 [-70.0, -37.0],
#                 {}
#             ).addTo(marker_cluster_2200dc1c31b9fabcc72160d01b982056);
#
#
#         var popup_f1c235cc2f3dc32f15a06e7347694141 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_343cd1388cb73ba671e34eb2bd4485d9 = $(`&lt;div id=&quot;html_343cd1388cb73ba671e34eb2bd4485d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-37&lt;br&gt;lat:-70&lt;/div&gt;`)[0];
#                 popup_f1c235cc2f3dc32f15a06e7347694141.setContent(html_343cd1388cb73ba671e34eb2bd4485d9);
#
#
#
#         marker_96c3d0ef28e72085caee5edee100b574.bindPopup(popup_f1c235cc2f3dc32f15a06e7347694141)
#         ;
#
#
#
#
#             var marker_c8359d5aff010b3068df3b60b640c67a = L.marker(
#                 [-38.0, -4.0],
#                 {}
#             ).addTo(marker_cluster_2200dc1c31b9fabcc72160d01b982056);
#
#
#         var popup_6c463acd1cb37c39dcb6b66e9a087357 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a3f9ec9c2b92025f0f8d46cdfe6415ce = $(`&lt;div id=&quot;html_a3f9ec9c2b92025f0f8d46cdfe6415ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-4&lt;br&gt;lat:-38&lt;/div&gt;`)[0];
#                 popup_6c463acd1cb37c39dcb6b66e9a087357.setContent(html_a3f9ec9c2b92025f0f8d46cdfe6415ce);
#
#
#
#         marker_c8359d5aff010b3068df3b60b640c67a.bindPopup(popup_6c463acd1cb37c39dcb6b66e9a087357)
#         ;
#
#
#
#
#             var marker_fe1bcd2b1e4b868831d632f4ed3baea2 = L.marker(
#                 [-79.0, -67.0],
#                 {}
#             ).addTo(marker_cluster_2200dc1c31b9fabcc72160d01b982056);
#
#
#         var popup_92919c0ca7ced2f497cb91ed2f271e7f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ccb8bd3ad70db26b99a105d0148efe53 = $(`&lt;div id=&quot;html_ccb8bd3ad70db26b99a105d0148efe53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-67&lt;br&gt;lat:-79&lt;/div&gt;`)[0];
#                 popup_92919c0ca7ced2f497cb91ed2f271e7f.setContent(html_ccb8bd3ad70db26b99a105d0148efe53);
#
#
#
#         marker_fe1bcd2b1e4b868831d632f4ed3baea2.bindPopup(popup_92919c0ca7ced2f497cb91ed2f271e7f)
#         ;
#
#
#
#
#             var marker_5194221f17e4cb69bba29a4a3944de92 = L.marker(
#                 [31.0, 3.0],
#                 {}
#             ).addTo(marker_cluster_2200dc1c31b9fabcc72160d01b982056);
#
#
#         var popup_9cdeac4903399afa478b1f44a3d32628 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a2c78f4896e8bd668d193ce8f091b434 = $(`&lt;div id=&quot;html_a2c78f4896e8bd668d193ce8f091b434&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:3&lt;br&gt;lat:31&lt;/div&gt;`)[0];
#                 popup_9cdeac4903399afa478b1f44a3d32628.setContent(html_a2c78f4896e8bd668d193ce8f091b434);
#
#
#
#         marker_5194221f17e4cb69bba29a4a3944de92.bindPopup(popup_9cdeac4903399afa478b1f44a3d32628)
#         ;
#
#
#
#
#             var marker_cf277b690417f67100cec045f26f7b9c = L.marker(
#                 [-56.0, 84.0],
#                 {}
#             ).addTo(marker_cluster_2200dc1c31b9fabcc72160d01b982056);
#
#
#         var popup_7b172f636752e3a2924a0650cab

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d794d1324f686a69de01147f074f0480 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d794d1324f686a69de01147f074f0480&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d794d1324f686a69de01147f074f0480 = L.map(
#                 &quot;map_d794d1324f686a69de01147f074f0480&quot;,
#                 {
#                     center: [1.51, -2.33],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3557c8477cc6d836dacbd4b9862bd8af = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3557c8477cc6d836dacbd4b9862bd8af.addTo(map_d794d1324f686a69de01147f074f0480);
#
#
#             var fast_marker_cluster_038afbdc302ea2cc0a98ac4c9f0335e6 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[-70.0, -37.0], [-38.0, -4.0], [-79.0, -67.0], [31.0, 3.0], [-56.0, 84.0], [-85.0, -98.0], [32.0, 41.0], [68.0, -90.0], [-4.0, 83.0], [-35.0, -175.0], [87.0, -141.0], [-32.0, -105.0], [81.0, 115.0], [-58.0, 72.0], [-19.0, -35.0], [-34.0, -110.0], [50.0, 19.0], [8.0, 152.0], [0.0, 169.0], [-46.0, 78.0], [49.0, 111.0], [-52.0, 8.0], [-2.0, 116.0], [-61.0, 61.0], [-90.0, 23.0], [-13.0, 80.0], [32.0, -178.0], [56.0, -38.0], [-36.0, 57.0], [70.0, 97.0], [32.0, -143.0], [86.0, -113.0], [31.0, 150.0], [-61.0, 62.0], [5.0, 77.0], [-58.0, -105.0], [-85.0, 24.0], [14.0, -112.0], [-89.0, 172.0], [-68.0, 161.0], [-48.0, -136.0], [-33.0, 5.0], [58.0, -25.0], [70.0, 103.0], [-3.0, -33.0], [-84.0, -167.0], [84.0, -108.0], [88.0, -179.0], [-71.0, -176.0], [-13.0, -79.0], [18.0, 100.0], [34.0, 86.0], [-19.0, 171.0], [12.0, 78.0], [22.0, 174.0], [-30.0, 36.0], [26.0, -45.0], [78.0, -82.0], [46.0, -37.0], [55.0, 129.0], [-54.0, -1.0], [70.0, -90.0], [-57.0, 36.0], [20.0, -64.0], [12.0, 27.0], [56.0, 51.0], [62.0, 60.0], [-72.0, -7.0], [28.0, -163.0], [53.0, -180.0], [-39.0, 174.0], [-29.0, 55.0], [36.0, 74.0], [-59.0, 101.0], [-28.0, -109.0], [9.0, -159.0], [45.0, 76.0], [-60.0, -114.0], [-18.0, 10.0], [0.0, -108.0], [7.0, 27.0], [53.0, -33.0], [28.0, 140.0], [-35.0, -70.0], [32.0, -117.0], [69.0, 177.0], [51.0, 161.0], [-47.0, -32.0], [36.0, 45.0], [-34.0, 71.0], [-68.0, -140.0], [84.0, -141.0], [43.0, 32.0], [89.0, -133.0], [-82.0, -15.0], [12.0, 122.0], [0.0, -174.0], [62.0, -71.0], [-63.0, 150.0], [88.0, -180.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_d794d1324f686a69de01147f074f0480);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_038afbdc302ea2cc0a98ac4c9f0335e6.addTo(map_d794d1324f686a69de01147f074f0480);
#
#
#             var layer_control_f8abb10e8a799081f5bf497db4193d69_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_3557c8477cc6d836dacbd4b9862bd8af,
#                 },
#                 overlays :  {
#                     &quot;macro_element_038afbdc302ea2cc0a98ac4c9f0335e6&quot; : fast_marker_cluster_038afbdc302ea2cc0a98ac4c9f0335e6,
#                 },
#             };
#             let layer_control_f8abb10e8a799081f5bf497db4193d69 = L.control.layers(
#                 layer_control_f8abb10e8a799081f5bf497db4193d69_layers.base_layers,
#                 layer_control_f8abb10e8a799081f5bf497db4193d69_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_d794d1324f686a69de01147f074f0480);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c265dba59e3c4d8a3cfb97b938219f78 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c265dba59e3c4d8a3cfb97b938219f78&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c265dba59e3c4d8a3cfb97b938219f78 = L.map(
#                 &quot;map_c265dba59e3c4d8a3cfb97b938219f78&quot;,
#                 {
#                     center: [1.51, -2.33],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9aa134aa4794da821d0e70f2704bb250 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9aa134aa4794da821d0e70f2704bb250.addTo(map_c265dba59e3c4d8a3cfb97b938219f78);
#
#
#             var fast_marker_cluster_6c0c641c81afc8e219846f7ec61969eb = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[-70.0, -37.0], [-38.0, -4.0], [-79.0, -67.0], [31.0, 3.0], [-56.0, 84.0], [-85.0, -98.0], [32.0, 41.0], [68.0, -90.0], [-4.0, 83.0], [-35.0, -175.0], [87.0, -141.0], [-32.0, -105.0], [81.0, 115.0], [-58.0, 72.0], [-19.0, -35.0], [-34.0, -110.0], [50.0, 19.0], [8.0, 152.0], [0.0, 169.0], [-46.0, 78.0], [49.0, 111.0], [-52.0, 8.0], [-2.0, 116.0], [-61.0, 61.0], [-90.0, 23.0], [-13.0, 80.0], [32.0, -178.0], [56.0, -38.0], [-36.0, 57.0], [70.0, 97.0], [32.0, -143.0], [86.0, -113.0], [31.0, 150.0], [-61.0, 62.0], [5.0, 77.0], [-58.0, -105.0], [-85.0, 24.0], [14.0, -112.0], [-89.0, 172.0], [-68.0, 161.0], [-48.0, -136.0], [-33.0, 5.0], [58.0, -25.0], [70.0, 103.0], [-3.0, -33.0], [-84.0, -167.0], [84.0, -108.0], [88.0, -179.0], [-71.0, -176.0], [-13.0, -79.0], [18.0, 100.0], [34.0, 86.0], [-19.0, 171.0], [12.0, 78.0], [22.0, 174.0], [-30.0, 36.0], [26.0, -45.0], [78.0, -82.0], [46.0, -37.0], [55.0, 129.0], [-54.0, -1.0], [70.0, -90.0], [-57.0, 36.0], [20.0, -64.0], [12.0, 27.0], [56.0, 51.0], [62.0, 60.0], [-72.0, -7.0], [28.0, -163.0], [53.0, -180.0], [-39.0, 174.0], [-29.0, 55.0], [36.0, 74.0], [-59.0, 101.0], [-28.0, -109.0], [9.0, -159.0], [45.0, 76.0], [-60.0, -114.0], [-18.0, 10.0], [0.0, -108.0], [7.0, 27.0], [53.0, -33.0], [28.0, 140.0], [-35.0, -70.0], [32.0, -117.0], [69.0, 177.0], [51.0, 161.0], [-47.0, -32.0], [36.0, 45.0], [-34.0, 71.0], [-68.0, -140.0], [84.0, -141.0], [43.0, 32.0], [89.0, -133.0], [-82.0, -15.0], [12.0, 122.0], [0.0, -174.0], [62.0, -71.0], [-63.0, 150.0], [88.0, -180.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_c265dba59e3c4d8a3cfb97b938219f78);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_6c0c641c81afc8e219846f7ec61969eb.addTo(map_c265dba59e3c4d8a3cfb97b938219f78);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
