# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32d68918932d6606cff1892ec7c4a1d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32d68918932d6606cff1892ec7c4a1d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32d68918932d6606cff1892ec7c4a1d4 = L.map(
#                 &quot;map_32d68918932d6606cff1892ec7c4a1d4&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66b375a89b47836f2af488674ee58622 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_66b375a89b47836f2af488674ee58622.addTo(map_32d68918932d6606cff1892ec7c4a1d4);
#
#
#             var marker_cluster_d9e608dca5b52e607098f8dcbb146ead = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_04fa5b7b7f54a7d5a056a20fc2330117 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_d9e608dca5b52e607098f8dcbb146ead);
#
#
#             var icon_02264dcb2db4642b4ecb5297bf2cc477 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_04fa5b7b7f54a7d5a056a20fc2330117.setIcon(icon_02264dcb2db4642b4ecb5297bf2cc477);
#
#
#         var popup_b8a85168cf6216bec012a8d80647c1f2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7ebf04dd87012a5da084035fd64eb1ba = $(`&lt;div id=&quot;html_7ebf04dd87012a5da084035fd64eb1ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_b8a85168cf6216bec012a8d80647c1f2.setContent(html_7ebf04dd87012a5da084035fd64eb1ba);
#
#
#
#         marker_04fa5b7b7f54a7d5a056a20fc2330117.bindPopup(popup_b8a85168cf6216bec012a8d80647c1f2)
#         ;
#
#
#
#
#             var marker_8c81920c8865acb0e3419b3bb25882b5 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_d9e608dca5b52e607098f8dcbb146ead);
#
#
#             var icon_ba91a3b5cff486c793460ece1fd2c8fc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8c81920c8865acb0e3419b3bb25882b5.setIcon(icon_ba91a3b5cff486c793460ece1fd2c8fc);
#
#
#         var popup_231f583ef39619392c83742cb9fdbd98 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8429760e209851cc1c05ce21fe3d56df = $(`&lt;div id=&quot;html_8429760e209851cc1c05ce21fe3d56df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_231f583ef39619392c83742cb9fdbd98.setContent(html_8429760e209851cc1c05ce21fe3d56df);
#
#
#
#         marker_8c81920c8865acb0e3419b3bb25882b5.bindPopup(popup_231f583ef39619392c83742cb9fdbd98)
#         ;
#
#
#
#
#             var marker_9df92fcd719a0bed2793feb7287249f4 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_d9e608dca5b52e607098f8dcbb146ead);
#
#
#         var popup_fdb7b6b816dcb09f402cf3d04ae10c93 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c98f9bafc13d92080e37f3e74d09994 = $(`&lt;div id=&quot;html_2c98f9bafc13d92080e37f3e74d09994&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_fdb7b6b816dcb09f402cf3d04ae10c93.setContent(html_2c98f9bafc13d92080e37f3e74d09994);
#
#
#
#         marker_9df92fcd719a0bed2793feb7287249f4.bindPopup(popup_fdb7b6b816dcb09f402cf3d04ae10c93)
#         ;
#
#
#
#
#             marker_cluster_d9e608dca5b52e607098f8dcbb146ead.addTo(map_32d68918932d6606cff1892ec7c4a1d4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a15bb84cf09742b7876e3db3534ddd92 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a15bb84cf09742b7876e3db3534ddd92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a15bb84cf09742b7876e3db3534ddd92 = L.map(
#                 &quot;map_a15bb84cf09742b7876e3db3534ddd92&quot;,
#                 {
#                     center: [-0.04, 14.54],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b4eeca768deb5dec151123f57dba942 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4b4eeca768deb5dec151123f57dba942.addTo(map_a15bb84cf09742b7876e3db3534ddd92);
#
#
#             var marker_cluster_b443ef091544f7b0fbae21ef9f7561d7 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_b443ef091544f7b0fbae21ef9f7561d7.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_749024203e7b56d484aea9bc451fbacb = L.marker(
#                 [88.0, -122.0],
#                 {}
#             ).addTo(marker_cluster_b443ef091544f7b0fbae21ef9f7561d7);
#
#
#         var popup_ebda2a74a0447262f58318cb6f506cd7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1dc6992c6036013e1b466a377359b3de = $(`&lt;div id=&quot;html_1dc6992c6036013e1b466a377359b3de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-122&lt;br&gt;lat:88&lt;/div&gt;`)[0];
#                 popup_ebda2a74a0447262f58318cb6f506cd7.setContent(html_1dc6992c6036013e1b466a377359b3de);
#
#
#
#         marker_749024203e7b56d484aea9bc451fbacb.bindPopup(popup_ebda2a74a0447262f58318cb6f506cd7)
#         ;
#
#
#
#
#             var marker_5dbaf46299eb0882cdf59ff5bba5c6d1 = L.marker(
#                 [56.0, 51.0],
#                 {}
#             ).addTo(marker_cluster_b443ef091544f7b0fbae21ef9f7561d7);
#
#
#         var popup_016b52e948962bcdab242e3bb15ab75f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6185151a24dd3d6d994cf1637dd2adcc = $(`&lt;div id=&quot;html_6185151a24dd3d6d994cf1637dd2adcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:51&lt;br&gt;lat:56&lt;/div&gt;`)[0];
#                 popup_016b52e948962bcdab242e3bb15ab75f.setContent(html_6185151a24dd3d6d994cf1637dd2adcc);
#
#
#
#         marker_5dbaf46299eb0882cdf59ff5bba5c6d1.bindPopup(popup_016b52e948962bcdab242e3bb15ab75f)
#         ;
#
#
#
#
#             var marker_e6cf68068b6b7db0b3f6377e991900fc = L.marker(
#                 [83.0, -30.0],
#                 {}
#             ).addTo(marker_cluster_b443ef091544f7b0fbae21ef9f7561d7);
#
#
#         var popup_a33aa70385f9098eefa783db1dac31ce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d3a7ac8b088aa3b2680b50856da1db2 = $(`&lt;div id=&quot;html_7d3a7ac8b088aa3b2680b50856da1db2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-30&lt;br&gt;lat:83&lt;/div&gt;`)[0];
#                 popup_a33aa70385f9098eefa783db1dac31ce.setContent(html_7d3a7ac8b088aa3b2680b50856da1db2);
#
#
#
#         marker_e6cf68068b6b7db0b3f6377e991900fc.bindPopup(popup_a33aa70385f9098eefa783db1dac31ce)
#         ;
#
#
#
#
#             var marker_18ae8400e95ce0ac98aee2a535f040d0 = L.marker(
#                 [21.0, 157.0],
#                 {}
#             ).addTo(marker_cluster_b443ef091544f7b0fbae21ef9f7561d7);
#
#
#         var popup_81a41f7726e801436358c20c7b07866a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5e027c1a1c04397d9d986e9ee1931229 = $(`&lt;div id=&quot;html_5e027c1a1c04397d9d986e9ee1931229&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:157&lt;br&gt;lat:21&lt;/div&gt;`)[0];
#                 popup_81a41f7726e801436358c20c7b07866a.setContent(html_5e027c1a1c04397d9d986e9ee1931229);
#
#
#
#         marker_18ae8400e95ce0ac98

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f303bec73e82c5e7497bddbe5e25d531 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f303bec73e82c5e7497bddbe5e25d531&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f303bec73e82c5e7497bddbe5e25d531 = L.map(
#                 &quot;map_f303bec73e82c5e7497bddbe5e25d531&quot;,
#                 {
#                     center: [-0.04, 14.54],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3681b574df9fe3fd549a90e84cce29ab = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3681b574df9fe3fd549a90e84cce29ab.addTo(map_f303bec73e82c5e7497bddbe5e25d531);
#
#
#             var marker_cluster_4119b5bfbec2f9d4e6145431da38c46b = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_8729b29b6928801317d72b968e6e937f = L.marker(
#                 [88.0, -122.0],
#                 {}
#             ).addTo(marker_cluster_4119b5bfbec2f9d4e6145431da38c46b);
#
#
#         var popup_d620145acf3567f688a4d2118d8383db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f63ae5bbec90f4f9f9449ceeb6f2d59e = $(`&lt;div id=&quot;html_f63ae5bbec90f4f9f9449ceeb6f2d59e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-122&lt;br&gt;lat:88&lt;/div&gt;`)[0];
#                 popup_d620145acf3567f688a4d2118d8383db.setContent(html_f63ae5bbec90f4f9f9449ceeb6f2d59e);
#
#
#
#         marker_8729b29b6928801317d72b968e6e937f.bindPopup(popup_d620145acf3567f688a4d2118d8383db)
#         ;
#
#
#
#
#             var marker_c61e43600833d18ecd026da628adf9c1 = L.marker(
#                 [56.0, 51.0],
#                 {}
#             ).addTo(marker_cluster_4119b5bfbec2f9d4e6145431da38c46b);
#
#
#         var popup_f6b88b6bbb8c1f8678f4c1e31915c63d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e561be16526416ba2418cb49f5908027 = $(`&lt;div id=&quot;html_e561be16526416ba2418cb49f5908027&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:51&lt;br&gt;lat:56&lt;/div&gt;`)[0];
#                 popup_f6b88b6bbb8c1f8678f4c1e31915c63d.setContent(html_e561be16526416ba2418cb49f5908027);
#
#
#
#         marker_c61e43600833d18ecd026da628adf9c1.bindPopup(popup_f6b88b6bbb8c1f8678f4c1e31915c63d)
#         ;
#
#
#
#
#             var marker_d9d91b8b3754d3085942b28c4914cb22 = L.marker(
#                 [83.0, -30.0],
#                 {}
#             ).addTo(marker_cluster_4119b5bfbec2f9d4e6145431da38c46b);
#
#
#         var popup_e7de99fa838b6889ac0776c3022de3d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d182a23066516d49a3f7fd94be5ea58 = $(`&lt;div id=&quot;html_5d182a23066516d49a3f7fd94be5ea58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-30&lt;br&gt;lat:83&lt;/div&gt;`)[0];
#                 popup_e7de99fa838b6889ac0776c3022de3d0.setContent(html_5d182a23066516d49a3f7fd94be5ea58);
#
#
#
#         marker_d9d91b8b3754d3085942b28c4914cb22.bindPopup(popup_e7de99fa838b6889ac0776c3022de3d0)
#         ;
#
#
#
#
#             var marker_1ae26cc77ad414129d4a027aa68992e3 = L.marker(
#                 [21.0, 157.0],
#                 {}
#             ).addTo(marker_cluster_4119b5bfbec2f9d4e6145431da38c46b);
#
#
#         var popup_9e62a69cd1911e5b609b91aac7e77e23 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e333c27d0f3d08d7dc40f2da4124b954 = $(`&lt;div id=&quot;html_e333c27d0f3d08d7dc40f2da4124b954&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:157&lt;br&gt;lat:21&lt;/div&gt;`)[0];
#                 popup_9e62a69cd1911e5b609b91aac7e77e23.setContent(html_e333c27d0f3d08d7dc40f2da4124b954);
#
#
#
#         marker_1ae26cc77ad414129d4a027aa68992e3.bindPopup(popup_9e62a69cd1911e5b609b91aac7e77e23)
#         ;
#
#
#
#
#             var marker_037dcd090f32caddebbbfa0a3039ca97 = L.marker(
#                 [71.0, 105.0],
#                 {}
#             ).addTo(marker_cluster_4119b5bfbec2f9d4e6145431da38c46b);
#
#
#         var popup_5e5fb5e6228cbbcae67a3c4606

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d5435892d831d8a49f9c8650a875fa9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d5435892d831d8a49f9c8650a875fa9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d5435892d831d8a49f9c8650a875fa9 = L.map(
#                 &quot;map_7d5435892d831d8a49f9c8650a875fa9&quot;,
#                 {
#                     center: [-0.04, 14.54],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9202543bdd5b425cb63ce41d8fc1787e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9202543bdd5b425cb63ce41d8fc1787e.addTo(map_7d5435892d831d8a49f9c8650a875fa9);
#
#
#             var fast_marker_cluster_79750747c2c716b63f0cffd2d49e2871 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[88.0, -122.0], [56.0, 51.0], [83.0, -30.0], [21.0, 157.0], [71.0, 105.0], [-49.0, 163.0], [-40.0, 109.0], [11.0, -179.0], [44.0, -5.0], [-56.0, -6.0], [9.0, 113.0], [67.0, 28.0], [61.0, -91.0], [-33.0, 164.0], [14.0, 82.0], [-58.0, 120.0], [-88.0, 51.0], [77.0, 0.0], [2.0, 20.0], [10.0, 129.0], [65.0, 47.0], [-56.0, 60.0], [57.0, 49.0], [76.0, -153.0], [-42.0, 139.0], [-50.0, 9.0], [-29.0, 54.0], [24.0, -135.0], [-80.0, -167.0], [28.0, 60.0], [-36.0, 37.0], [52.0, 113.0], [2.0, -31.0], [74.0, -31.0], [60.0, 108.0], [-10.0, 52.0], [9.0, 159.0], [87.0, 9.0], [-20.0, -53.0], [33.0, -165.0], [6.0, 108.0], [75.0, 165.0], [30.0, 30.0], [-27.0, -34.0], [67.0, -45.0], [33.0, 33.0], [-11.0, 168.0], [-23.0, 28.0], [-61.0, 117.0], [-55.0, -150.0], [6.0, 37.0], [-82.0, 57.0], [20.0, -148.0], [22.0, -37.0], [1.0, -137.0], [56.0, 112.0], [-67.0, -72.0], [70.0, -27.0], [-82.0, 171.0], [-19.0, 85.0], [-22.0, -143.0], [-36.0, -15.0], [-7.0, -88.0], [51.0, 125.0], [-15.0, 137.0], [-5.0, -164.0], [-74.0, -117.0], [28.0, 143.0], [26.0, 81.0], [59.0, 103.0], [-27.0, -92.0], [37.0, 55.0], [-17.0, -66.0], [-39.0, -51.0], [-3.0, -22.0], [-40.0, -173.0], [70.0, -127.0], [-5.0, -153.0], [52.0, 21.0], [74.0, 107.0], [-16.0, -26.0], [-58.0, 61.0], [-36.0, -17.0], [-25.0, 151.0], [-22.0, 10.0], [-70.0, 131.0], [-65.0, 86.0], [-21.0, 167.0], [-55.0, 102.0], [-43.0, 168.0], [-55.0, -11.0], [-83.0, -179.0], [36.0, -136.0], [-33.0, 105.0], [22.0, -35.0], [0.0, 89.0], [-61.0, 1.0], [-65.0, -139.0], [61.0, 59.0], [-15.0, -175.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_7d5435892d831d8a49f9c8650a875fa9);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_79750747c2c716b63f0cffd2d49e2871.addTo(map_7d5435892d831d8a49f9c8650a875fa9);
#
#
#             var layer_control_a42459094d785f745481614c6fccc4be_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_9202543bdd5b425cb63ce41d8fc1787e,
#                 },
#                 overlays :  {
#                     &quot;macro_element_79750747c2c716b63f0cffd2d49e2871&quot; : fast_marker_cluster_79750747c2c716b63f0cffd2d49e2871,
#                 },
#             };
#             let layer_control_a42459094d785f745481614c6fccc4be = L.control.layers(
#                 layer_control_a42459094d785f745481614c6fccc4be_layers.base_layers,
#                 layer_control_a42459094d785f745481614c6fccc4be_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_7d5435892d831d8a49f9c8650a875fa9);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_788307b8c70d75654353ab855becd823 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_788307b8c70d75654353ab855becd823&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_788307b8c70d75654353ab855becd823 = L.map(
#                 &quot;map_788307b8c70d75654353ab855becd823&quot;,
#                 {
#                     center: [-0.04, 14.54],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d74d2a082a873c657f4a902a7e7ba0cb = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d74d2a082a873c657f4a902a7e7ba0cb.addTo(map_788307b8c70d75654353ab855becd823);
#
#
#             var fast_marker_cluster_e9f08b26ba3448f881dff3c8a1144681 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[88.0, -122.0], [56.0, 51.0], [83.0, -30.0], [21.0, 157.0], [71.0, 105.0], [-49.0, 163.0], [-40.0, 109.0], [11.0, -179.0], [44.0, -5.0], [-56.0, -6.0], [9.0, 113.0], [67.0, 28.0], [61.0, -91.0], [-33.0, 164.0], [14.0, 82.0], [-58.0, 120.0], [-88.0, 51.0], [77.0, 0.0], [2.0, 20.0], [10.0, 129.0], [65.0, 47.0], [-56.0, 60.0], [57.0, 49.0], [76.0, -153.0], [-42.0, 139.0], [-50.0, 9.0], [-29.0, 54.0], [24.0, -135.0], [-80.0, -167.0], [28.0, 60.0], [-36.0, 37.0], [52.0, 113.0], [2.0, -31.0], [74.0, -31.0], [60.0, 108.0], [-10.0, 52.0], [9.0, 159.0], [87.0, 9.0], [-20.0, -53.0], [33.0, -165.0], [6.0, 108.0], [75.0, 165.0], [30.0, 30.0], [-27.0, -34.0], [67.0, -45.0], [33.0, 33.0], [-11.0, 168.0], [-23.0, 28.0], [-61.0, 117.0], [-55.0, -150.0], [6.0, 37.0], [-82.0, 57.0], [20.0, -148.0], [22.0, -37.0], [1.0, -137.0], [56.0, 112.0], [-67.0, -72.0], [70.0, -27.0], [-82.0, 171.0], [-19.0, 85.0], [-22.0, -143.0], [-36.0, -15.0], [-7.0, -88.0], [51.0, 125.0], [-15.0, 137.0], [-5.0, -164.0], [-74.0, -117.0], [28.0, 143.0], [26.0, 81.0], [59.0, 103.0], [-27.0, -92.0], [37.0, 55.0], [-17.0, -66.0], [-39.0, -51.0], [-3.0, -22.0], [-40.0, -173.0], [70.0, -127.0], [-5.0, -153.0], [52.0, 21.0], [74.0, 107.0], [-16.0, -26.0], [-58.0, 61.0], [-36.0, -17.0], [-25.0, 151.0], [-22.0, 10.0], [-70.0, 131.0], [-65.0, 86.0], [-21.0, 167.0], [-55.0, 102.0], [-43.0, 168.0], [-55.0, -11.0], [-83.0, -179.0], [36.0, -136.0], [-33.0, 105.0], [22.0, -35.0], [0.0, 89.0], [-61.0, 1.0], [-65.0, -139.0], [61.0, 59.0], [-15.0, -175.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_788307b8c70d75654353ab855becd823);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_e9f08b26ba3448f881dff3c8a1144681.addTo(map_788307b8c70d75654353ab855becd823);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
