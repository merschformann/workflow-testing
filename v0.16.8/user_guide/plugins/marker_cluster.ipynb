# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8bee92db159fd7dc924a53ada1dd242 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8bee92db159fd7dc924a53ada1dd242&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8bee92db159fd7dc924a53ada1dd242 = L.map(
#                 &quot;map_b8bee92db159fd7dc924a53ada1dd242&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a1cf0b2d4cb1bb2a8c4af385eda0944 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6a1cf0b2d4cb1bb2a8c4af385eda0944.addTo(map_b8bee92db159fd7dc924a53ada1dd242);
#
#
#             var marker_cluster_080bd69794b15987db05aee58923d619 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_cd0a0513689d836cf351cda03cbce190 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_080bd69794b15987db05aee58923d619);
#
#
#             var icon_91b945c41c2dd08a12036a42df067c75 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cd0a0513689d836cf351cda03cbce190.setIcon(icon_91b945c41c2dd08a12036a42df067c75);
#
#
#         var popup_96e2f206f2148ff0664b89d68ee4b865 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e5819c2aed74ec78a86c05bab37e5456 = $(`&lt;div id=&quot;html_e5819c2aed74ec78a86c05bab37e5456&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_96e2f206f2148ff0664b89d68ee4b865.setContent(html_e5819c2aed74ec78a86c05bab37e5456);
#
#
#
#         marker_cd0a0513689d836cf351cda03cbce190.bindPopup(popup_96e2f206f2148ff0664b89d68ee4b865)
#         ;
#
#
#
#
#             var marker_e8777e768f62342d76fcd1da131616c9 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_080bd69794b15987db05aee58923d619);
#
#
#             var icon_c0f3374908012eabe5a80332098c237b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e8777e768f62342d76fcd1da131616c9.setIcon(icon_c0f3374908012eabe5a80332098c237b);
#
#
#         var popup_5d5f29d959a599e275f465f9bc3e06c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_39af7df3a56289cece6fea367fb7c316 = $(`&lt;div id=&quot;html_39af7df3a56289cece6fea367fb7c316&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_5d5f29d959a599e275f465f9bc3e06c1.setContent(html_39af7df3a56289cece6fea367fb7c316);
#
#
#
#         marker_e8777e768f62342d76fcd1da131616c9.bindPopup(popup_5d5f29d959a599e275f465f9bc3e06c1)
#         ;
#
#
#
#
#             var marker_4860800f99c37d5a933f089049335a76 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_080bd69794b15987db05aee58923d619);
#
#
#         var popup_904fab69a6aa4dae6e32cbb509deb972 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bb08d4a929b7106ee77d876689b19a3d = $(`&lt;div id=&quot;html_bb08d4a929b7106ee77d876689b19a3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_904fab69a6aa4dae6e32cbb509deb972.setContent(html_bb08d4a929b7106ee77d876689b19a3d);
#
#
#
#         marker_4860800f99c37d5a933f089049335a76.bindPopup(popup_904fab69a6aa4dae6e32cbb509deb972)
#         ;
#
#
#
#
#             marker_cluster_080bd69794b15987db05aee58923d619.addTo(map_b8bee92db159fd7dc924a53ada1dd242);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c35b5d757412b1de842516cb348ccbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c35b5d757412b1de842516cb348ccbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c35b5d757412b1de842516cb348ccbc = L.map(
#                 &quot;map_0c35b5d757412b1de842516cb348ccbc&quot;,
#                 {
#                     center: [-5.24, -6.69],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4db8f6fcbb8c2f20bed9623706e37f21 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4db8f6fcbb8c2f20bed9623706e37f21.addTo(map_0c35b5d757412b1de842516cb348ccbc);
#
#
#             var marker_cluster_78febb6c8555503af2bed01764a9989e = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_78febb6c8555503af2bed01764a9989e.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_de58f9328915370e7bab3450441a36ff = L.marker(
#                 [-61.0, -151.0],
#                 {}
#             ).addTo(marker_cluster_78febb6c8555503af2bed01764a9989e);
#
#
#         var popup_cb9b2453ae77d5cb520f759846ded03c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa2d11eba35436dee039d240e4cb56c1 = $(`&lt;div id=&quot;html_aa2d11eba35436dee039d240e4cb56c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-151&lt;br&gt;lat:-61&lt;/div&gt;`)[0];
#                 popup_cb9b2453ae77d5cb520f759846ded03c.setContent(html_aa2d11eba35436dee039d240e4cb56c1);
#
#
#
#         marker_de58f9328915370e7bab3450441a36ff.bindPopup(popup_cb9b2453ae77d5cb520f759846ded03c)
#         ;
#
#
#
#
#             var marker_2db80415021bc2e42c35b07857394f4f = L.marker(
#                 [49.0, 90.0],
#                 {}
#             ).addTo(marker_cluster_78febb6c8555503af2bed01764a9989e);
#
#
#         var popup_2b4a8d8a199feb6a5a21d2e2e52e082e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7da281806cc10dbd4059e0247cbe5a52 = $(`&lt;div id=&quot;html_7da281806cc10dbd4059e0247cbe5a52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:90&lt;br&gt;lat:49&lt;/div&gt;`)[0];
#                 popup_2b4a8d8a199feb6a5a21d2e2e52e082e.setContent(html_7da281806cc10dbd4059e0247cbe5a52);
#
#
#
#         marker_2db80415021bc2e42c35b07857394f4f.bindPopup(popup_2b4a8d8a199feb6a5a21d2e2e52e082e)
#         ;
#
#
#
#
#             var marker_a8fc45c98833096c816355fecd449b14 = L.marker(
#                 [-60.0, -58.0],
#                 {}
#             ).addTo(marker_cluster_78febb6c8555503af2bed01764a9989e);
#
#
#         var popup_b052c5f7d10c280f192b8b69a2621a4b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a587c197cfacd865b4e27a687b07f8a9 = $(`&lt;div id=&quot;html_a587c197cfacd865b4e27a687b07f8a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-58&lt;br&gt;lat:-60&lt;/div&gt;`)[0];
#                 popup_b052c5f7d10c280f192b8b69a2621a4b.setContent(html_a587c197cfacd865b4e27a687b07f8a9);
#
#
#
#         marker_a8fc45c98833096c816355fecd449b14.bindPopup(popup_b052c5f7d10c280f192b8b69a2621a4b)
#         ;
#
#
#
#
#             var marker_caa7adfd284a2dd352a1f00838aa1170 = L.marker(
#                 [20.0, -147.0],
#                 {}
#             ).addTo(marker_cluster_78febb6c8555503af2bed01764a9989e);
#
#
#         var popup_c992effc46437f7330742c9ac89c3a9c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3f0ecf6045422573e7e9f9e3df92f61b = $(`&lt;div id=&quot;html_3f0ecf6045422573e7e9f9e3df92f61b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-147&lt;br&gt;lat:20&lt;/div&gt;`)[0];
#                 popup_c992effc46437f7330742c9ac89c3a9c.setContent(html_3f0ecf6045422573e7e9f9e3df92f61b);
#
#
#
#         marker_caa7adfd284a

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34f2e1bf8717078647f3f7088d8bb2b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34f2e1bf8717078647f3f7088d8bb2b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_34f2e1bf8717078647f3f7088d8bb2b4 = L.map(
#                 &quot;map_34f2e1bf8717078647f3f7088d8bb2b4&quot;,
#                 {
#                     center: [-5.24, -6.69],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b04a10fd5d5c569c3d1e45eb3a826829 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b04a10fd5d5c569c3d1e45eb3a826829.addTo(map_34f2e1bf8717078647f3f7088d8bb2b4);
#
#
#             var marker_cluster_b884f366457371c91e9e00145b9a4b57 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_83a0b6bf607b4c7249f724bfae212018 = L.marker(
#                 [-61.0, -151.0],
#                 {}
#             ).addTo(marker_cluster_b884f366457371c91e9e00145b9a4b57);
#
#
#         var popup_97fbf40f04cd1a561e2dea1c4bba9a1b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c2d0beee71eb1ab9e5e77721737bfd49 = $(`&lt;div id=&quot;html_c2d0beee71eb1ab9e5e77721737bfd49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-151&lt;br&gt;lat:-61&lt;/div&gt;`)[0];
#                 popup_97fbf40f04cd1a561e2dea1c4bba9a1b.setContent(html_c2d0beee71eb1ab9e5e77721737bfd49);
#
#
#
#         marker_83a0b6bf607b4c7249f724bfae212018.bindPopup(popup_97fbf40f04cd1a561e2dea1c4bba9a1b)
#         ;
#
#
#
#
#             var marker_f01c9c4e97c6adaf088c7ac30ed8d9f2 = L.marker(
#                 [49.0, 90.0],
#                 {}
#             ).addTo(marker_cluster_b884f366457371c91e9e00145b9a4b57);
#
#
#         var popup_255af25bfae79e1382352e3b43234b40 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d2cddf56fc2e34babde806a95d6d13d = $(`&lt;div id=&quot;html_5d2cddf56fc2e34babde806a95d6d13d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:90&lt;br&gt;lat:49&lt;/div&gt;`)[0];
#                 popup_255af25bfae79e1382352e3b43234b40.setContent(html_5d2cddf56fc2e34babde806a95d6d13d);
#
#
#
#         marker_f01c9c4e97c6adaf088c7ac30ed8d9f2.bindPopup(popup_255af25bfae79e1382352e3b43234b40)
#         ;
#
#
#
#
#             var marker_002f70648153cd7677c4a0abfa09dcc6 = L.marker(
#                 [-60.0, -58.0],
#                 {}
#             ).addTo(marker_cluster_b884f366457371c91e9e00145b9a4b57);
#
#
#         var popup_425588b87c8d578c348a8f44721a4f0c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e9ae91d6d6331eebeb1524334ac395a = $(`&lt;div id=&quot;html_8e9ae91d6d6331eebeb1524334ac395a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-58&lt;br&gt;lat:-60&lt;/div&gt;`)[0];
#                 popup_425588b87c8d578c348a8f44721a4f0c.setContent(html_8e9ae91d6d6331eebeb1524334ac395a);
#
#
#
#         marker_002f70648153cd7677c4a0abfa09dcc6.bindPopup(popup_425588b87c8d578c348a8f44721a4f0c)
#         ;
#
#
#
#
#             var marker_36b012a241ad1436d79a66be05ddbff3 = L.marker(
#                 [20.0, -147.0],
#                 {}
#             ).addTo(marker_cluster_b884f366457371c91e9e00145b9a4b57);
#
#
#         var popup_6c6921e82bc9ccaa7f1803eab3fe8f68 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b9cef27793c33c6bb2008516c05a922 = $(`&lt;div id=&quot;html_6b9cef27793c33c6bb2008516c05a922&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-147&lt;br&gt;lat:20&lt;/div&gt;`)[0];
#                 popup_6c6921e82bc9ccaa7f1803eab3fe8f68.setContent(html_6b9cef27793c33c6bb2008516c05a922);
#
#
#
#         marker_36b012a241ad1436d79a66be05ddbff3.bindPopup(popup_6c6921e82bc9ccaa7f1803eab3fe8f68)
#         ;
#
#
#
#
#             var marker_2baab5d0c62a99c565beaa9fe8a6d902 = L.marker(
#                 [-17.0, -75.0],
#                 {}
#             ).addTo(marker_cluster_b884f366457371c91e9e00145b9a4b57);
#
#
#         var popup_a33955d1addaf096cfa

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5434c881b9383c8f79f32c4e75aeb8a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5434c881b9383c8f79f32c4e75aeb8a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5434c881b9383c8f79f32c4e75aeb8a2 = L.map(
#                 &quot;map_5434c881b9383c8f79f32c4e75aeb8a2&quot;,
#                 {
#                     center: [-5.24, -6.69],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a48e498850dd940c79dab600bc85c024 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a48e498850dd940c79dab600bc85c024.addTo(map_5434c881b9383c8f79f32c4e75aeb8a2);
#
#
#             var fast_marker_cluster_3d4c723a6944773843aa1d706fcd3842 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[-61.0, -151.0], [49.0, 90.0], [-60.0, -58.0], [20.0, -147.0], [-17.0, -75.0], [80.0, 92.0], [-1.0, -176.0], [31.0, -26.0], [9.0, 30.0], [0.0, -85.0], [67.0, 173.0], [81.0, 171.0], [-32.0, -127.0], [-2.0, -45.0], [-76.0, -111.0], [63.0, 166.0], [49.0, -119.0], [-39.0, -98.0], [-54.0, -57.0], [1.0, 21.0], [-62.0, -166.0], [89.0, -141.0], [12.0, -27.0], [14.0, -114.0], [-74.0, 154.0], [-17.0, 58.0], [-11.0, -95.0], [77.0, 116.0], [12.0, 8.0], [83.0, 3.0], [0.0, -135.0], [-35.0, 149.0], [38.0, 39.0], [-14.0, -105.0], [-83.0, -41.0], [-10.0, 1.0], [-88.0, 139.0], [55.0, -56.0], [2.0, 26.0], [87.0, 19.0], [-14.0, -26.0], [60.0, -94.0], [-62.0, -118.0], [-38.0, 119.0], [-73.0, 59.0], [-72.0, -88.0], [-29.0, -52.0], [-1.0, -167.0], [-80.0, -159.0], [-43.0, -112.0], [-65.0, 154.0], [-52.0, -146.0], [58.0, 0.0], [-51.0, -91.0], [1.0, -73.0], [-30.0, 141.0], [-11.0, 25.0], [-18.0, 123.0], [-13.0, -43.0], [42.0, 166.0], [-39.0, 65.0], [-40.0, 57.0], [29.0, 62.0], [-35.0, -59.0], [-71.0, -130.0], [20.0, -112.0], [-47.0, 132.0], [-9.0, -14.0], [-46.0, -86.0], [-80.0, -147.0], [47.0, -118.0], [-3.0, -52.0], [4.0, 136.0], [-86.0, -138.0], [44.0, -84.0], [60.0, 77.0], [20.0, -83.0], [36.0, -10.0], [39.0, 36.0], [15.0, 91.0], [-57.0, 51.0], [-50.0, -50.0], [-14.0, 153.0], [-50.0, 80.0], [59.0, 21.0], [-1.0, 159.0], [-25.0, 122.0], [71.0, -172.0], [-23.0, 97.0], [-83.0, 101.0], [-40.0, -164.0], [-1.0, 2.0], [4.0, 160.0], [70.0, -95.0], [12.0, 102.0], [53.0, -48.0], [-26.0, -87.0], [87.0, 141.0], [-52.0, 70.0], [-8.0, 147.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_5434c881b9383c8f79f32c4e75aeb8a2);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_3d4c723a6944773843aa1d706fcd3842.addTo(map_5434c881b9383c8f79f32c4e75aeb8a2);
#
#
#             var layer_control_d8e4fd5693b34d8cf83609c5f2035d5b_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_a48e498850dd940c79dab600bc85c024,
#                 },
#                 overlays :  {
#                     &quot;macro_element_3d4c723a6944773843aa1d706fcd3842&quot; : fast_marker_cluster_3d4c723a6944773843aa1d706fcd3842,
#                 },
#             };
#             let layer_control_d8e4fd5693b34d8cf83609c5f2035d5b = L.control.layers(
#                 layer_control_d8e4fd5693b34d8cf83609c5f2035d5b_layers.base_layers,
#                 layer_control_d8e4fd5693b34d8cf83609c5f2035d5b_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_5434c881b9383c8f79f32c4e75aeb8a2);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b36bee8008249141249ba76bdc7a947 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b36bee8008249141249ba76bdc7a947&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b36bee8008249141249ba76bdc7a947 = L.map(
#                 &quot;map_0b36bee8008249141249ba76bdc7a947&quot;,
#                 {
#                     center: [-5.24, -6.69],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5c76f52afe7a33bc2ae7bf25fb172840 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5c76f52afe7a33bc2ae7bf25fb172840.addTo(map_0b36bee8008249141249ba76bdc7a947);
#
#
#             var fast_marker_cluster_a12fbe2d287e7cb6446fefbb962b22a2 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[-61.0, -151.0], [49.0, 90.0], [-60.0, -58.0], [20.0, -147.0], [-17.0, -75.0], [80.0, 92.0], [-1.0, -176.0], [31.0, -26.0], [9.0, 30.0], [0.0, -85.0], [67.0, 173.0], [81.0, 171.0], [-32.0, -127.0], [-2.0, -45.0], [-76.0, -111.0], [63.0, 166.0], [49.0, -119.0], [-39.0, -98.0], [-54.0, -57.0], [1.0, 21.0], [-62.0, -166.0], [89.0, -141.0], [12.0, -27.0], [14.0, -114.0], [-74.0, 154.0], [-17.0, 58.0], [-11.0, -95.0], [77.0, 116.0], [12.0, 8.0], [83.0, 3.0], [0.0, -135.0], [-35.0, 149.0], [38.0, 39.0], [-14.0, -105.0], [-83.0, -41.0], [-10.0, 1.0], [-88.0, 139.0], [55.0, -56.0], [2.0, 26.0], [87.0, 19.0], [-14.0, -26.0], [60.0, -94.0], [-62.0, -118.0], [-38.0, 119.0], [-73.0, 59.0], [-72.0, -88.0], [-29.0, -52.0], [-1.0, -167.0], [-80.0, -159.0], [-43.0, -112.0], [-65.0, 154.0], [-52.0, -146.0], [58.0, 0.0], [-51.0, -91.0], [1.0, -73.0], [-30.0, 141.0], [-11.0, 25.0], [-18.0, 123.0], [-13.0, -43.0], [42.0, 166.0], [-39.0, 65.0], [-40.0, 57.0], [29.0, 62.0], [-35.0, -59.0], [-71.0, -130.0], [20.0, -112.0], [-47.0, 132.0], [-9.0, -14.0], [-46.0, -86.0], [-80.0, -147.0], [47.0, -118.0], [-3.0, -52.0], [4.0, 136.0], [-86.0, -138.0], [44.0, -84.0], [60.0, 77.0], [20.0, -83.0], [36.0, -10.0], [39.0, 36.0], [15.0, 91.0], [-57.0, 51.0], [-50.0, -50.0], [-14.0, 153.0], [-50.0, 80.0], [59.0, 21.0], [-1.0, 159.0], [-25.0, 122.0], [71.0, -172.0], [-23.0, 97.0], [-83.0, 101.0], [-40.0, -164.0], [-1.0, 2.0], [4.0, 160.0], [70.0, -95.0], [12.0, 102.0], [53.0, -48.0], [-26.0, -87.0], [87.0, 141.0], [-52.0, 70.0], [-8.0, 147.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_0b36bee8008249141249ba76bdc7a947);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_a12fbe2d287e7cb6446fefbb962b22a2.addTo(map_0b36bee8008249141249ba76bdc7a947);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
